# %% [markdown]
# # **Read Data**

# %%
## Importing Packages
import math
import nltk
import random
import pickle
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
file_path = r'D:\Courses\codes\Py\GRAMSAUTO\DATA\en_US\data\en_US.twitter.txt'

# Open the file in read mode ('r')
with open(file_path, 'r', encoding='utf-8') as file:
    # Read the entire content of the file into a string
    contentB = file.read()

# %%
import re
content = re.sub(r'[^a-zA-Z\s]', '', contentB)

# %%
def preprocess_pipeline(data) -> 'list':

    # Split by newline character
    sentences = data.split('\n')

        # Remove leading and trailing spaces
    sentences = [s.strip() for s in sentences]

    # Drop Empty Sentences
    sentences = [s for s in sentences if len(s) > 0]

    # Empty List to hold Tokenized Sentences
    tokenized = []

    # Iterate through sentences
    for sentence in sentences:

        # Convert to lowercase
        sentence = sentence.lower()

        # Convert to a list of words
        token = nltk.word_tokenize(sentence)

        # Append to list
        tokenized.append(token)

    return tokenized

# %%
tokenized_sentences = preprocess_pipeline(content)

# %%
tokenized_sentences
# Out:
# [['how',
#   'are',
#   'you',
#   'btw',
#   'thanks',
#   'for',
#   'the',
#   'rt',
#   'you',
#   'gon',
#   'na',
#   'be',
#   'in',
#   'dc',
#   'anytime',
#   'soon',
#   'love',
#   'to',
#   'see',
#   'you',
#   'been',
#   'way',
#   'way',
#   'too',
#   'long'],
#  ['when',
#   'you',
#   'meet',
#   'someone',
#   'special',
#   'youll',
#   'know',
#   'your',
#   'heart',
#   'will',
#   'beat',
#   'more',
#   'rapidly',
#   'and',
#   'youll',
#   'smile',
#   'for',
#   'no',
#   'reason'],
#  ['theyve', 'decided', 'its', 'more', 'fun', 'if', 'i', 'dont'],
#  ['so',
#   'tired',
#   'd',
#   'played',
#   'lazer',
#   'tag',
#   'ran',
#   'a',
#   'lot',
#   'd',
#   'ughh',
#   'going',
#   'to',
#   'sleep',
#   'like',
#   'in',
#   'minutes'],
#  ['words',
#   'from',
#   'a',
#   'complete',
#   'stranger',
#   'made',
#   'my',
#   'birthday',
#   'even',
#   'better'],
#  ['first',
#   'cubs',
#   'game',
#   'ever',
#   'wrigley',
#   'field',
#   'is',
#   'gorgeous',
#   'this',
#   'is',
#   'perfect',
#   'go',
#   'cubs',
#   'go'],
#  ['i',
#   'no',
#   'i',
#   'get',
#   'another',
#   'day',
#   'off',
#   'from',
#   'skool',
#   'due',
#   'to',
#   'the',
#   'wonderful',
#   'snow',
#   'and',
#   'this',
#   'wakes',
#   'me',
#   'updamn',
#   'thing'],
#  ['im',
#   'coo',
#   'jus',
#   'at',
#   'work',
#   'hella',
#   'tired',
#   'r',
#   'u',
#   'ever',
#   'in',
#   'cali'],
#  ['the',
#   'new',
#   'sundrop',
#   'commercial',
#   'hehe',
#   'love',
#   'at',
#   'first',
#   'sight'],
#  ['we', 'need', 'to', 'reconnect', 'this', 'week'],
#  ['i',
#   'always',
#   'wonder',
#   'how',
#   'the',
#   'guys',
#   'on',
#   'the',
#   'auctions',
#   'shows',
#   'learned',
#   'to',
#   'talk',
#   'so',
#   'fast',
#   'all',
#   'i',
#   'hear',
#   'is',
#   'djsosnekspqnslanskam'],
#  ['dammnnnnn', 'what', 'a', 'catch'],
#  ['such',
#   'a',
#   'great',
#   'picture',
#   'the',
#   'green',
#   'shirt',
#   'totally',
#   'brings',
#   'out',
#   'your',
#   'eyes'],
#  ['desk',
#   'put',
#   'together',
#   'room',
#   'all',
#   'set',
#   'up',
#   'oh',
#   'boy',
#   'oh',
#   'boy'],
#  ['im', 'doing', 'it'],
#  ['beauty',
#   'brainstorming',
#   'in',
#   'the',
#   'alchemy',
#   'office',
#   'with',
#   'and',
#   'sally',
#   'walker'],
#  ['looking',
#   'for',
#   'a',
#   'new',
#   'band',
#   'to',
#   'blog',
#   'for',
#   'the',
#   'month',
#   'anyone',
#   'interested'],
#  ['packing',
#   'for',
#   'a',
#   'quick',
#   'move',
#   'down',
#   'the',
#   'street',
#   'if',
#   'only',
#   'i',
#   'had',
#   'some',
#   'movers'],
#  ['ford', 'focus', 'hatchback'],
#  ['rt',
#   'according',
#   'to',
#   'the',
#   'national',
#   'retail',
#   'federation',
#   'billion',
#   'was',
#   'spent',
#   'on',
#   'mothersday',
#   'last',
#   'year'],
#  ['the',
#   'tragedy',
#   'of',
#   'life',
#   'is',
#   'not',
#   'that',
#   'it',
#   'ends',
#   'so',
#   'soon',
#   'but',
#   'that',
#   'we',
#   'wait',
#   'so',
#   'long',
#   'to',
#   'begin',
#   'it',
#   'wm',
#   'lewis'],
#  ['more',
#   'skating',
#   'come',
#   'by',
#   'the',
#   'check',
#   'out',
#   'a',
#   'movie',
#   'eat',
#   'a',
#   'great',
#   'dinner',
#   'and',
#   'top',
#   'it',
#   'off',
#   'with',
#   'great',
#   'times',
#   'at',
#   'the',
#   'ice',
#   'rink'],
#  ['watch', 'your', 'mailbox'],
#  ['tommorows', 'the', 'day'],
#  ['good',
#   'questions',
#   'rt',
#   'your',
#   'brand',
#   'will',
#   'be',
#   'judged',
#   'based',
#   'on',
#   'its',
#   'website',
#   'is',
#   'your',
#   'website',
#   'a',
#   'good',
#   'brand',
#   'ambassador'],
#  ['dont',
#   'care',
#   'what',
#   'others',
#   'think',
#   'of',
#   'you',
#   'and',
#   'you',
#   'will',
#   'save',
#   'yourself',
#   'a',
#   'lot',
#   'of',
#   'mental',
#   'energy',
#   'that',
#   'instead',
#   'can',
#   'be',
#   'used',
#   'to',
#   'push',
#   'you',
#   'towards',
#   'success'],
#  ['this',
#   'ron',
#   'artest',
#   'interview',
#   'is',
#   'it',
#   'possible',
#   'to',
#   'die',
#   'from',
#   'laughter'],
#  ['linda',
#   'just',
#   'looked',
#   'at',
#   'my',
#   'sched',
#   'i',
#   'have',
#   'to',
#   'hustle',
#   'back',
#   'to',
#   'chula',
#   'for',
#   'pm',
#   'meetings',
#   'so',
#   'no',
#   'time',
#   'lunch',
#   'do',
#   'u',
#   'meet',
#   'every',
#   'fri'],
#  ['bum',
#   'squad',
#   'lets',
#   'get',
#   'it',
#   'rt',
#   'shout',
#   'that',
#   'ninja',
#   'out',
#   'for',
#   'winning'],
#  ['i',
#   'love',
#   'you',
#   'and',
#   'im',
#   'so',
#   'proud',
#   'of',
#   'you',
#   'from',
#   'sitting',
#   'on',
#   'those',
#   'stairs',
#   'on',
#   'the',
#   'x',
#   'factor',
#   'to',
#   'now',
#   'you',
#   'boys',
#   'are',
#   'my',
#   'inspiration',
#   'xx'],
#  ['maybe',
#   'some',
#   'other',
#   'time',
#   'i',
#   'cant',
#   'slow',
#   'down',
#   'right',
#   'across',
#   'that',
#   'state',
#   'line',
#   'right',
#   'about',
#   'now'],
#  ['exhaust', 'leak', 'arrrgh'],
#  ['i',
#   'love',
#   'reading',
#   'your',
#   'magazine',
#   'it',
#   'always',
#   'cheers',
#   'me',
#   'up'],
#  ['tables',
#   'are',
#   'all',
#   'sold',
#   'out',
#   'for',
#   'the',
#   'mystique',
#   'masquerade',
#   'ball'],
#  ['make',
#   'one',
#   'up',
#   'it',
#   'might',
#   'help',
#   'you',
#   'feel',
#   'better',
#   'alternative',
#   'just',
#   'scream',
#   'nonsense',
#   'at',
#   'the',
#   'dumb',
#   'machine'],
#  ['ya',
#   'ik',
#   'and',
#   'i',
#   'never',
#   'asked',
#   'him',
#   'to',
#   'follow',
#   'me',
#   'i',
#   'only',
#   'mentioned',
#   'him',
#   'once',
#   'in',
#   'one',
#   'of',
#   'my',
#   'tweets',
#   'i',
#   'didnt',
#   'do',
#   'anything',
#   'else'],
#  ['i', 'will'],
#  ['great',
#   'talking',
#   'to',
#   'you',
#   'guys',
#   'tonight',
#   'looking',
#   'forward',
#   'to',
#   'your',
#   'piece',
#   'next',
#   'week',
#   'jon'],
#  ['small', 'market', 'baseball', 'you', 'knowfor', 'the'],
#  ['sing', 'it'],
#  ['it', 'comes', 'on', 'tonight', 'not', 'tomorrow'],
#  ['maybe',
#   'just',
#   'seems',
#   'they',
#   'thought',
#   'up',
#   'that',
#   'idea',
#   'over',
#   'sunday',
#   'brunch',
#   'and',
#   'thought',
#   'it',
#   'was',
#   'swell'],
#  ['thanks',
#   'for',
#   'the',
#   'ff',
#   'awfully',
#   'good',
#   'company',
#   'to',
#   'be',
#   'in'],
#  ['the',
#   'longer',
#   'we',
#   'live',
#   'the',
#   'more',
#   'we',
#   'find',
#   'we',
#   'are',
#   'like',
#   'other',
#   'persons',
#   'oliver',
#   'wendell',
#   'holmes'],
#  ['made', 'my', 'list', 'for', 'top', 'women'],
#  ['nice',
#   'i',
#   'watched',
#   'the',
#   'whole',
#   'series',
#   'loved',
#   'julia',
#   'and',
#   'her',
#   'mom',
#   'erica',
#   'was',
#   'such',
#   'a',
#   'badass'],
#  ['gop',
#   'line',
#   'on',
#   'obama',
#   'gay',
#   'marriage',
#   'stance',
#   'seems',
#   'to',
#   'be',
#   'that',
#   'he',
#   'flipflopped',
#   'really',
#   'want',
#   'to',
#   'use',
#   'that',
#   'with',
#   'romney',
#   'as',
#   'your',
#   'presidential',
#   'candidate'],
#  ['i',
#   'know',
#   'i',
#   'know',
#   'then',
#   'you',
#   'kick',
#   'yourself',
#   'when',
#   'the',
#   'fight',
#   'goes',
#   'lopsided',
#   'but',
#   'if',
#   'the',
#   'upset',
#   'does',
#   'happen',
#   'wow',
#   'nothing',
#   'like',
#   'it'],
#  ['no',
#   'stress',
#   'balls',
#   'or',
#   'keg',
#   'and',
#   'different',
#   'crew',
#   'but',
#   'these',
#   'guys',
#   'know',
#   'how',
#   'to',
#   'party'],
#  ['william',
#   'davis',
#   'attorney',
#   'says',
#   'client',
#   'will',
#   'plead',
#   'insanity',
#   'he',
#   'faces',
#   'firstdegree',
#   'murder',
#   'charge',
#   'in',
#   'womans',
#   'death'],
#  ['occupymadison',
#   'ga',
#   'i',
#   'always',
#   'considered',
#   'myself',
#   'a',
#   'liberal',
#   'until',
#   'i',
#   'saw',
#   'the',
#   'liberal',
#   'machine',
#   'in',
#   'action',
#   'it',
#   'was',
#   'ugly'],
#  ['weird',
#   'thought',
#   'we',
#   'got',
#   'to',
#   'witness',
#   'the',
#   'change',
#   'of',
#   'a',
#   'millenia',
#   'the',
#   'next',
#   'change',
#   'is',
#   'generations',
#   'awayimagine',
#   'what',
#   'the',
#   'differences',
#   'will',
#   'be'],
#  ['got', 'a', 'good', 'one'],
#  ['love', 'chris', 'brown'],
#  ['wit', 'them', 'sexy', 'ass', 'lips'],
#  ['its', 'sounds', 'good'],
#  ['how',
#   'unfortunate',
#   'that',
#   'those',
#   'days',
#   'when',
#   'every',
#   'status',
#   'update',
#   'was',
#   'a',
#   'song',
#   'lyrics',
#   'were',
#   'also',
#   'the',
#   'days',
#   'when',
#   'i',
#   'first',
#   'discovered',
#   'new',
#   'wave'],
#  ['i', 'had', 'a', 'bomb', 'ass', 'day', 'chillin', 'with', 'friends'],
#  ['working',
#   'on',
#   'music',
#   'for',
#   'holiday',
#   'show',
#   'on',
#   'the',
#   'in',
#   'santa',
#   'barbara',
#   'open',
#   'bar',
#   'me',
#   'tim',
#   'from',
#   'palin',
#   'white',
#   'ts',
#   'and',
#   'jr',
#   'richards',
#   'from',
#   'dishwalla'],
#  ['hey',
#   'nate',
#   'thanks',
#   'for',
#   'dropping',
#   'by',
#   'yesterday',
#   'how',
#   'was',
#   'your',
#   'meal'],
#  ['ff', 'literary', 'lights', 'who', 'brightened', 'my', 'week'],
#  ['time',
#   'to',
#   'shape',
#   'up',
#   'water',
#   'pavement',
#   'weights',
#   'and',
#   'zija',
#   'are',
#   'going',
#   'to',
#   'be',
#   'my',
#   'friends',
#   'wedding',
#   'just',
#   'months',
#   'away'],
#  ['report',
#   'the',
#   'many',
#   'things',
#   'that',
#   'are',
#   'positive',
#   'about',
#   'the',
#   'university',
#   'of',
#   'arkansas',
#   'athletics',
#   'program'],
#  ['athletescelebrities',
#   'should',
#   'have',
#   'a',
#   'tool',
#   'to',
#   'charge',
#   'per',
#   'rt',
#   'request',
#   'to',
#   'support',
#   'foundationscharities',
#   'fans',
#   'get',
#   'involved'],
#  ['enjoy', 'stay', 'cool'],
#  ['yo',
#   'chick',
#   'she',
#   'so',
#   'thirst',
#   'aye',
#   'i',
#   'really',
#   'dont',
#   'know',
#   'what',
#   'else',
#   'theyre',
#   'saying',
#   'tho',
#   'except',
#   'that',
#   'lol'],
#  ['talks', 'in', 'third', 'person'],
#  ['many',
#   'things',
#   'can',
#   'happen',
#   'only',
#   'you',
#   'can',
#   'control',
#   'your',
#   'reaction',
#   'to',
#   'it',
#   'practice',
#   'this',
#   'good'],
#  ['you',
#   'will',
#   'allow',
#   'me',
#   'to',
#   'continue',
#   'to',
#   'do',
#   'what',
#   'i',
#   'love',
#   'big',
#   'shows',
#   'wife'],
#  ['haha',
#   'very',
#   'cute',
#   'have',
#   'u',
#   'heard',
#   'from',
#   'julie',
#   'whos',
#   'that',
#   'on',
#   'her',
#   'fb',
#   'im',
#   'tryin',
#   'not',
#   'to',
#   'laugh'],
#  ['and', 'somedays', 'youre', 'the', 'windshield', 'wiper'],
#  ['im', 'taking', 'adam'],
#  ['lets', 'do', 'this'],
#  ['not', 'much', 'ben', 'hows', 'you'],
#  ['sarah', 'trying', 'to', 'explain', 'to', 'my', 'teacher', 'yolo', 'lmfao'],
#  ['inspiring',
#   'rt',
#   'great',
#   'minds',
#   'must',
#   'be',
#   'ready',
#   'not',
#   'only',
#   'to',
#   'take',
#   'opportunities',
#   'but',
#   'to',
#   'make',
#   'them',
#   'colton'],
#  ['med',
#   'schoolwow',
#   'i',
#   'could',
#   'never',
#   'do',
#   'that',
#   'am',
#   'too',
#   'ocd',
#   'to',
#   'be',
#   'around',
#   'blood',
#   'and',
#   'sick',
#   'people',
#   'for',
#   'long',
#   'periods',
#   'of',
#   'time'],
#  ['sleeping', 'not', 'likely', 'rt', 'sleeping', 'to'],
#  ['time', 'for', 'lunch'],
#  ['not', 'being', 'dependent', 'on', 'anyone', 'for', 'your', 'happiness'],
#  ['this',
#   'humidity',
#   'is',
#   'not',
#   'sitting',
#   'well',
#   'with',
#   'me',
#   'at',
#   'all',
#   'needacinschool',
#   'd'],
#  ['do',
#   'u',
#   'know',
#   'whats',
#   'creepily',
#   'i',
#   'hate',
#   'cheesecake',
#   'its',
#   'cake',
#   'with',
#   'cheese',
#   'in',
#   'front',
#   'of',
#   'it'],
#  ['thanks', 'got', 'it', 'at', 'walmart'],
#  ['still',
#   'havent',
#   'seen',
#   'super',
#   'every',
#   'th',
#   'checkin',
#   'wins',
#   'a',
#   'free',
#   'movie',
#   'ticket',
#   'checkins',
#   'so',
#   'far'],
#  ['rt',
#   'congratulations',
#   'to',
#   'the',
#   'for',
#   'advancing',
#   'in',
#   'the',
#   'stanleycup',
#   'playoffs',
#   'they',
#   'defeated',
#   'the',
#   'sens',
#   'in',
#   'a',
#   'series'],
#  ['hey', 'hey', 'hey', 'can', 'i', 'meet', 'chaaaa'],
#  ['ghost', 'hunters', 'makes', 'me', 'cry'],
#  ['whos',
#   'going',
#   'to',
#   'the',
#   'ovw',
#   'show',
#   'tomorrow',
#   'your',
#   'team',
#   'dominoski',
#   'will',
#   'be',
#   'in',
#   'the',
#   'house',
#   'first',
#   'brew',
#   'after',
#   'the',
#   'show',
#   'is',
#   'on',
#   'me'],
#  ['just', 'waking', 'up', 'but', 'therave', 'last', 'night', 'though'],
#  ['at', 'six', 'flags'],
#  ['thanks', 'tom'],
#  ['theyre',
#   'not',
#   'applauding',
#   'because',
#   'you',
#   'dont',
#   'have',
#   'a',
#   'button'],
#  ['im',
#   'not',
#   'mad',
#   'it',
#   'just',
#   'sucks',
#   'that',
#   'i',
#   'cant',
#   'show',
#   'you',
#   'off',
#   'this'],
#  ['im', 'at', 'little', 'league', 'majors', 'try', 'outs', 'in'],
#  ['where', 'my', 'meatballs', 'at', 'and', 'naomi'],
#  ['doing',
#   'some',
#   'cufon',
#   'testing',
#   'and',
#   'implementation',
#   'in',
#   'wordpress',
#   'what',
#   'the',
#   'fouc',
#   'dyall',
#   'think',
#   'of',
#   'cufon'],
#  ['lo',
#   'mejor',
#   'it',
#   'was',
#   'cool',
#   'experiencing',
#   'work',
#   'through',
#   'the',
#   'eyes',
#   'of',
#   'an',
#   'excited',
#   'teen'],
#  ['me',
#   'the',
#   'only',
#   'b',
#   'word',
#   'u',
#   'should',
#   'call',
#   'a',
#   'girl',
#   'is',
#   'beautful',
#   'colin',
#   'or',
#   'a',
#   'butterfly'],
#  ['i',
#   'just',
#   'think',
#   'that',
#   'the',
#   'zooming',
#   'is',
#   'overused',
#   'it',
#   'needs',
#   'to',
#   'be',
#   'done',
#   'tastefully',
#   'and',
#   'its',
#   'not',
#   'the',
#   'point'],
#  ['if',
#   'you',
#   'have',
#   'firefox',
#   'or',
#   'google',
#   'chrome',
#   'type',
#   'in',
#   'let',
#   'it',
#   'snow',
#   'into',
#   'google',
#   'today'],
#  ['hahahahhahah', 'u', 'just', 'made', 'my', 'day', 'd'],
#  ['i',
#   'can',
#   'hear',
#   'high',
#   'and',
#   'dry',
#   'through',
#   'the',
#   'walls',
#   'amazing'],
#  ['rt',
#   'important',
#   'our',
#   'new',
#   'hashtag',
#   'is',
#   'sntck',
#   'please',
#   'tweet',
#   'your',
#   'specialneeds',
#   'resources',
#   'and',
#   'writings',
#   'with',
#   'us',
#   'to',
#   'share'],
#  ['proud',
#   'to',
#   'have',
#   'voted',
#   'twice',
#   'for',
#   'the',
#   'sagaftra',
#   'merger',
#   'have',
#   'you',
#   'voted',
#   'yet'],
#  ['this', 'conference', 'is', 'rockin'],
#  ['pretty', 'sure', 'that', 'was', 'a', 'broken', 'leg'],
#  ['keith',
#   'was',
#   'also',
#   'good',
#   'a',
#   'smoking',
#   'in',
#   'the',
#   'dugout',
#   'and',
#   'being',
#   'a',
#   'class',
#   'a',
#   'jerk',
#   'i',
#   'grew',
#   'up',
#   'a',
#   'mets',
#   'fansorry',
#   'to',
#   'admit'],
#  ['shes', 'calling', 'you', 'back', 'is', 'having', 'a', 'moment'],
#  ['reward',
#   'yourself',
#   'for',
#   'just',
#   'getting',
#   'up',
#   'in',
#   'the',
#   'morning',
#   'its',
#   'a',
#   'wonderful',
#   'accomplishment'],
#  ['big',
#   'ups',
#   'to',
#   'for',
#   'leaving',
#   'voicemails',
#   'that',
#   'google',
#   'can',
#   'accurately',
#   'transcribe'],
#  ['get', 'better'],
#  ['everyone',
#   'say',
#   'a',
#   'prayer',
#   'for',
#   'my',
#   'brother',
#   'who',
#   'is',
#   'at',
#   'wrigley',
#   'field',
#   'with',
#   'his',
#   'wife',
#   'and',
#   'kids',
#   'she',
#   'and',
#   'her',
#   'daughters',
#   'are',
#   'in',
#   'cardinals',
#   'jerseys'],
#  ['why', 'you', 'actin', 'like', 'that', 'towards', 'me', 'now'],
#  ['have',
#   'a',
#   'great',
#   'eveningafternoonwhatever',
#   'it',
#   'is',
#   'where',
#   'you',
#   'are',
#   'folks'],
#  ['experience', 'of', 'a', 'life', 'time'],
#  ['hey',
#   'how',
#   'did',
#   'you',
#   'like',
#   'dogtooth',
#   'i',
#   'watched',
#   'like',
#   'six',
#   'months',
#   'ago',
#   'but',
#   'dont',
#   'know',
#   'anyone',
#   'else',
#   'who',
#   'saw',
#   'it'],
#  ['the',
#   'average',
#   'gossip',
#   'and',
#   'complain',
#   'the',
#   'exceptional',
#   'create',
#   'and',
#   'inspire',
#   'leadership',
#   'rt'],
#  ['onethingyoushouldntdo',
#   'spam',
#   'someone',
#   'to',
#   'death',
#   'its',
#   'like',
#   'stalking',
#   'them',
#   'like',
#   'really'],
#  ['me', 'too'],
#  ['buffalo',
#   'we',
#   'do',
#   'appreciate',
#   'you',
#   'following',
#   'poised',
#   'creation',
#   'on',
#   'twitter'],
#  ['i',
#   'promise',
#   'you',
#   'can',
#   'go',
#   'ten',
#   'minutes',
#   'without',
#   'hanging',
#   'on',
#   'his',
#   'arm'],
#  ['snap', 'backs', 'and', 'tattoos'],
#  ['fallout', 'from', 'the', 'original', 'actually'],
#  ['who', 'is', 'your', 'favorite', 'tv', 'mom'],
#  ['hey',
#   'giants',
#   'fans',
#   'how',
#   'ya',
#   'feeling',
#   'tonight',
#   'boy',
#   'do',
#   'you',
#   'look',
#   'dumb',
#   'in',
#   'that',
#   'stupid',
#   'panda',
#   'hat'],
#  ['out', 'of', 'twitter', 'jail', 'i', 'see'],
#  ['it', 'puts', 'the', 'woo', 'in', 'my', 'woo'],
#  ['people',
#   'can',
#   'keep',
#   'talkingthy',
#   'can',
#   'say',
#   'what',
#   'thy',
#   'likei',
#   'dont',
#   'worry',
#   'cause',
#   'everythings',
#   'goin',
#   'be',
#   'alrightno',
#   'one',
#   'get',
#   'n',
#   'way',
#   'i',
#   'feeling',
#   'jesus'],
#  ['drawn',
#   'dead',
#   'will',
#   'be',
#   'at',
#   'the',
#   'wynn',
#   'today',
#   'giving',
#   'out',
#   'free',
#   'shirts'],
#  ['the',
#   'fact',
#   'that',
#   'i',
#   'added',
#   'an',
#   'extra',
#   'd',
#   'on',
#   'the',
#   'end',
#   'of',
#   'just',
#   'amplifies',
#   'its',
#   'greatness',
#   'that',
#   'much',
#   'more',
#   'oy',
#   'vey'],
#  ['hmm',
#   'i',
#   'got',
#   'hackeddo',
#   'not',
#   'open',
#   'that',
#   'link',
#   'in',
#   'the',
#   'dm',
#   'that',
#   'was',
#   'sent',
#   'from',
#   'my',
#   'account',
#   'sorry',
#   'yikes'],
#  ['dont', 'break', 'my', 'butt'],
#  ['youre', 'welcome'],
#  ['o',
#   'intrigued',
#   'by',
#   'were',
#   'in',
#   'negotiations',
#   'for',
#   'building',
#   'our',
#   'new',
#   'website'],
#  ['so', 'what', 'do', 'you', 'do', 'in', 'okc'],
#  ['the',
#   'fact',
#   'that',
#   'lives',
#   'on',
#   'an',
#   'island',
#   'makes',
#   'me',
#   'wan',
#   'na',
#   'shoot',
#   'myself',
#   'because',
#   'i',
#   'need',
#   'to',
#   'see',
#   'her',
#   'at',
#   'least',
#   'every',
#   'other',
#   'day',
#   'to',
#   'feel',
#   'sane'],
#  ['players',
#   'were',
#   'tebowing',
#   'before',
#   'sat',
#   'nfl',
#   'astroturf',
#   'collegiate',
#   'bowl',
#   'praying',
#   'in',
#   'the',
#   'end',
#   'zone',
#   'before',
#   'the',
#   'game',
#   'and',
#   'tebowing',
#   'a',
#   'great',
#   'stite'],
#  ['yes', 'they', 'can'],
#  ['hahahahaha',
#   'i',
#   'love',
#   'it',
#   'thanks',
#   'for',
#   'the',
#   'quick',
#   'birthday',
#   'lesson'],
#  ['im', 'almost', 'up', 'to', 'youu'],
#  ['tonight', 'should', 'be', 'fun'],
#  ['i', 'spy', 'at', 'zeitgeist', 'coffee'],
#  ['thanks', 'for', 'the', 'retweet'],
#  ['be', 'quiet', 'poo', 'balls', 'im', 'writing', 'this', 'on', 'my', 'wall'],
#  ['sarkozy', 'more', 'like', 'sarkohnohedidntzy', 'am', 'i', 'right'],
#  ['going',
#   'through',
#   'rnrchi',
#   'bag',
#   'wondering',
#   'if',
#   'people',
#   'actually',
#   'pay',
#   'to',
#   'do',
#   'the',
#   'ready',
#   'to',
#   'run',
#   'mile',
#   'training',
#   'run'],
#  ['thats',
#   'game',
#   'we',
#   'lost',
#   'i',
#   'cant',
#   'hate',
#   'on',
#   'the',
#   'heat',
#   'good',
#   'game'],
#  ['the', 'marlins', 'wish', 'they', 'had', 'in', 'attendance', 'tonight'],
#  ['for', 'nelson'],
#  ['tweetin', 'while', 'i', 'walk', 'check', 'my', 'walkin', 'soundtrack'],
#  ['are',
#   'you',
#   'visiting',
#   'again',
#   'cause',
#   'that',
#   'would',
#   'be',
#   'awesome'],
#  ['no',
#   'its',
#   'the',
#   'interview',
#   'he',
#   'told',
#   'us',
#   'about',
#   'in',
#   'class',
#   'member'],
#  ['who', 'has', 'the', 'bigger', 'stick'],
#  ['these',
#   'late',
#   'night',
#   'walks',
#   'are',
#   'still',
#   'religion',
#   'to',
#   'me',
#   'thank',
#   'goodness',
#   'for',
#   'these'],
#  ['is', 'that', 'a', 'rhetorical', 'question'],
#  ['i',
#   'want',
#   'a',
#   'new',
#   'phone',
#   'case',
#   'preferably',
#   'a',
#   'sparkly',
#   'one'],
#  ['everybody',
#   'in',
#   'the',
#   'class',
#   'is',
#   'laughing',
#   'at',
#   'this',
#   'part',
#   'and',
#   'i',
#   'had',
#   'no',
#   'idea',
#   'what',
#   'was',
#   'said',
#   'p'],
#  ['bestfriend',
#   'just',
#   'got',
#   'hit',
#   'on',
#   'my',
#   'a',
#   'something',
#   'year',
#   'old'],
#  ['thanks', 'for', 'the', 'follow', 'your', 'gorgeous', 'btw'],
#  ['oh',
#   'boo',
#   'and',
#   'here',
#   'i',
#   'was',
#   'promoting',
#   'what',
#   'i',
#   'thought',
#   'it',
#   'would',
#   'be',
#   'to',
#   'a',
#   'friend',
#   'yesterday',
#   'let',
#   'me',
#   'know',
#   'if',
#   'the',
#   'cobbler',
#   'needs',
#   'help'],
#  ['collaboration',
#   'addresses',
#   'complex',
#   'problems',
#   'more',
#   'effectively',
#   'because',
#   'there',
#   'are',
#   'more',
#   'perspectives',
#   'in',
#   'the',
#   'roomgary',
#   'mangiofico'],
#  ['cinco', 'de', 'mayo', 'fiesta', 'at', 'la', 'carreta', 'is', 'packed'],
#  ['dallas',
#   'slapped',
#   'me',
#   'on',
#   'my',
#   'red',
#   'as',
#   'cherries',
#   'sunburn',
#   'and',
#   'im',
#   'still',
#   'crying',
#   'aftr',
#   'mins',
#   'i',
#   'hate',
#   'him'],
#  ['is',
#   'that',
#   'kind',
#   'of',
#   'place',
#   'like',
#   'in',
#   'dc',
#   'ladybugs',
#   'lurv',
#   'it'],
#  ['well', 'done'],
#  ['i', 'was', 'born', 'weeks', 'early', 'haha'],
#  ['cant', 'wait', 'till'],
#  ['you', 'are', 'gorgeous', 'em'],
#  ['thats',
#   'what',
#   'i',
#   'thought',
#   'just',
#   'wanted',
#   'to',
#   'check',
#   'before',
#   'i',
#   'rework',
#   'it'],
#  ['adele', 'gets', 'off', 'a', 'standing', 'ovation', 'right', 'away'],
#  ['keep', 'moving', 'and', 'get', 'out', 'of', 'the', 'way'],
#  ['yeah',
#   'l',
#   'could',
#   'be',
#   'the',
#   'bigger',
#   'person',
#   'or',
#   'you',
#   'could',
#   'just',
#   'shut',
#   'the',
#   'fuck',
#   'up'],
#  ['anything',
#   'intriguing',
#   'going',
#   'over',
#   'there',
#   'any',
#   'clues',
#   'on',
#   'who',
#   'the',
#   'browns',
#   'draft',
#   'next'],
#  ['being',
#   'chauffeured',
#   'in',
#   'a',
#   'brand',
#   'new',
#   'range',
#   'rover',
#   'w',
#   'and',
#   'happy',
#   'derby',
#   'day'],
#  ['i', 'lost', 'pounds', 'sweating', 'in', 'sparring', 'class', 'today'],
#  ['let',
#   'peace',
#   'find',
#   'a',
#   'toe',
#   'hold',
#   'in',
#   'this',
#   'tumultuous',
#   'world'],
#  ['reminder',
#   'we',
#   'play',
#   'in',
#   'dallas',
#   'tonight',
#   'at',
#   'the',
#   'den',
#   'p',
#   'start',
#   'see',
#   'yall',
#   'there'],
#  ['me', 'too'],
#  ['and',
#   'thank',
#   'everyone',
#   'of',
#   'you',
#   'who',
#   'has',
#   'taken',
#   'the',
#   'time',
#   'out',
#   'of',
#   'your',
#   'day',
#   'to',
#   'listen',
#   'to',
#   'us',
#   'your',
#   'all',
#   'amazing',
#   'much',
#   'love',
#   'hp'],
#  ['in',
#   'md',
#   'miaaa',
#   'boys',
#   'lax',
#   'action',
#   'st',
#   'marys',
#   'annapolis',
#   'goes',
#   'into',
#   'loyolablakefields',
#   'house',
#   'and',
#   'leaves',
#   'with',
#   'a',
#   'victory'],
#  ['fridaytheth', 'is', 'the', 'best', 'movie', 'everand', 'todays', 'date'],
#  ['the',
#   'poor',
#   'needs',
#   'relief',
#   'and',
#   'they',
#   'need',
#   'it',
#   'now',
#   'somebody',
#   'help'],
#  ['okay',
#   'so',
#   'apparently',
#   'its',
#   'not',
#   'new',
#   'sorry',
#   'for',
#   'having',
#   'a',
#   'life',
#   'and',
#   'not',
#   'listening',
#   'to',
#   'music',
#   'all',
#   'day',
#   'long'],
#  ['heard',
#   'pm',
#   'was',
#   'in',
#   'broncos',
#   'training',
#   'facility',
#   'all',
#   'day',
#   'even',
#   'had',
#   'a',
#   'hour'],
#  ['that',
#   'is',
#   'hilarious',
#   'we',
#   'need',
#   'to',
#   'do',
#   'what',
#   'we',
#   'can',
#   'to',
#   'feel',
#   'young'],
#  ['i', 'had', 'the', 'weirdest', 'dreams', 'last', 'night'],
#  ['scrapbook',
#   'class',
#   'next',
#   'up',
#   'hinged',
#   'reattachment',
#   'of',
#   'enclosures',
#   'w',
#   'wheat',
#   'paste',
#   'and',
#   'japanese',
#   'tissue',
#   'its',
#   'like',
#   'im',
#   'at',
#   'nerd',
#   'camp'],
#  ['if',
#   'your',
#   'girlfriends',
#   'parents',
#   'pay',
#   'her',
#   'cell',
#   'phone',
#   'bill'],
#  ['thanks', 'ill', 'definitely', 'be', 'using', 'some', 'edmundson'],
#  ['this',
#   'little',
#   'girl',
#   'by',
#   'cady',
#   'groves',
#   'i',
#   'it',
#   'look',
#   'it',
#   'up'],
#  ['yourkoz',
#   'gamesfind',
#   'out',
#   'who',
#   'this',
#   'isshe',
#   'concentrates',
#   'on',
#   'the',
#   'calibre',
#   'and',
#   'quality',
#   'of',
#   'education',
#   'for',
#   'jordanian',
#   'children',
#   'global',
#   'education'],
#  ['can',
#   'u',
#   'please',
#   'rt',
#   'or',
#   'follow',
#   'im',
#   'one',
#   'of',
#   'your',
#   'biggest',
#   'fans'],
#  ['the',
#   'tea',
#   'party',
#   'movement',
#   'filled',
#   'the',
#   'gap',
#   'in',
#   'republican',
#   'party',
#   'on',
#   'intolerance',
#   'for',
#   'overspending'],
#  ['flores',
#   'says',
#   'vocational',
#   'training',
#   'is',
#   'his',
#   'backyard',
#   'admiration',
#   'for',
#   'police',
#   'nurses'],
#  ['in', 'krav', 'maga', 'there', 'are', 'no', 'rules', 'no', 'restrictions'],
#  ['thank', 'you', 'im', 'proud', 'of', 'us', 'all'],
#  ['i', 'love', 'you', 'brianana'],
#  ['as',
#   'for',
#   'me',
#   'and',
#   'my',
#   'house',
#   'we',
#   'will',
#   'serve',
#   'the',
#   'lord',
#   'and',
#   'we',
#   'will',
#   'embrace',
#   'our',
#   'lgbt',
#   'brothers',
#   'and',
#   'sisters'],
#  ['im', 'following', 'u', 'so', 'u', 'cant', 'welch', 'lol'],
#  ['plan', 'on', 'being', 'a', 'dj'],
#  ['i',
#   'actually',
#   'saw',
#   'a',
#   'police',
#   'officer',
#   'on',
#   'horseback',
#   'galloping',
#   'through',
#   'downtown'],
#  ['th',
#   'grade',
#   'was',
#   'so',
#   'great',
#   'though',
#   'we',
#   'all',
#   'said',
#   'wed',
#   'all',
#   'stay',
#   'close',
#   'we',
#   'should',
#   'all',
#   'get',
#   'together',
#   'asap'],
#  ['so', 'its', 'not', 'the', 'same'],
#  ['got',
#   'that',
#   'vol',
#   'return',
#   'of',
#   'the',
#   'bodysnatchers',
#   'bumpin',
#   'perfect',
#   'for',
#   'the',
#   'gym',
#   'im',
#   'going',
#   'in',
#   'right',
#   'now'],
#  ['is',
#   'our',
#   'new',
#   'twitter',
#   'pg',
#   'follow',
#   'exciting',
#   'deals',
#   'atx',
#   'challenges',
#   'insights',
#   'on',
#   'fashion',
#   'epicurean',
#   'entertainment',
#   'the',
#   'arts'],
#  ['daddy', 'got', 'a', 'new', 'truck'],
#  ['freakin', 'is', 'flawlessin', 'every', 'way'],
#  ['hes', 'next', 'to', 'go', 'bro'],
#  ['thanks',
#   'for',
#   'finally',
#   'providing',
#   'a',
#   'good',
#   'nights',
#   'rest',
#   'and',
#   'i',
#   'had',
#   'a',
#   'great',
#   'time',
#   'hope',
#   'your',
#   'run',
#   'post',
#   'beers',
#   'was',
#   'good'],
#  ['i', 'love', 'my', 'momma'],
#  ['hello', 'new', 'followers'],
#  ['not',
#   'sure',
#   'any',
#   'recommendations',
#   'rt',
#   'hey',
#   'chicago',
#   'what',
#   'are',
#   'you',
#   'eating',
#   'at',
#   'the',
#   'taste',
#   'of',
#   'chicago',
#   'this',
#   'weekend'],
#  ['mayoral',
#   'candidate',
#   'forum',
#   'on',
#   'education',
#   'this',
#   'thursday',
#   'january',
#   'pm',
#   'at',
#   'warren',
#   'easton',
#   'canal',
#   'street'],
#  ['ah',
#   'i',
#   'miss',
#   'that',
#   'place',
#   'so',
#   'much',
#   'we',
#   'def',
#   'need',
#   'to',
#   'do',
#   'another',
#   'road',
#   'trip',
#   'this',
#   'summer'],
#  ['join',
#   'the',
#   'maui',
#   'mall',
#   'shoppers',
#   'club',
#   'at',
#   'wwwmauimallcom',
#   'we',
#   'give',
#   'away',
#   'three',
#   'great',
#   'prizes',
#   'monthly',
#   'including',
#   'gift',
#   'certificate',
#   'to',
#   'the',
#   'mall'],
#  ['busy',
#   'day',
#   'i',
#   'thought',
#   'called',
#   'about',
#   'film',
#   'but',
#   'it',
#   'was',
#   'same',
#   'name',
#   'dude',
#   'who',
#   'is',
#   'a',
#   'set',
#   'medic',
#   'internmistakes'],
#  ['total', 'white', 'cat', 'move'],
#  ['i', 'actually', 'liked', 'derek', 'morris', 'as', 'a', 'ranger'],
#  ['twovsuns',
#   'massage',
#   'is',
#   'now',
#   'offering',
#   'couples',
#   'massage',
#   'what',
#   'a',
#   'great',
#   'way',
#   'to',
#   'start',
#   'off',
#   'your',
#   'valentines',
#   'day',
#   'call',
#   'to',
#   'schedule',
#   'today'],
#  ['stellar',
#   'of',
#   'to',
#   'reply',
#   'digiday',
#   'i',
#   'find',
#   'the',
#   'lack',
#   'of',
#   'women',
#   'in',
#   'marketingpr',
#   'leadership',
#   'interesting',
#   'its',
#   'an',
#   'area',
#   'of',
#   'research',
#   'for',
#   'me'],
#  ['enter',
#   'to',
#   'win',
#   'an',
#   'orioles',
#   'vintage',
#   'cap',
#   'by',
#   'email',
#   'or',
#   'tweet',
#   'the',
#   'answer',
#   'to',
#   'which',
#   'os',
#   'pitchers',
#   'hold',
#   'the',
#   'record',
#   'for',
#   'the',
#   'most',
#   'opening',
#   'day',
#   'starts'],
#  ['prepare',
#   'for',
#   'testing',
#   'season',
#   'by',
#   'practicing',
#   'to',
#   'read',
#   'standardized',
#   'instructions',
#   'in',
#   'dry',
#   'monotone'],
#  ['what',
#   'is',
#   'a',
#   'life',
#   'without',
#   'a',
#   'purpose',
#   'what',
#   'is',
#   'a',
#   'purpose',
#   'without',
#   'love'],
#  ['got',
#   'to',
#   'fa',
#   'the',
#   'one',
#   'time',
#   'one',
#   'time',
#   'and',
#   'nope',
#   'that',
#   'shit',
#   'stressede',
#   'the',
#   'hell',
#   'out',
#   'boa'],
#  ['thats',
#   'the',
#   'beauty',
#   'of',
#   'selfpublishing',
#   'you',
#   'can',
#   'find',
#   'your',
#   'audience',
#   'without',
#   'publishing',
#   'types'],
#  ['im',
#   'waiting',
#   'patiently',
#   'for',
#   'the',
#   'videos',
#   'of',
#   'the',
#   'tram',
#   'ride',
#   'and',
#   'pics',
#   'at',
#   'yoga'],
#  ['congrats',
#   'to',
#   'patti',
#   'groff',
#   'clm',
#   'on',
#   'winning',
#   'the',
#   'spirit',
#   'of',
#   'ala',
#   'award',
#   'a',
#   'huge',
#   'honor',
#   'recognizing',
#   'leadership',
#   'and',
#   'dedication'],
#  ['finally',
#   'going',
#   'to',
#   'bed',
#   'had',
#   'a',
#   'long',
#   'night',
#   'but',
#   'atleast',
#   'it',
#   'was',
#   'for',
#   'a',
#   'good',
#   'cause',
#   'relayforlife'],
#  ['haha', 'works', 'for', 'me', 'sometimes'],
#  ['send', 'details', 'and', 'i', 'can', 'post'],
#  ['wearing',
#   'my',
#   'shirt',
#   'to',
#   'the',
#   'skrillex',
#   'show',
#   'in',
#   'indy',
#   'tonight',
#   'already',
#   'got',
#   'a',
#   'lot',
#   'of',
#   'compliments'],
#  ['howdy', 'ali', 'good', 'to', 'meet', 'you', 'too'],
#  ['the',
#   'scent',
#   'of',
#   'coco',
#   'chanel',
#   'perfume',
#   'will',
#   'aways',
#   'flood',
#   'me',
#   'with',
#   'lovely',
#   'memories',
#   'of',
#   'my',
#   'dear',
#   'aunt',
#   'lynn'],
#  ['we',
#   'all',
#   'got',
#   'that',
#   'one',
#   'friend',
#   'whose',
#   'laugh',
#   'is',
#   'always',
#   'funnier',
#   'than',
#   'the',
#   'joke'],
#  ['fact',
#   'girls',
#   'have',
#   'a',
#   'lot',
#   'of',
#   'crushes',
#   'but',
#   'their',
#   'heart',
#   'only',
#   'belongs',
#   'to',
#   'one',
#   'guy'],
#  ['number',
#   'one',
#   'seo',
#   'mistake',
#   'not',
#   'doing',
#   'on',
#   'page',
#   'keyword',
#   'optimization'],
#  ['count',
#   'on',
#   'me',
#   'rt',
#   'better',
#   'get',
#   'your',
#   'own',
#   'party',
#   'started'],
#  ['i',
#   'hate',
#   'when',
#   'i',
#   'wear',
#   'bhoops',
#   'and',
#   'people',
#   'are',
#   'like',
#   'the',
#   'bigger',
#   'the',
#   'hole',
#   'the',
#   'bigger',
#   'the',
#   'hoe',
#   'and',
#   'im',
#   'just',
#   'like',
#   'oo',
#   'bitch',
#   'try',
#   'me'],
#  ['be', 'the', 'light', 'in', 'the', 'world', 'of', 'darkness'],
#  ['kids',
#   'little',
#   'stage',
#   'puppet',
#   'theater',
#   'little',
#   'stage',
#   'puppet',
#   'theater',
#   'friday',
#   'may',
#   'at',
#   'pm',
#   'monrovia',
#   'california',
#   'e',
#   'colorado'],
#  ['lost',
#   'one',
#   'dream',
#   'so',
#   'now',
#   'im',
#   'gon',
#   'na',
#   'pursue',
#   'an',
#   'even',
#   'greater',
#   'one'],
#  ['interested',
#   'to',
#   'see',
#   'matte',
#   'football',
#   'helmets',
#   'next',
#   'year',
#   'not',
#   'convinced',
#   'yet'],
#  ['oh', 'man', 'i', 'want', 'some', 'french', 'toast', 'so', 'bad', 'now'],
#  ['you', 'mean', 'a', 'winky', 'face', 'is', 'not', 'the', 'correct', 'use'],
#  ['omg',
#   'jesus',
#   'loves',
#   'me',
#   'so',
#   'much',
#   'that',
#   'sometimes',
#   'my',
#   'hair',
#   'falls',
#   'out',
#   'then',
#   'i',
#   'pick',
#   'it',
#   'up',
#   'and',
#   'burn',
#   'it',
#   'as',
#   'an',
#   'offering',
#   'it',
#   'feels',
#   'so',
#   'nice'],
#  ['no', 'you', 'not'],
#  ['hi',
#   'there',
#   'sueanne',
#   'liking',
#   'the',
#   'newest',
#   'avatar',
#   'getting',
#   'to',
#   'be',
#   'beach',
#   'weather',
#   'right'],
#  ['the',
#   'trip',
#   'home',
#   'feels',
#   'twice',
#   'as',
#   'long',
#   'even',
#   'with',
#   'good',
#   'music',
#   'and',
#   'junk',
#   'food',
#   'too',
#   'bad',
#   'i',
#   'dont',
#   'smoke',
#   'anymore'],
#  ['thanks',
#   'for',
#   'ther',
#   'rt',
#   'about',
#   'administrative',
#   'professionals',
#   'day'],
#  ['tryin', 'to', 'stay', 'up', 'for', 'loiter', 'squad'],
#  ['looks',
#   'like',
#   'its',
#   'a',
#   'jquery',
#   'problem',
#   'in',
#   'thisselectmenuitem',
#   'this',
#   'refers',
#   'to',
#   'the',
#   'document',
#   'right'],
#  ['can', 'i', 'get', 'a', 'refill'],
#  ['sitting', 'in', 'the', 'doctors', 'office'],
#  ['ha', 'nah', 'that', 'aint', 'me'],
#  ['hey',
#   'everyone',
#   'please',
#   'follow',
#   'one',
#   'of',
#   'the',
#   'best',
#   'metal',
#   'drummers',
#   'ever',
#   'paul',
#   'bostaph'],
#  ['wow',
#   'bollywood',
#   'and',
#   'smash',
#   'are',
#   'still',
#   'trending',
#   'thats',
#   'how',
#   'good',
#   'tonights',
#   'episode',
#   'of',
#   'smash',
#   'was'],
#  ['seriously', 'ill', 'have', 'to', 'check', 'it', 'out'],
#  ['just',
#   'saw',
#   'this',
#   'tweet',
#   'it',
#   'was',
#   'good',
#   'to',
#   'meet',
#   'you',
#   'too',
#   'thank',
#   'you',
#   'so',
#   'much',
#   'for',
#   'your',
#   'support',
#   'mt'],
#  ['are', 'you', 'coming', 'to', 'get', 'donovan'],
#  ['ok',
#   'just',
#   'asked',
#   'to',
#   'have',
#   'it',
#   'shipped',
#   'should',
#   'have',
#   'it',
#   'in',
#   'the',
#   'next',
#   'few',
#   'days'],
#  ['engineering',
#   'dev',
#   'managerexcellent',
#   'leadership',
#   'opportunity',
#   'in',
#   'bellevue'],
#  ['sometimes',
#   'no',
#   'syntax',
#   'error',
#   'doesnt',
#   'equal',
#   'finished',
#   'it',
#   'equals',
#   'actually',
#   'beginning'],
#  ['listening',
#   'to',
#   'the',
#   'faint',
#   'always',
#   'makes',
#   'me',
#   'think',
#   'of',
#   'you',
#   'its',
#   'not',
#   'bad',
#   'for',
#   'paperwriting',
#   'music'],
#  ['sleep', 'with', 'one', 'eye', 'open'],
#  ['loved', 'that', 'beer', 'thank', 'you', 'for', 'sharing'],
#  ['successfully',
#   'set',
#   'up',
#   'nokia',
#   'education',
#   'delivery',
#   'server',
#   'locally',
#   'macbook',
#   'pro',
#   'but',
#   'am',
#   'at',
#   'a',
#   'loss',
#   'for',
#   'user',
#   'guides'],
#  ['that',
#   'alberto',
#   'is',
#   'part',
#   'of',
#   'our',
#   'secret',
#   'sauce',
#   'for',
#   'the',
#   'game',
#   'they',
#   'are',
#   'not',
#   'aware',
#   'as',
#   'that',
#   'could',
#   'bias',
#   'gameplay'],
#  ['hell', 'yeah', 'how', 'much', 'are', 'the', 'tickets'],
#  ['thank',
#   'god',
#   'lifetime',
#   'and',
#   'thank',
#   'you',
#   'john',
#   'i',
#   'hope',
#   'the',
#   'show',
#   'lasts',
#   'forever',
#   'on',
#   'television',
#   'this',
#   'show',
#   'is',
#   'very',
#   'valuable',
#   'to',
#   'all',
#   'of',
#   'us'],
#  ['teen',
#   'wolf',
#   'trailer',
#   'omg',
#   'i',
#   'cant',
#   'wait',
#   'till',
#   'it',
#   'comes',
#   'back',
#   'on'],
#  ['u',
#   'said',
#   'i',
#   'will',
#   'be',
#   'there',
#   'with',
#   'youbut',
#   'wisconsin',
#   'needs',
#   'u',
#   'now',
#   'go',
#   'spend',
#   'campaign',
#   'there'],
#  ['late', 'night', 'last', 'night'],
#  ['pittsburgh',
#   'wpxi',
#   'interviewing',
#   'family',
#   'across',
#   'st',
#   'whose',
#   'chimney',
#   'fell',
#   'down',
#   'during',
#   'the',
#   'earthquake',
#   'tempted',
#   'walk',
#   'out',
#   'dressed',
#   'in',
#   'my',
#   'batman',
#   'outfit'],
#  ['time', 'to', 'dream', 'bout', 'some', 'crazy', 'ishhh', 'goodnight'],
#  ['okaay', 'looool', 'i', 'still', 'remember', 'our', 'thoughts'],
#  ['its', 'my', 'fault', 'im', 'sorry'],
#  ['hey',
#   'clifbar',
#   'people',
#   'love',
#   'your',
#   'stuff',
#   'but',
#   'need',
#   'more',
#   'info',
#   'on',
#   'this',
#   'arsenic',
#   'in',
#   'organic',
#   'bar',
#   'business',
#   'in',
#   'the',
#   'news',
#   'today',
#   'whats',
#   'your',
#   'take'],
#  ['chicago', 'roadtrip', 'status', 'active'],
#  ['watched',
#   'anatomy',
#   'of',
#   'a',
#   'murder',
#   'tonight',
#   'have',
#   'u',
#   'seen',
#   'it',
#   'lates',
#   'courtroom',
#   'drama',
#   'that',
#   'you',
#   'would',
#   'surely',
#   'appreciate'],
#  ['happy',
#   'mothers',
#   'day',
#   'all',
#   'moms',
#   'from',
#   'me',
#   'floborojan',
#   'rt',
#   'yearning',
#   'hear',
#   'well',
#   'done',
#   'good',
#   'faithful',
#   'servantfrom',
#   'my',
#   'wife',
#   'cont'],
#  ['hard',
#   'to',
#   'believe',
#   'but',
#   'the',
#   'great',
#   'online',
#   'formerly',
#   'reignnet',
#   'has',
#   'accumulated',
#   'over',
#   'customers'],
#  ['griffin', 'shoots', 'on', 'his', 'way', 'down', 'irks', 'me'],
#  ['hey', 'shawty', 'i', 'was', 'thinkin', 'of', 'you'],
#  ['theyre',
#   'gon',
#   'na',
#   'win',
#   'just',
#   'to',
#   'fly',
#   'to',
#   'miami',
#   'tomorrow'],
#  ['sweet',
#   'let',
#   'me',
#   'know',
#   'what',
#   'you',
#   'think',
#   'cant',
#   'wait',
#   'to',
#   'read',
#   'humanize',
#   'by'],
#  ['stop', 'trying', 'to', 'control', 'everything', 'and', 'just', 'let', 'go'],
#  ['it', 'is', 'an', 'absolutely', 'gorgeous', 'december', 'moon'],
#  ['god',
#   'has',
#   'so',
#   'many',
#   'amazing',
#   'plans',
#   'for',
#   'you',
#   'i',
#   'cant',
#   'wait',
#   'for',
#   'whats',
#   'to',
#   'come',
#   'and',
#   'some',
#   'new',
#   'music'],
#  ['yuptheres',
#   'all',
#   'kinds',
#   'of',
#   'sneezing',
#   'sniffles',
#   'in',
#   'my',
#   'house',
#   'lately'],
#  ['were', 'apart', 'at', 'a', 'ray'],
#  ['holy',
#   'shit',
#   'my',
#   'mom',
#   'can',
#   'talk',
#   'about',
#   'the',
#   'same',
#   'damn',
#   'thing',
#   'that',
#   'everybody',
#   'already',
#   'knows'],
#  ['coming',
#   'up',
#   'on',
#   'a',
#   'year',
#   'with',
#   'twitter',
#   'and',
#   'not',
#   'much',
#   'to',
#   'show',
#   'for',
#   'it'],
#  ['ok', 'i', 'need', 'a', 'remote', 'starter', 'asap'],
#  ['i',
#   'could',
#   'go',
#   'for',
#   'a',
#   'nice',
#   'post',
#   'dinner',
#   'cheese',
#   'plate',
#   'what',
#   'kind',
#   'of',
#   'host',
#   'are',
#   'you'],
#  ['just',
#   'had',
#   'the',
#   'best',
#   'snow',
#   'cone',
#   'imperial',
#   'woodpecker',
#   'in',
#   'nyc',
#   'get',
#   'there'],
#  ['i', 'need', 'to', 'see', 'so', 'many', 'movies'],
#  ['why', 'do', 'i', 'always', 'buy', 'the', 'biggest', 'wedding', 'gift'],
#  ['younger',
#   'guys',
#   'is',
#   'in',
#   'the',
#   'rotation',
#   'hopefully',
#   'behind',
#   'cc',
#   'and',
#   'then',
#   'rf',
#   'prob',
#   'with',
#   'swisher',
#   'and',
#   'catcher'],
#  ['thanks',
#   'still',
#   'need',
#   'helpsuggestions',
#   'i',
#   'had',
#   'another',
#   'commitments',
#   'saturday',
#   'from',
#   'the',
#   'young',
#   'youth',
#   'group'],
#  ['i', 'deserve', 'to', 'know', 'its', 'gmo'],
#  ['started',
#   'today',
#   'at',
#   'with',
#   'meditation',
#   'and',
#   'a',
#   'double',
#   'iced',
#   'espresso',
#   'i',
#   'think',
#   'i',
#   'have',
#   'found',
#   'the',
#   'magic',
#   'morning',
#   'combo'],
#  ['its',
#   'your',
#   'blog',
#   'and',
#   'you',
#   'are',
#   'well',
#   'aware',
#   'of',
#   'the',
#   'link',
#   'dont',
#   'play',
#   'dumb',
#   'with',
#   'me'],
#  ['need', 'to', 'vacuum'],
#  ['the', 'panna', 'cotta', 'is', 'a', 'must', 'make'],
#  ['if',
#   'this',
#   'whole',
#   'journalism',
#   'thing',
#   'doesnt',
#   'work',
#   'out',
#   'i',
#   'think',
#   'i',
#   'now',
#   'know',
#   'what',
#   'i',
#   'want',
#   'my',
#   'second',
#   'career',
#   'to',
#   'be'],
#  ['because',
#   'theyre',
#   'bad',
#   'bitches',
#   'aka',
#   'bitches',
#   'doing',
#   'bad',
#   'close',
#   'to',
#   'the',
#   'lowest',
#   'female',
#   'life',
#   'form',
#   'next',
#   'to',
#   'jersey',
#   'chasers'],
#  ['man',
#   'i',
#   'am',
#   'in',
#   'the',
#   'weeds',
#   'today',
#   'at',
#   'work',
#   'someone',
#   'bring',
#   'me',
#   'zkabob',
#   'and',
#   'brighten',
#   'my',
#   'day'],
#  ['dont',
#   'forget',
#   'our',
#   'th',
#   'annual',
#   'cutsacause',
#   'is',
#   'tomorrow',
#   'from',
#   'dont',
#   'miss',
#   'out',
#   'on',
#   'this',
#   'amazing',
#   'event',
#   'call',
#   'to',
#   'book'],
#  ['at',
#   'first',
#   'i',
#   'wasnt',
#   'sure',
#   'because',
#   'im',
#   'vegetarian',
#   'but',
#   'some',
#   'of',
#   'their',
#   'menu',
#   'does',
#   'look',
#   'good',
#   'especially',
#   'the',
#   'cheeses'],
#  ['ill', 'go', 'without', 'before', 'i', 'beg', 'for', 'something'],
#  ['rt',
#   'and',
#   'iu',
#   'moves',
#   'on',
#   'to',
#   'the',
#   'next',
#   'round',
#   'of',
#   'the',
#   'tournament'],
#  ['silverton',
#   'skip',
#   'the',
#   'strip',
#   'new',
#   'years',
#   'eve',
#   'celebration',
#   'wristband',
#   'all',
#   'you',
#   'can',
#   'drink'],
#  ['i', 'need', 'two', 'new', 'tires'],
#  ['nba',
#   'fannight',
#   'chris',
#   'webber',
#   'my',
#   'dad',
#   'likes',
#   'your',
#   'glasses',
#   'dc'],
#  ['sometimes',
#   'you',
#   'got',
#   'ta',
#   'do',
#   'stuff',
#   'you',
#   'really',
#   'dont',
#   'wan',
#   'na',
#   'do'],
#  ['sounds', 'good', 'bro'],
#  ['im', 'digging', 'the', 'offspring', 'right', 'now'],
#  ['thanks', 'for', 'the', 'rt'],
#  ['enjoy',
#   'this',
#   'sunny',
#   'day',
#   'with',
#   'a',
#   'smile',
#   'on',
#   'your',
#   'face',
#   'and',
#   'your',
#   'head',
#   'held',
#   'high',
#   'cuz',
#   'u',
#   'never',
#   'know',
#   'when',
#   'the',
#   'dark',
#   'clouds',
#   'will',
#   'roll',
#   'in'],
#  ['because',
#   'why',
#   'doesnt',
#   'look',
#   'like',
#   'a',
#   'keg',
#   'guess',
#   'it',
#   'usually',
#   'smells',
#   'like',
#   'one',
#   'i',
#   'guess'],
#  ['no',
#   'worries',
#   'we',
#   'hope',
#   'you',
#   'find',
#   'ours',
#   'interesting',
#   'and',
#   'helpful',
#   'as',
#   'well'],
#  ['spammers',
#   'id',
#   'like',
#   'to',
#   'see',
#   'the',
#   'statistic',
#   'on',
#   'what',
#   'spammers',
#   'cost',
#   'american',
#   'small',
#   'businesses',
#   'in',
#   'a',
#   'dollar',
#   'amount',
#   'they',
#   'cost',
#   'me',
#   'so',
#   'much'],
#  ['cory', 'booker', 'is', 'on', 'my', 'tv'],
#  ['if',
#   'the',
#   'pencil',
#   'is',
#   'so',
#   'popular',
#   'then',
#   'why',
#   'is',
#   'it',
#   'number'],
#  ['plz',
#   'go',
#   'follow',
#   'she',
#   'follow',
#   'back',
#   'd',
#   'and',
#   'i',
#   'will',
#   'follow',
#   'you',
#   'too',
#   'd'],
#  ['chasing',
#   'the',
#   'sun',
#   'is',
#   'honestly',
#   'a',
#   'very',
#   'very',
#   'amazing',
#   'song',
#   'its',
#   'so',
#   'addicting',
#   'lol'],
#  ['brandon', 'dont', 'joke', 'like', 'that'],
#  ['rt',
#   'drake',
#   'be',
#   'sounding',
#   'like',
#   'he',
#   'be',
#   'crying',
#   'his',
#   'ass',
#   'off',
#   'when',
#   'he',
#   'be',
#   'singing',
#   'sometimes',
#   'lol',
#   'hell',
#   'yeah'],
#  ['motivation',
#   'and',
#   'inspiration',
#   'energize',
#   'people',
#   'not',
#   'by',
#   'pushing',
#   'them',
#   'in',
#   'the',
#   'right',
#   'direction',
#   'as',
#   'control',
#   'mechanisms',
#   'do',
#   'but',
#   'by',
#   'satisfying',
#   'basic'],
#  ['i',
#   'thought',
#   'you',
#   'were',
#   'strictly',
#   'infrastructure',
#   'bro',
#   'you',
#   'doing',
#   'sharepoint',
#   'dev',
#   'roles',
#   'too',
#   'now'],
#  ['no',
#   'i',
#   'had',
#   'the',
#   'kids',
#   'the',
#   'ex',
#   'kinda',
#   'dropped',
#   'them',
#   'on',
#   'me'],
#  ['playing', 'with', 'fire', 'again'],
#  ['ads',
#   'when',
#   'creatives',
#   'and',
#   'noncreatives',
#   'unite',
#   'is',
#   'march',
#   'th',
#   'stay',
#   'tuned',
#   'in',
#   'to',
#   'twitter',
#   'and',
#   'your',
#   'email',
#   'for',
#   'more',
#   'information'],
#  ['awesome',
#   'although',
#   'a',
#   'little',
#   'jealous',
#   'bout',
#   'the',
#   'jordans',
#   'haha'],
#  ['join',
#   'the',
#   'club',
#   'that',
#   'plays',
#   'unfollowfriday',
#   'every',
#   'week',
#   'it',
#   'relieves',
#   'stress'],
#  ['you',
#   'said',
#   'that',
#   'u',
#   'cant',
#   'say',
#   'boys',
#   'like',
#   'my',
#   'headyet',
#   'i',
#   'have',
#   'a',
#   'bfso',
#   'obviously',
#   'he',
#   'likes',
#   'my',
#   'head'],
#  ['do',
#   'you',
#   'need',
#   'a',
#   'custom',
#   'welcome',
#   'gate',
#   'for',
#   'your',
#   'business',
#   'page',
#   'we',
#   'can',
#   'do',
#   'it',
#   'need',
#   'social',
#   'media',
#   'management',
#   'we',
#   'can',
#   'handle',
#   'that',
#   'for',
#   'you',
#   'too'],
#  ['or', 'moons', 'over', 'my', 'hammy', 'lol', 'm'],
#  ['missing',
#   'a',
#   'very',
#   'important',
#   'page',
#   'from',
#   'my',
#   'booking',
#   'notebookthis',
#   'isnt',
#   'good'],
#  ['gets',
#   'a',
#   'standing',
#   'ovation',
#   'on',
#   'leno',
#   'freedom',
#   'is',
#   'catching'],
#  ['sorry',
#   'for',
#   'the',
#   'technical',
#   'difficulties',
#   'tonight',
#   'guys',
#   'one',
#   'day',
#   'soon',
#   'well',
#   'have',
#   'proper',
#   'working',
#   'equipment'],
#  ['it',
#   'should',
#   'keep',
#   'that',
#   'same',
#   'letter',
#   'everytime',
#   'u',
#   'plug',
#   'it',
#   'in'],
#  ['my',
#   'facebook',
#   'doesnt',
#   'look',
#   'any',
#   'different',
#   'can',
#   'i',
#   'say',
#   'facebook',
#   'on',
#   'twitter'],
#  ['the',
#   'thing',
#   'i',
#   'wish',
#   'i',
#   'could',
#   'say',
#   'to',
#   'you',
#   'but',
#   'knowing',
#   'i',
#   'wont'],
#  ['is', 'doing', 'some', 'work', 'check', 'them', 'out'],
#  ['got', 'the', 'th', 'pickteam', 'leaguesomebody', 'help', 'me'],
#  ['you', 'never', 'know'],
#  ['that', 'song', 'still', 'gives', 'me', 'chills'],
#  ['aight', 'heat', 'nation', 'victory', 'nite', 'nite', 'lets', 'go', 'heat'],
#  ['i', 'love', 'talking', 'to', 'this', 'kidd'],
#  ['thin',
#   'air',
#   'will',
#   'help',
#   'so',
#   'the',
#   'offense',
#   'wont',
#   'have',
#   'to',
#   'drive',
#   'as',
#   'far'],
#  ['whoa', 'whoa', 'koalas', 'get', 'chlamydia'],
#  ['rip',
#   'to',
#   'the',
#   'day',
#   'when',
#   'titanic',
#   'sent',
#   'more',
#   'than',
#   'people',
#   'to',
#   'a',
#   'watery',
#   'grave'],
#  ['lakers',
#   'would',
#   'do',
#   'well',
#   'to',
#   'keep',
#   'drawing',
#   'fouls',
#   'on',
#   'the',
#   'thunder',
#   'bigs'],
#  ['is',
#   'there',
#   'a',
#   'worse',
#   'place',
#   'to',
#   'get',
#   'drafted',
#   'than',
#   'cleveland'],
#  ['can',
#   'somebody',
#   'make',
#   'me',
#   'a',
#   'spaghetti',
#   'diagram',
#   'showing',
#   'the',
#   'connections',
#   'among',
#   'all',
#   'of',
#   'these',
#   'data',
#   'citation',
#   'programs',
#   'overwhelming'],
#  ['well',
#   'were',
#   'getting',
#   'close',
#   'to',
#   'completing',
#   'the',
#   'albumsee',
#   'the',
#   'journey'],
#  ['going', 'to', 'bed', 'night'],
#  ['just',
#   'finished',
#   'one',
#   'thousand',
#   'giftswhat',
#   'a',
#   'read',
#   'just',
#   'ordered',
#   'newhate',
#   'waiting'],
#  ['i',
#   'just',
#   'love',
#   'when',
#   'my',
#   'mother',
#   'forgets',
#   'to',
#   'pay',
#   'my',
#   'phone',
#   'bill',
#   'sure',
#   'hope',
#   'i',
#   'dont',
#   'have',
#   'a',
#   'wreck',
#   'on',
#   'the',
#   'way',
#   'home',
#   'and',
#   'have',
#   'to',
#   'call'],
#  ['i',
#   'just',
#   'swabbed',
#   'for',
#   'janet',
#   'liang',
#   'tonight',
#   'and',
#   'im',
#   'actually',
#   'home',
#   'tonight',
#   'to',
#   'listen'],
#  ['josh',
#   'hamilton',
#   'cracks',
#   'on',
#   'cj',
#   'for',
#   'home',
#   'runs',
#   'on',
#   'the',
#   'season',
#   'dude',
#   'is',
#   'in',
#   'a',
#   'zone'],
#  ['does',
#   'anyone',
#   'get',
#   'blown',
#   'out',
#   'on',
#   'the',
#   'road',
#   'more',
#   'often',
#   'than',
#   'the',
#   'lakers'],
#  ['girls',
#   'over',
#   'should',
#   'stick',
#   'to',
#   'sweats',
#   'and',
#   'bags',
#   'over',
#   'their',
#   'heads'],
#  ['is',
#   'your',
#   'last',
#   'name',
#   'trump',
#   'mine',
#   'got',
#   'for',
#   'the',
#   'first',
#   'for',
#   'each',
#   'thereafter'],
#  ['haha', 'its', 'the', 'culture', 'b', 'haha'],
#  ['la',
#   'mujer',
#   'de',
#   'ivan',
#   'pm',
#   'screened',
#   'as',
#   'part',
#   'of',
#   'the',
#   'new',
#   'chilean',
#   'directors',
#   'showcase'],
#  ['haha',
#   'your',
#   'full',
#   'of',
#   'it',
#   'its',
#   'a',
#   'gray',
#   'day',
#   'and',
#   'im',
#   'stressed',
#   'but',
#   'doing',
#   'ok',
#   'ha'],
#  ['well',
#   'there',
#   'might',
#   'not',
#   'be',
#   'any',
#   'crying',
#   'in',
#   'baseball',
#   'but',
#   'there',
#   'is',
#   'a',
#   'great',
#   'deal',
#   'of',
#   'it',
#   'in',
#   'skiing'],
#  ['i',
#   'would',
#   'love',
#   'to',
#   'connect',
#   'sometime',
#   'where',
#   'are',
#   'you',
#   'located'],
#  ['yessir', 'you', 'are', 'correct'],
#  ['i',
#   'want',
#   'steak',
#   'and',
#   'crab',
#   'so',
#   'bad',
#   'right',
#   'now',
#   'im',
#   'thinking',
#   'a',
#   'late',
#   'night',
#   'grilling',
#   'session',
#   'later'],
#  ['you',
#   'will',
#   'absolutely',
#   'love',
#   'it',
#   'after',
#   'the',
#   'first',
#   'pages',
#   'so',
#   'suck',
#   'it',
#   'up',
#   'and',
#   'get',
#   'that',
#   'far',
#   'it',
#   'turns',
#   'on',
#   'a',
#   'dime'],
#  ['you',
#   'know',
#   'football',
#   'isnt',
#   'nearly',
#   'as',
#   'fun',
#   'to',
#   'watch',
#   'when',
#   'beer',
#   'isnt',
#   'involved'],
#  ['being', 'abused'],
#  ['i',
#   'found',
#   'toure',
#   'neblett',
#   'much',
#   'less',
#   'of',
#   'a',
#   'jerk',
#   'than',
#   'one',
#   'name',
#   'toure',
#   'the',
#   'delusional',
#   'ego',
#   'maniac',
#   'with',
#   'an',
#   'opinion',
#   'on',
#   'everything'],
#  ['anyone',
#   'out',
#   'there',
#   'looking',
#   'to',
#   'buy',
#   'hunting',
#   'land',
#   'in',
#   'northern',
#   'central',
#   'wisconsin',
#   'this',
#   'fall'],
#  ['omg',
#   'mediatemple',
#   'namesevers',
#   'are',
#   'down',
#   'somebodys',
#   'going',
#   'to',
#   'be',
#   'in',
#   'trouble'],
#  ['mathematics',
#   'is',
#   'made',
#   'of',
#   'percent',
#   'formulas',
#   'percent',
#   'proofs',
#   'and',
#   'percent',
#   'imagination',
#   'and',
#   'mathematicians',
#   'prove',
#   'this',
#   'all',
#   'the',
#   'time'],
#  ['can', 'i', 'set', 'up', 'an', 'interview', 'with', 'you', 'guys'],
#  ['wow', 'i', 'have', 'snake', 'bites', 'again'],
#  ['phillip',
#   'humber',
#   'threw',
#   'a',
#   'perfect',
#   'game',
#   'will',
#   'never',
#   'stop',
#   'talking',
#   'about',
#   'it',
#   'haha'],
#  ['happy', 'casimir', 'pulaski', 'day', 'only', 'in', 'illinois'],
#  ['guys', 'make', 'me', 'upset'],
#  ['is', 'everyone', 'getting', 'along'],
#  ['so',
#   'its',
#   'worth',
#   'watching',
#   'so',
#   'afraid',
#   'to',
#   'commit',
#   'to',
#   'another',
#   'show'],
#  ['yes',
#   'you',
#   'should',
#   'be',
#   'mean',
#   'to',
#   'the',
#   'foster',
#   'dog',
#   'so',
#   'he',
#   'doesnt',
#   'like',
#   'you',
#   'thats',
#   'the',
#   'ticket'],
#  ['aw', 'okay'],
#  ['i', 'want', 'to', 'get', 'followers', 'already', 'follow', 'me'],
#  ['i',
#   'guess',
#   'they',
#   'think',
#   'they',
#   'doin',
#   'somethin',
#   'by',
#   'changing',
#   'my',
#   'fb',
#   'password',
#   'nd',
#   'im',
#   'the',
#   'lil',
#   'kid',
#   'lmaooo'],
#  ['id',
#   'like',
#   'to',
#   'know',
#   'how',
#   'much',
#   'household',
#   'help',
#   'had',
#   'when',
#   'the',
#   'boys',
#   'were',
#   'infants',
#   'in',
#   'school'],
#  ['iv',
#   'never',
#   'felt',
#   'this',
#   'for',
#   'any',
#   'guy',
#   'u',
#   'must',
#   'be',
#   'special',
#   'its',
#   'a',
#   'thing',
#   'called',
#   'true',
#   'love'],
#  ['i',
#   'didnt',
#   'say',
#   'it',
#   'wasnt',
#   'a',
#   'good',
#   'question',
#   'i',
#   'said',
#   'its',
#   'not',
#   'a',
#   'good',
#   'question',
#   'on',
#   'mothers',
#   'day'],
#  ['surrendering',
#   'isnt',
#   'just',
#   'about',
#   'letting',
#   'goits',
#   'about',
#   'letting',
#   'god',
#   'i',
#   'surrender',
#   'all'],
#  ['rooney',
#   'rule',
#   'you',
#   'should',
#   'start',
#   'eating',
#   'right',
#   'getting',
#   'sleep',
#   'and',
#   'exercising',
#   'soon',
#   'because',
#   'soon',
#   'it',
#   'will',
#   'be',
#   'too',
#   'late'],
#  ['richard',
#   'welsh',
#   'is',
#   'steves',
#   'dad',
#   'he',
#   'is',
#   'hoping',
#   'teamsoaringhigh',
#   'from',
#   'colorado',
#   'where',
#   'the',
#   'welsh',
#   'family',
#   'lived',
#   'a',
#   'country',
#   'road',
#   'or',
#   'from',
#   'each',
#   'other'],
#  ['g',
#   'certified',
#   'wet',
#   'tshirt',
#   'contest',
#   'friday',
#   'club',
#   'drama',
#   'want',
#   'to',
#   'get',
#   'in',
#   'for',
#   'free',
#   'txt',
#   'me',
#   'i',
#   'will',
#   'tell',
#   'you',
#   'how'],
#  ['startingnow',
#   'i',
#   'want',
#   'all',
#   'those',
#   'girls',
# ...
#  ['the', 'best', 'wwe', 'superstar', 'of', 'all', 'time'],
#  ['get', 'it', 'gurlll'],
#  ['haha',
#   'he',
#   'is',
#   'really',
#   'adapting',
#   'the',
#   'american',
#   'way',
#   'liam',
#   'stick',
#   'with',
#   'the',
#   'british',
#   'keep',
#   'it',
#   'that',
#   'way'],
#  ['yeah', 'jersey', 'shore', 'yeahyes', 'that', 'is', 'tweetworthy'],
#  ['att',
#   'all',
#   'dbhh',
#   'followers',
#   'make',
#   'sure',
#   'to',
#   'follow',
#   'americanalienep',
#   'dropping',
#   'soon'],
#  ['im',
#   'just',
#   'tired',
#   'of',
#   'us',
#   'stupid',
#   'poor',
#   'folk',
#   'that',
#   'would',
#   'be',
#   'you',
#   'the',
#   'gop',
#   'continuously',
#   'voting',
#   'for',
#   'these',
#   'cronies'],
#  ['sup', 'im', 'fuckin', 'dying', 'here', 'outta', 'boredom'],
#  ['act',
#   'like',
#   'a',
#   'gentleman',
#   'and',
#   'youll',
#   'attract',
#   'a',
#   'lady',
#   'act',
#   'like',
#   'douchebag',
#   'and',
#   'youll',
#   'attract',
#   'nobody'],
#  ['happy',
#   'national',
#   'pretzel',
#   'day',
#   'what',
#   'is',
#   'your',
#   'favorite',
#   'kind',
#   'of',
#   'pretzel'],
#  ['i', 'owe', 'my', 'followers', 'some', 'twitpics'],
#  ['biebet', 'wtf', 'what', 'would', 'usher', 'say'],
#  ['sore', 'tired', 'going', 'to', 'sleep', 'd'],
#  ['pictures', 'and', 'counting'],
#  ['thanks', 'heavenly', 'father', 'to', 'see', 'another', 'day'],
#  ['we',
#   'hear',
#   'the',
#   'game',
#   'vs',
#   'the',
#   'red',
#   'sox',
#   'wil',
#   'be',
#   'innings',
#   'this',
#   'year',
#   'and',
#   'not',
#   'thats',
#   'what',
#   'bobby',
#   'v',
#   'is',
#   'saying',
#   'too'],
#  ['just',
#   'heard',
#   'about',
#   'a',
#   'vegan',
#   'restaurant',
#   'in',
#   'charlotte',
#   'dairy',
#   'and',
#   'egg',
#   'free',
#   'kitchen',
#   'with',
#   'a',
#   'food',
#   'allergy',
#   'conscious',
#   'staff',
#   'dont',
#   'mind',
#   'if',
#   'i',
#   'do'],
#  ['good',
#   'morning',
#   'if',
#   'you',
#   'could',
#   'as',
#   'god',
#   'one',
#   'question',
#   'what',
#   'would',
#   'it',
#   'be',
#   'ask',
#   'yourself',
#   'today',
#   'then',
#   'ask',
#   'yourself',
#   'what',
#   'is',
#   'god',
#   'asking',
#   'me',
#   'today'],
#  ['im',
#   'trying',
#   'to',
#   'get',
#   'off',
#   'early',
#   'todaywhat',
#   'time',
#   'do',
#   'u',
#   'get',
#   'off',
#   'work'],
#  ['i',
#   'hate',
#   'parting',
#   'ways',
#   'with',
#   'my',
#   'blankie',
#   'in',
#   'the',
#   'morning'],
#  ['the', 'downfall', 'of', 'us', 'all', 'adaytoremember'],
#  ['sunburn',
#   'myths',
#   'stripped',
#   'bare',
#   'darker',
#   'skin',
#   'doesnt',
#   'fry',
#   'so',
#   'feel',
#   'free',
#   'to',
#   'bag',
#   'on',
#   'the',
#   'sunscreen',
#   'not',
#   'so',
#   'fast'],
#  ['who',
#   'doesnt',
#   'want',
#   'to',
#   'get',
#   'to',
#   'the',
#   'juicy',
#   'bits',
#   'and',
#   'all',
#   'that',
#   'bondage',
#   'and',
#   'sex',
#   'dont',
#   'we',
#   'all',
#   'wish',
#   'we',
#   'were',
#   'anastasia'],
#  ['making',
#   'it',
#   'difficult',
#   'for',
#   'me',
#   'to',
#   'deal',
#   'with',
#   'you',
#   'makes',
#   'it',
#   'easier',
#   'for',
#   'me',
#   'not',
#   'to',
#   'want',
#   'to'],
#  ['really',
#   'inspired',
#   'by',
#   'the',
#   'booksreading',
#   'k',
#   'now',
#   'heading',
#   'to',
#   'everest',
#   'bc',
#   'in',
#   'april',
#   'any',
#   'chance',
#   'you',
#   'will',
#   'be',
#   'up',
#   'there',
#   'eric'],
#  ['sony',
#   'ceo',
#   'rolf',
#   'schmidtholtz',
#   'said',
#   'today',
#   'that',
#   'pursuit',
#   'of',
#   'the',
#   'uks',
#   'emi',
#   'the',
#   'label',
#   'owning',
#   'the',
#   'music',
#   'of',
#   'the',
#   'beatles',
#   'was',
#   'not',
#   'out',
#   'of',
#   'the',
#   'question'],
#  ['nice',
#   'outfit',
#   'batman',
#   'wheres',
#   'the',
#   'rubber',
#   'suit',
#   'to',
#   'accentuate',
#   'your',
#   'chest',
#   'like',
#   'the',
#   'movie',
#   'haha'],
#  ['idkk',
#   'about',
#   'hving',
#   'his',
#   'restroom',
#   'party',
#   'lmao',
#   'i',
#   'would',
#   'let',
#   'you',
#   'in',
#   'but',
#   'they',
#   'are',
#   'standing',
#   'room',
#   'only',
#   'events'],
#  ['watch',
#   'greatdaysa',
#   'today',
#   'and',
#   'see',
#   'what',
#   'makes',
#   'a',
#   'year',
#   'old',
#   'ride',
#   'his',
#   'bike',
#   'miles',
#   'across',
#   'continents',
#   'to',
#   'break',
#   'world',
#   'records'],
#  ['just', 'a', 'little', 'love', 'tap'],
#  ['say',
#   'it',
#   'isnt',
#   'so',
#   'a',
#   'break',
#   'from',
#   'twitter',
#   'welcome',
#   'back'],
#  ['enjoyed', 'my', 'evening'],
#  ['thanks',
#   'colin',
#   'stoked',
#   'for',
#   'the',
#   'fight',
#   'tonight',
#   'who',
#   'do',
#   'you',
#   'have'],
#  ['has',
#   'recommended',
#   'that',
#   'someone',
#   'move',
#   'to',
#   'vienna',
#   'virginia',
#   'what',
#   'has',
#   'come',
#   'over',
#   'himtest',
#   'ifttt'],
#  ['taught',
#   'vizrhet',
#   'which',
#   'do',
#   'u',
#   'prefer',
#   'and',
#   'y',
#   'picturing',
#   'texts',
#   'or',
#   'reading',
#   'images',
#   'ive',
#   'used',
#   'ri',
#   'but',
#   'tough',
#   'undergrads'],
#  ['i',
#   'tired',
#   'to',
#   'help',
#   'you',
#   'out',
#   'and',
#   'commented',
#   'on',
#   'it',
#   'lol'],
#  ['dealing',
#   'with',
#   'fms',
#   'but',
#   'loving',
#   'this',
#   'spring',
#   'weather',
#   'it',
#   'puts',
#   'the',
#   'spring',
#   'back',
#   'to',
#   'my',
#   'step',
#   'smile',
#   'on',
#   'my',
#   'face',
#   'hope',
#   'youre',
#   'doing',
#   'well'],
#  ['does',
#   'any',
#   'one',
#   'please',
#   'help',
#   'my',
#   'friend',
#   'frank',
#   'he',
#   'needs',
#   'gay',
#   'people',
#   'in',
#   'his',
#   'msn',
#   'thanks'],
#  ['so', 'funny'],
#  ['sucker',
#   'punch',
#   'cost',
#   'm',
#   'to',
#   'make',
#   'grossed',
#   'm',
#   'last',
#   'weekend',
#   'diary',
#   'of',
#   'wimpy',
#   'kid',
#   'cost',
#   'm',
#   'to',
#   'make',
#   'grossed',
#   'm',
#   'last',
#   'weekend',
#   'go',
#   'wimpy'],
#  ['awesome', 'thanks', 'i', 'would', 'love', 'more', 'infomation'],
#  ['what',
#   'a',
#   'shame',
#   'we',
#   'all',
#   'became',
#   'such',
#   'fragile',
#   'broken',
#   'things'],
#  ['that', 'makes', 'a', 'ton', 'of', 'sense'],
#  ['cautionary',
#   'tale',
#   'she',
#   'went',
#   'to',
#   'central',
#   'america',
#   'for',
#   'mos',
#   'w',
#   'tons',
#   'of',
#   'books',
#   'on',
#   'her',
#   'kindle',
#   'kindle',
#   'not',
#   'working'],
#  ['how', 'is', 'that', 'possible', 'lol'],
#  ['srsly',
#   'tho',
#   'i',
#   'die',
#   'every',
#   'single',
#   'time',
#   'i',
#   'watch',
#   'this',
#   'show'],
#  ['i', 'have', 'a', 'flat', 'tire', 'on', 'my', 'scooter'],
#  ['knowledge',
#   'is',
#   'power',
#   'and',
#   'power',
#   'corrupts',
#   'so',
#   'study',
#   'hard',
#   'and',
#   'be',
#   'evil'],
#  ['high',
#   'fuel',
#   'costs',
#   'having',
#   'consumers',
#   'looking',
#   'to',
#   'buy',
#   'more',
#   'fuel',
#   'efficient',
#   'vehicles',
#   'marketwatch',
#   'press',
#   'release'],
#  ['rumors',
#   'abounding',
#   'that',
#   'daniel',
#   'daylewis',
#   'is',
#   'going',
#   'to',
#   'play',
#   'general',
#   'zodhopefully',
#   'its',
#   'true'],
#  ['this',
#   'you',
#   'can',
#   'dream',
#   'about',
#   'it',
#   'or',
#   'you',
#   'can',
#   'go',
#   'out',
#   'and',
#   'make',
#   'it',
#   'happen'],
#  ['getting',
#   'new',
#   'music',
#   'for',
#   'this',
#   'weekend',
#   'pow',
#   'then',
#   'out',
#   'to',
#   'have',
#   'a',
#   'few',
#   'dranks'],
#  ['send', 'me', 'a', 'hard', 'drive', 'ill', 'hook', 'you', 'up'],
#  ['can',
#   'you',
#   'please',
#   'followmecody',
#   'for',
#   'it',
#   'would',
#   'make',
#   'her',
#   'day'],
#  ['lol',
#   'the',
#   'people',
#   'i',
#   'know',
#   'are',
#   'all',
#   'good',
#   'looking',
#   'my',
#   'brother',
#   'in',
#   'law',
#   'being',
#   'one',
#   'of',
#   'them'],
#  ['fall',
#   'out',
#   'boy',
#   'playing',
#   'at',
#   'work',
#   'shit',
#   'just',
#   'got',
#   'angsty'],
#  ['its', 'a', 'beautiful', 'day'],
#  ['mls',
#   'is',
#   'a',
#   'joke',
#   'premier',
#   'league',
#   'is',
#   'where',
#   'its',
#   'at',
#   'and',
#   'real',
#   'madrid',
#   'will',
#   'do',
#   'ok',
#   'but',
#   'wont',
#   'be',
#   'the',
#   'same',
#   'without',
#   'ronaldo'],
#  ['midpenn', 'on', 'midpenn'],
#  ['missing',
#   'the',
#   'minnesota',
#   'twins',
#   'this',
#   'week',
#   'weve',
#   'got',
#   'the',
#   'perfect',
#   'solution',
#   'for',
#   'you',
#   'grab',
#   'twins',
#   'tickets',
#   'for',
#   'mondays',
#   'game',
#   'against',
#   'the',
#   'red',
#   'sox'],
#  ['due',
#   'to',
#   'an',
#   'officer',
#   'involved',
#   'shooting',
#   'at',
#   'the',
#   'san',
#   'ysidro',
#   'port',
#   'of',
#   'entry',
#   'northbound',
#   'ped',
#   'crossing',
#   'is',
#   'temporarily',
#   'suspended'],
#  ['its',
#   'a',
#   'beautiful',
#   'day',
#   'the',
#   'sidewalk',
#   'sale',
#   'is',
#   'up',
#   'great',
#   'savings',
#   'of',
#   'on',
#   'an',
#   'amazing',
#   'selection',
#   'of',
#   'books',
#   'holiday',
#   'cards',
#   'napkins'],
#  ['week',
#   'technique',
#   'class',
#   'begins',
#   'july',
#   'th',
#   'tuesday',
#   'evenings',
#   'pm',
#   'actors',
#   'intensive',
#   'studio',
#   'in',
#   'los',
#   'angeles',
#   'wwwactorsintensivecom'],
#  ['retweetthisif', 'if', 'you', 'hate', 'work'],
#  ['dont', 'be', 'a', 'pussy', 'eat', 'the', 'pussy'],
#  ['im', 'craving', 'chickfla', 'sauce', 'and', 'their', 'fries'],
#  ['she', 'chose', 'fire'],
#  ['digital', 'tools', 'that', 'make', 'shopping', 'easier'],
#  ['maybe',
#   'cuz',
#   'its',
#   'near',
#   'midnight',
#   'everybody',
#   'went',
#   'home',
#   'thats',
#   'why',
#   'things',
#   'are',
#   'sucky',
#   'lol',
#   'wow',
#   'is',
#   'it',
#   'really',
#   'that',
#   'late',
#   'i',
#   'have',
#   'an',
#   'assignment',
#   'due'],
#  ['but', 'i', 'just', 'ask'],
#  ['oh',
#   'we',
#   'out',
#   'here',
#   'for',
#   's',
#   'birthdaysee',
#   'you',
#   'soon',
#   'rt',
#   'now',
#   'on',
#   'to',
#   'shoot',
#   'for',
#   'who',
#   'needs',
#   'miami',
#   'btch'],
#  ['at',
#   'times',
#   'silence',
#   'can',
#   'connect',
#   'you',
#   'with',
#   'people',
#   'more',
#   'than',
#   'words',
#   'can'],
#  ['nfl', 'schedules', 'are', 'out', 'after', 'draft'],
#  ['i',
#   'just',
#   'saw',
#   'that',
#   'press',
#   'clip',
#   'of',
#   'mila',
#   'kunis',
#   'speaking',
#   'russian',
#   'why',
#   'is',
#   'the',
#   'thought',
#   'of',
#   'her',
#   'not',
#   'knowing',
#   'any',
#   'english',
#   'more',
#   'attractive',
#   'to',
#   'me'],
#  ['i',
#   'miss',
#   'i',
#   'would',
#   'retweet',
#   'her',
#   'tweet',
#   'but',
#   'it',
#   'doesnt',
#   'lem',
#   'me',
#   'c'],
#  ['mikey', 'can', 'you', 'say', 'happy', 'birthday', 'to'],
#  ['cinco', 'de', 'mayo', 'is', 'almost', 'here'],
#  ['rmd',
#   'just',
#   'said',
#   'im',
#   'the',
#   'cleanest',
#   'bum',
#   'hes',
#   'ever',
#   'seen',
#   'lol'],
#  ['well',
#   'shit',
#   'im',
#   'glad',
#   'i',
#   'didnt',
#   'jokes',
#   'on',
#   'you',
#   'mothafuckka',
#   'p'],
#  ['girl',
#   'ur',
#   'so',
#   'clean',
#   'without',
#   'a',
#   'scratch',
#   'does',
#   'it',
#   'make',
#   'your',
#   'heart',
#   'go',
#   'fast',
#   'when',
#   'these',
#   'wild',
#   'boys',
#   'put',
#   'in',
#   'work',
#   'im',
#   'a',
#   'live',
#   'wire',
#   'writhing',
#   'in',
#   'the',
#   'dirt'],
#  ['hey',
#   'gang',
#   'before',
#   'this',
#   'wraps',
#   'up',
#   'are',
#   'there',
#   'other',
#   'hr',
#   'related',
#   'tweet',
#   'chats',
#   'that',
#   'i',
#   'should',
#   'know',
#   'about',
#   'ones',
#   'you',
#   'could',
#   'recommend'],
#  ['just',
#   'at',
#   'a',
#   'larege',
#   'pizza',
#   'patron',
#   'pizzathe',
#   'latin',
#   'lifeenjoy'],
#  ['rt',
#   'liesgirlstellforattention',
#   'im',
#   'pregnant',
#   'and',
#   'justin',
#   'bieber',
#   'is',
#   'the',
#   'father',
#   'hahaha',
#   'best',
#   'one'],
#  ['so',
#   'sad',
#   'to',
#   'hear',
#   'of',
#   'passing',
#   'of',
#   'junior',
#   'seau',
#   'one',
#   'of',
#   'most',
#   'feared',
#   'linebackers',
#   'ever',
#   'thoughts',
#   'prayers',
#   'to',
#   'his',
#   'entire',
#   'fam'],
#  ['did',
#   'anyone',
#   'have',
#   'a',
#   'look',
#   'at',
#   'the',
#   'video',
#   'did',
#   'you',
#   'guys',
#   'like',
#   'it'],
#  ['if',
#   'you',
#   'get',
#   'upset',
#   'over',
#   'people',
#   'who',
#   'unfollow',
#   'you',
#   'maybe',
#   'you',
#   'should',
#   'take',
#   'every',
#   'unfollow',
#   'as',
#   'saving',
#   'a',
#   'life',
#   'from',
#   'the',
#   'stupidity',
#   'you',
#   'spew'],
#  ['dont', 'let', 'her'],
#  ['the',
#   'one',
#   'good',
#   'thing',
#   'about',
#   'isagenix',
#   'and',
#   'not',
#   'sleeping',
#   'at',
#   'night',
#   'is',
#   'that',
#   'i',
#   'was',
#   'able',
#   'to',
#   'work',
#   'nights',
#   'of',
#   'hour',
#   'shifts',
#   'straight'],
#  ['bitch', 'im', 'high', 'of', 'life'],
#  ['until', 'u', 'expand', 'the', 'photo'],
#  ['thanks', 'for', 'the', 'retweet'],
#  ['i',
#   'really',
#   'hate',
#   'my',
#   'life',
#   'right',
#   'now',
#   'i',
#   'swear',
#   'i',
#   'cant',
#   'truth',
#   'any',
#   'one',
#   'at',
#   'all',
#   'im',
#   'done',
#   'plus',
#   'my',
#   'phone',
#   'is',
#   'completly',
#   'destroyed',
#   'o',
#   'm',
#   'g'],
#  ['and', 'he', 'went', 'to', 'inglewood', 'in'],
#  ['what',
#   'do',
#   'you',
#   'call',
#   'a',
#   'grasshopper',
#   'with',
#   'no',
#   'legs',
#   'a',
#   'grasshover'],
#  ['edutweet',
#   'what',
#   'are',
#   'the',
#   'best',
#   'educational',
#   'uses',
#   'for',
#   'twitter',
#   'live',
#   'staff',
#   'dev',
#   'using',
#   'book',
#   'digital',
#   'tools',
#   'for',
#   'teaching'],
#  ['smiles',
#   'are',
#   'like',
#   'bandaids',
#   'they',
#   'cover',
#   'up',
#   'the',
#   'pain',
#   'but',
#   'it',
#   'still',
#   'hurts'],
#  ['the',
#   'wisdom',
#   'of',
#   'the',
#   'wise',
#   'and',
#   'the',
#   'experience',
#   'of',
#   'the',
#   'ages',
#   'are',
#   'perpetuated',
#   'by',
#   'quotations'],
#  ['i', 'know', 'this', 'great', 'bass', 'player'],
#  ['you',
#   'can',
#   'withstand',
#   'surgery',
#   'with',
#   'hypnosis',
#   'and',
#   'no',
#   'anesthesia'],
#  ['what',
#   'measuring',
#   'stick',
#   'do',
#   'you',
#   'use',
#   'to',
#   'gauge',
#   'the',
#   'success',
#   'of',
#   'your',
#   'projects',
#   'any',
#   'guidelines',
#   'or',
#   'standards',
#   'youve',
#   'found',
#   'useful'],
#  ['go', 'to', 'the', 'rio', 'hotel', 'on', 'the', 'beach'],
#  ['lmfao',
#   'you',
#   'outta',
#   'control',
#   'bestie',
#   'i',
#   'got',
#   'a',
#   'dinnermovie',
#   'date',
#   'for',
#   'friday',
#   'nite',
#   'you',
#   'know',
#   'ill',
#   'tell',
#   'u',
#   'all',
#   'about',
#   'it'],
#  ['hrs',
#   'until',
#   'this',
#   'weeks',
#   'grown',
#   'up',
#   'talk',
#   'radio',
#   'still',
#   'time',
#   'to',
#   'send',
#   'in',
#   'your',
#   'ideas',
#   'for',
#   'tonights',
#   'show'],
#  ['apparently',
#   'sleep',
#   'is',
#   'so',
#   'overrated',
#   'that',
#   'my',
#   'body',
#   'doesnt',
#   'think',
#   'i',
#   'need',
#   'to',
#   'bother',
#   'with',
#   'it'],
#  ['darn', 'i', 'took', 'uk', 'plus'],
#  ['talking', 'to', 'mommy'],
#  ['ok', 'not', 'doing', 'the', 'oscars', 'watching', 'anniehall', 'instead'],
#  ['wheninrva', 'is', 'so', 'three', 'days', 'ago'],
#  ['why',
#   'hello',
#   'longest',
#   'day',
#   'ever',
#   'id',
#   'like',
#   'to',
#   'be',
#   'done',
#   'with',
#   'you',
#   'now'],
#  ['thanks',
#   'madame',
#   'leader',
#   'you',
#   'illuminated',
#   'the',
#   'issues',
#   'we',
#   'need',
#   'your',
#   'voice',
#   'more',
#   'than',
#   'ever'],
#  ['no',
#   'derrick',
#   'rose',
#   'and',
#   'no',
#   'dwight',
#   'howardheat',
#   'eastern',
#   'conference',
#   'championship'],
#  ['greenwich',
#   'one',
#   'of',
#   'my',
#   'most',
#   'favorite',
#   'places',
#   'on',
#   'earth',
#   'i',
#   'love',
#   'walking',
#   'this',
#   'area',
#   'at',
#   'night',
#   'during',
#   'the',
#   'summer'],
#  ['about',
#   'to',
#   'be',
#   'live',
#   'on',
#   'livestream',
#   'interview',
#   'check',
#   'out',
#   'our',
#   'next',
#   'lt',
#   'gov'],
#  ['wow',
#   'full',
#   'house',
#   'theme',
#   'song',
#   'used',
#   'in',
#   'sarah',
#   'silverman',
#   'program'],
#  ['watch',
#   'twist',
#   'live',
#   'and',
#   'our',
#   'ceo',
#   'ask',
#   'for',
#   'advice',
#   'from',
#   'and'],
#  ['merriest',
#   'of',
#   'christmases',
#   'tweets',
#   'enjoy',
#   'every',
#   'minute',
#   'of',
#   'it'],
#  ['i',
#   'wonder',
#   'what',
#   'actually',
#   'thinks',
#   'about',
#   'all',
#   'the',
#   'trending',
#   'topics',
#   'about',
#   'them',
#   'shirtless',
#   'niall',
#   'replacedsongswithlouisass',
#   'seriously'],
#  ['direct', 'message'],
#  ['and',
#   'then',
#   'that',
#   'friend',
#   'comes',
#   'back',
#   'for',
#   'a',
#   'rematch',
#   'right'],
#  ['of',
#   'us',
#   'wholesalers',
#   'surveyed',
#   'are',
#   'more',
#   'optimistic',
#   'on',
#   'their',
#   'business',
#   'now',
#   'than',
#   'three',
#   'months',
#   'ago',
#   'highest',
#   'in',
#   'over',
#   'a',
#   'year',
#   'via',
#   'ubs',
#   'survey'],
#  ['alright',
#   'w',
#   'wager',
#   'i',
#   'dont',
#   'know',
#   'who',
#   'you',
#   'are',
#   'or',
#   'how',
#   'you',
#   'got',
#   'on',
#   'my',
#   'exam',
#   'list',
#   'but',
#   'i',
#   'will',
#   'take',
#   'your',
#   'advice',
#   'in',
#   'enough',
#   'is',
#   'as',
#   'good',
#   'as',
#   'a',
#   'feast'],
#  ['boo',
#   'i',
#   'accidentally',
#   'threw',
#   'away',
#   'my',
#   'list',
#   'of',
#   'story',
#   'ideas',
#   'for',
#   'next',
#   'semester'],
#  ['art',
#   'washes',
#   'from',
#   'the',
#   'soul',
#   'the',
#   'dust',
#   'of',
#   'everyday',
#   'life',
#   'pablo',
#   'picasso'],
#  ['as', 'of', 'right', 'now', 'at', 'this', 'sec', 'pass', 'me', 'by'],
#  ...]

# %%
## Obtain Train and Test Split
train, test = train_test_split(tokenized_sentences, test_size=0.2, random_state=42)

## Obtain Train and Validation Split
train, val = train_test_split(train, test_size=0.25, random_state=42)

# %%
def count_the_words(sentences) -> 'dict':

  # Creating a Dictionary of counts
  word_counts = {}

  # Iterating over sentences
  for sentence in sentences:

    # Iterating over Tokens
    for token in sentence:

      # Add count for new word
      if token not in word_counts.keys():
        word_counts[token] = 1

      # Increase count by one
      else:
        word_counts[token] += 1

  return word_counts

# %%
word_count = count_the_words(tokenized_sentences)
word_count
# Out:
# {'how': 74629,
#  'are': 158116,
#  'you': 543701,
#  'btw': 2810,
#  'thanks': 88664,
#  'for': 384535,
#  'the': 934172,
#  'rt': 88706,
#  'gon': 22562,
#  'na': 36245,
#  'be': 187177,
#  'in': 377037,
#  'dc': 4654,
#  'anytime': 1645,
#  'soon': 19331,
#  'love': 105589,
#  'to': 786630,
#  'see': 66510,
#  'been': 43742,
#  'way': 36582,
#  'too': 58355,
#  'long': 18886,
#  'when': 81787,
#  'meet': 10173,
#  'someone': 20383,
#  'special': 7189,
#  'youll': 6778,
#  'know': 79269,
#  'your': 170773,
#  'heart': 9211,
#  'will': 94282,
#  'beat': 5589,
#  'more': 62522,
#  'rapidly': 108,
#  'and': 433687,
#  'smile': 4487,
#  'no': 76416,
#  'reason': 5883,
#  'theyve': 923,
#  'decided': 2138,
#  'its': 120636,
#  'fun': 22755,
#  'if': 105462,
#  'i': 713693,
#  'dont': 90108,
#  'so': 163274,
#  'tired': 6643,
#  'd': 23874,
#  'played': 3957,
#  'lazer': 24,
#  'tag': 1440,
#  'ran': 1886,
#  'a': 608623,
#  'lot': 13436,
#  'ughh': 325,
#  'going': 55563,
#  'sleep': 12969,
#  'like': 121325,
#  'minutes': 6913,
#  'words': 6932,
#  'from': 83691,
#  'complete': 2454,
#  'stranger': 714,
#  'made': 18532,
#  'my': 290517,
#  'birthday': 16260,
#  'even': 25805,
#  'better': 30101,
#  'first': 31192,
#  'cubs': 912,
#  'game': 29905,
#  'ever': 24842,
#  'wrigley': 172,
#  'field': 2916,
#  'is': 357544,
#  'gorgeous': 2672,
#  'this': 162736,
#  'perfect': 7653,
#  'go': 71777,
#  'get': 111932,
#  'another': 16706,
#  'day': 90061,
#  'off': 35732,
#  'skool': 292,
#  'due': 3173,
#  'wonderful': 6173,
#  'snow': 3530,
#  'wakes': 186,
#  'me': 200959,
#  'updamn': 3,
#  'thing': 21352,
#  'im': 158565,
#  'coo': 212,
#  'jus': 1544,
#  'at': 185524,
#  'work': 41450,
#  'hella': 687,
#  'r': 9118,
#  'u': 76339,
#  'cali': 872,
#  'new': 69381,
#  'sundrop': 11,
#  'commercial': 2537,
#  'hehe': 1036,
#  'sight': 618,
#  'we': 132289,
#  'need': 50652,
#  'reconnect': 101,
#  'week': 28457,
#  'always': 29054,
#  'wonder': 6304,
#  'guys': 21029,
#  'on': 276264,
#  'auctions': 60,
#  'shows': 4786,
#  'learned': 2858,
#  'talk': 16017,
#  'fast': 4539,
#  'all': 120167,
#  'hear': 15189,
#  'djsosnekspqnslanskam': 1,
#  'dammnnnnn': 1,
#  'what': 110968,
#  'catch': 4683,
#  'such': 10569,
#  'great': 75382,
#  'picture': 4637,
#  'green': 4909,
#  'shirt': 3095,
#  'totally': 6391,
#  'brings': 1384,
#  'out': 114139,
#  'eyes': 4831,
#  'desk': 1380,
#  'put': 14173,
#  'together': 7738,
#  'room': 8042,
#  'set': 7354,
#  'up': 113003,
#  'oh': 32161,
#  'boy': 6824,
#  'doing': 21148,
#  'it': 291399,
#  'beauty': 2025,
#  'brainstorming': 160,
#  'alchemy': 38,
#  'office': 6275,
#  'with': 172995,
#  'sally': 195,
#  'walker': 927,
#  'looking': 25301,
#  'band': 4875,
#  'blog': 5306,
#  'month': 6599,
#  'anyone': 16019,
#  'interested': 4297,
#  'packing': 876,
#  'quick': 2951,
#  'move': 6592,
#  'down': 27527,
#  'street': 4615,
#  'only': 39272,
#  'had': 41981,
#  'some': 61568,
#  'movers': 118,
#  'ford': 626,
#  'focus': 2546,
#  'hatchback': 10,
#  'according': 1351,
#  'national': 4056,
#  'retail': 433,
#  'federation': 55,
#  'billion': 1001,
#  'was': 117028,
#  'spent': 2742,
#  'mothersday': 168,
#  'last': 37279,
#  'year': 26777,
#  'tragedy': 321,
#  'of': 358981,
#  'life': 33058,
#  'not': 126356,
#  'that': 232908,
#  'ends': 1699,
#  'but': 123890,
#  'wait': 26678,
#  'begin': 2282,
#  'wm': 104,
#  'lewis': 539,
#  'skating': 259,
#  'come': 40140,
#  'by': 58790,
#  'check': 20003,
#  'movie': 11020,
#  'eat': 8582,
#  'dinner': 7193,
#  'top': 7641,
#  'times': 9719,
#  'ice': 3913,
#  'rink': 91,
#  'watch': 16653,
#  'mailbox': 122,
#  'tommorows': 6,
#  'good': 99672,
#  'questions': 3879,
#  'brand': 2507,
#  'judged': 168,
#  'based': 2154,
#  'website': 5155,
#  'ambassador': 164,
#  'care': 9309,
#  'others': 5925,
#  'think': 53702,
#  'save': 4260,
#  'yourself': 8053,
#  'mental': 812,
#  'energy': 2933,
#  'instead': 4983,
#  'can': 92921,
#  'used': 8493,
#  'push': 1341,
#  'towards': 1070,
#  'success': 5083,
#  'ron': 1203,
#  'artest': 267,
#  'interview': 3672,
#  'possible': 3520,
#  'die': 4466,
#  'laughter': 444,
#  'linda': 258,
#  'just': 149619,
#  'looked': 3180,
#  'sched': 70,
#  'have': 168051,
#  'hustle': 443,
#  'back': 57380,
#  'chula': 72,
#  'pm': 18573,
#  'meetings': 1018,
#  'time': 74697,
#  'lunch': 7617,
#  'do': 105793,
#  'every': 19968,
#  'fri': 989,
#  'bum': 405,
#  'squad': 497,
#  'lets': 17858,
#  'shout': 4928,
#  'ninja': 502,
#  'winning': 3236,
#  'proud': 5618,
#  'sitting': 4059,
#  'those': 19958,
#  'stairs': 443,
#  'x': 5988,
#  'factor': 648,
#  'now': 81926,
#  'boys': 5612,
#  'inspiration': 1857,
#  'xx': 1339,
#  'maybe': 13964,
#  'other': 19467,
#  'cant': 54271,
#  'slow': 2866,
#  'right': 45533,
#  'across': 2606,
#  'state': 6725,
#  'line': 6735,
#  'about': 90952,
#  'exhaust': 48,
#  'leak': 177,
#  'arrrgh': 9,
#  'reading': 7498,
#  'magazine': 1402,
#  'cheers': 2024,
#  'tables': 521,
#  'sold': 2227,
#  'mystique': 19,
#  'masquerade': 41,
#  'ball': 3970,
#  'make': 47176,
#  'one': 81325,
#  'might': 12299,
#  'help': 20167,
#  'feel': 24450,
#  'alternative': 498,
#  'scream': 786,
#  'nonsense': 388,
#  'dumb': 2528,
#  'machine': 1469,
#  'ya': 13367,
#  'ik': 370,
#  'never': 33452,
#  'asked': 4023,
#  'him': 27447,
#  'follow': 47326,
#  'mentioned': 1019,
#  'once': 7981,
#  'tweets': 9242,
#  'didnt': 20849,
#  'anything': 11628,
#  'else': 10001,
#  'talking': 10364,
#  'tonight': 43863,
#  'forward': 13454,
#  'piece': 2778,
#  'next': 30907,
#  'jon': 717,
#  'small': 4792,
#  'market': 3517,
#  'baseball': 3336,
#  'knowfor': 2,
#  'sing': 2766,
#  'comes': 6360,
#  'tomorrow': 27984,
#  'seems': 5839,
#  'they': 68992,
#  'thought': 14654,
#  'idea': 8759,
#  'over': 31225,
#  'sunday': 8496,
#  'brunch': 1324,
#  'swell': 144,
#  'ff': 5566,
#  'awfully': 130,
#  'company': 4147,
#  'longer': 3099,
#  'live': 19569,
#  'find': 17304,
#  'persons': 480,
#  'oliver': 238,
#  'wendell': 75,
#  'holmes': 234,
#  'list': 6296,
#  'women': 6257,
#  'nice': 22131,
#  'watched': 3891,
#  'whole': 7793,
#  'series': 4659,
#  'loved': 6424,
#  'julia': 283,
#  'her': 33591,
#  'mom': 11125,
#  'erica': 183,
#  'badass': 646,
#  'gop': 1356,
#  'obama': 3803,
#  'gay': 3362,
#  'marriage': 1935,
#  'stance': 134,
#  'he': 55425,
#  'flipflopped': 13,
#  'really': 45254,
#  'want': 47869,
#  'use': 15793,
#  'romney': 1923,
#  'as': 70914,
#  'presidential': 402,
#  'candidate': 721,
#  'then': 31876,
#  'kick': 2870,
#  'fight': 4674,
#  'goes': 6878,
#  'lopsided': 19,
#  'upset': 1459,
#  'does': 19662,
#  'happen': 6248,
#  'wow': 12908,
#  'nothing': 13248,
#  'stress': 1293,
#  'balls': 1434,
#  'or': 68940,
#  'keg': 143,
#  'different': 5934,
#  'crew': 2349,
#  'these': 15907,
#  'party': 12984,
#  'william': 898,
#  'davis': 1151,
#  'attorney': 371,
#  'says': 10032,
#  'client': 1622,
#  'plead': 64,
#  'insanity': 389,
#  'faces': 1014,
#  'firstdegree': 6,
#  'murder': 754,
#  'charge': 1202,
#  'womans': 320,
#  'death': 3189,
#  'occupymadison': 6,
#  'ga': 727,
#  'considered': 905,
#  'myself': 9102,
#  'liberal': 366,
#  'until': 12148,
#  'saw': 12857,
#  'action': 2802,
#  'ugly': 2521,
#  'weird': 4964,
#  'got': 66662,
#  'witness': 397,
#  'change': 10627,
#  'millenia': 3,
#  'generations': 223,
#  'awayimagine': 1,
#  'differences': 248,
#  'chris': 3337,
#  'brown': 2866,
#  'wit': 4503,
#  'them': 38423,
#  'sexy': 3681,
#  'ass': 12223,
#  'lips': 819,
#  'sounds': 10424,
#  'unfortunate': 263,
#  'days': 18749,
#  'status': 1481,
#  'update': 2540,
#  'song': 12673,
#  'lyrics': 906,
#  'were': 43599,
#  'also': 16164,
#  'discovered': 944,
#  'wave': 701,
#  'bomb': 1098,
#  'chillin': 1058,
#  'friends': 18703,
#  'working': 15096,
#  'music': 19148,
#  'holiday': 3448,
#  'show': 30935,
#  'santa': 1406,
#  'barbara': 300,
#  'open': 11152,
#  'bar': 5152,
#  'tim': 1596,
#  'palin': 322,
#  'white': 6565,
#  'ts': 213,
#  'jr': 1270,
#  'richards': 141,
#  'dishwalla': 1,
#  'hey': 25550,
#  'nate': 401,
#  'dropping': 789,
#  'yesterday': 7540,
#  'meal': 1288,
#  'literary': 315,
#  'lights': 1731,
#  'who': 55078,
#  'brightened': 33,
#  'shape': 876,
#  'water': 5080,
#  'pavement': 70,
#  'weights': 226,
#  'zija': 3,
#  'wedding': 2627,
#  'months': 4437,
#  'away': 13465,
#  'report': 2324,
#  'many': 18834,
#  'things': 21118,
#  'positive': 2553,
#  'university': 1776,
#  'arkansas': 250,
#  'athletics': 149,
#  'program': 3464,
#  'athletescelebrities': 1,
#  'should': 36581,
#  'tool': 1344,
#  'per': 2088,
#  'request': 1241,
#  'support': 10454,
#  'foundationscharities': 1,
#  'fans': 8557,
#  'involved': 1535,
#  'enjoy': 10031,
#  'stay': 11833,
#  'cool': 16874,
#  'yo': 6288,
#  'chick': 1347,
#  'she': 29723,
#  'thirst': 148,
#  'aye': 872,
#  'theyre': 8110,
#  'saying': 7279,
#  'tho': 5210,
#  'except': 2274,
#  'lol': 66709,
#  'talks': 1368,
#  'third': 1737,
#  'person': 11818,
#  'control': 2654,
#  'reaction': 611,
#  'practice': 3299,
#  'allow': 1240,
#  'continue': 1841,
#  'big': 23706,
#  'wife': 3511,
#  'haha': 26606,
#  'very': 25283,
#  'cute': 6880,
#  'heard': 9146,
#  'julie': 382,
#  'whos': 5741,
#  'fb': 4066,
#  'tryin': 711,
#  'laugh': 3430,
#  'somedays': 49,
#  'youre': 38965,
#  'windshield': 130,
#  'wiper': 23,
#  'taking': 8095,
#  'adam': 1358,
#  'much': 44125,
#  'ben': 1336,
#  'hows': 2754,
#  'sarah': 1033,
#  'trying': 13599,
#  'explain': 1548,
#  'teacher': 2857,
#  'yolo': 796,
#  'lmfao': 2366,
#  'inspiring': 1177,
#  'minds': 1126,
#  'must': 12158,
#  'ready': 17221,
#  'take': 27914,
#  'opportunities': 1115,
#  'colton': 157,
#  'med': 337,
#  'schoolwow': 1,
#  'could': 26329,
#  'am': 47883,
#  'ocd': 90,
#  'around': 14846,
#  'blood': 1951,
#  'sick': 6203,
#  'people': 51496,
#  'periods': 147,
#  'sleeping': 2240,
#  'likely': 1686,
#  'being': 23462,
#  'dependent': 107,
#  'happiness': 2143,
#  'humidity': 220,
#  'well': 46182,
#  'needacinschool': 1,
#  'whats': 18653,
#  'creepily': 19,
#  'hate': 18315,
#  'cheesecake': 314,
#  'cake': 2827,
#  'cheese': 3072,
#  'front': 4039,
#  'walmart': 867,
#  'still': 37944,
#  'havent': 9923,
#  'seen': 8769,
#  'super': 7815,
#  'th': 19971,
#  'checkin': 362,
#  'wins': 2684,
#  'free': 20344,
#  'ticket': 2643,
#  'checkins': 44,
#  'far': 9477,
#  'congratulations': 3613,
#  'advancing': 72,
#  'stanleycup': 34,
#  'playoffs': 1922,
#  'defeated': 133,
#  'sens': 32,
#  'chaaaa': 1,
#  'ghost': 841,
#  'hunters': 162,
#  'makes': 14074,
#  'cry': 3257,
#  'ovw': 7,
#  'team': 14509,
#  'dominoski': 1,
#  'house': 13515,
#  'brew': 615,
#  'after': 23683,
#  'waking': 1418,
#  'therave': 1,
#  'night': 40341,
#  'though': 14116,
#  'six': 1513,
#  'flags': 289,
#  'tom': 2017,
#  'applauding': 21,
#  'because': 23032,
#  'button': 1516,
#  'mad': 5571,
#  'sucks': 4391,
#  'little': 18881,
#  'league': 2175,
#  'majors': 169,
#  'try': 14872,
#  'outs': 589,
#  'where': 26431,
#  'meatballs': 148,
#  'naomi': 72,
#  'cufon': 3,
#  'testing': 1093,
#  'implementation': 118,
#  'wordpress': 531,
#  'fouc': 1,
#  'dyall': 1,
#  'lo': 360,
#  'mejor': 9,
#  'experiencing': 289,
#  'through': 12633,
#  'an': 65950,
#  'excited': 15573,
#  'teen': 1165,
#  'b': 9037,
#  'word': 9613,
#  'call': 18980,
#  'girl': 17355,
#  'beautful': 12,
#  'colin': 204,
#  'butterfly': 197,
#  'zooming': 29,
#  'overused': 55,
#  'needs': 9306,
#  'done': 17363,
#  'tastefully': 6,
#  'point': 7418,
#  'firefox': 196,
#  'google': 4639,
#  'chrome': 417,
#  'type': 2947,
#  'let': 23480,
#  'into': 21670,
#  'today': 71233,
#  'hahahahhahah': 3,
#  'high': 9527,
#  'dry': 1233,
#  'walls': 579,
#  'amazing': 19322,
#  'important': 4519,
#  'our': 61798,
#  'hashtag': 1129,
#  'sntck': 1,
#  'please': 29778,
#  'tweet': 19447,
#  'specialneeds': 26,
#  'resources': 935,
#  'writings': 52,
#  'us': 50138,
#  'share': 5546,
#  'voted': 1139,
#  'twice': 1893,
#  'sagaftra': 97,
#  'merger': 117,
#  'yet': 13172,
#  'conference': 4581,
#  'rockin': 943,
#  'pretty': 16651,
#  'sure': 24867,
#  'broken': 2112,
#  'leg': 1237,
#  'keith': 455,
#  'smoking': 1045,
#  'dugout': 81,
#  'class': 11584,
#  'jerk': 616,
#  'grew': 754,
#  'mets': 542,
#  'fansorry': 1,
#  'admit': 1420,
#  'shes': 7625,
#  'calling': 3017,
#  'having': 14972,
#  'moment': 6739,
#  'reward': 518,
#  'getting': 25681,
#  'morning': 26000,
#  'accomplishment': 252,
#  'ups': 896,
#  'leaving': 2805,
#  'voicemails': 35,
#  'accurately': 65,
#  'transcribe': 24,
#  'everyone': 24920,
#  'say': 31853,
#  'prayer': 902,
#  'brother': 4187,
#  'his': 33924,
#  'kids': 10717,
#  'daughters': 545,
#  'cardinals': 429,
#  'jerseys': 310,
#  'why': 38148,
#  'actin': 121,
#  'eveningafternoonwhatever': 1,
#  'folks': 4025,
#  'experience': 4754,
#  'did': 39562,
#  'dogtooth': 5,
#  'ago': 6063,
#  'average': 1292,
#  'gossip': 364,
#  'complain': 968,
#  'exceptional': 140,
#  'create': 2836,
#  'inspire': 805,
#  'leadership': 1470,
#  'onethingyoushouldntdo': 8,
#  'spam': 1496,
#  'stalking': 349,
#  'buffalo': 842,
#  'appreciate': 5225,
#  'following': 13058,
#  'poised': 359,
#  'creation': 705,
#  'twitter': 29883,
#  'promise': 2168,
#  'ten': 1537,
#  'without': 10031,
#  'hanging': 2410,
#  'arm': 974,
#  'snap': 758,
#  'backs': 307,
#  'tattoos': 472,
#  'fallout': 68,
#  'original': 1828,
#  'actually': 11639,
#  'favorite': 12499,
#  'tv': 7611,
#  'giants': 1602,
#  'feeling': 8598,
#  'look': 24830,
#  'stupid': 5541,
#  'panda': 289,
#  'hat': 1440,
#  'jail': 853,
#  'puts': 983,
#  'woo': 1763,
#  'keep': 22246,
#  'talkingthy': 1,
#  'thy': 259,
#  'likei': 19,
#  'worry': 2937,
#  'cause': 9657,
#  'everythings': 293,
#  'goin': 2552,
#  'alrightno': 1,
#  'n': 10970,
#  'jesus': 3156,
#  'drawn': 237,
#  'dead': 4705,
#  'wynn': 60,
#  'giving': 5187,
#  'shirts': 1196,
#  'fact': 4328,
#  'added': 1759,
#  'extra': 3086,
#  'end': 11560,
#  'amplifies': 7,
#  'greatness': 467,
#  'oy': 198,
#  'vey': 45,
#  'hmm': 1491,
#  'hackeddo': 1,
#  'link': 4138,
#  'dm': 5465,
#  'sent': 4294,
#  'account': 4930,
#  'sorry': 14726,
#  'yikes': 725,
#  'break': 7560,
#  'butt': 1704,
#  'welcome': 12948,
#  'o': 7096,
#  'intrigued': 217,
#  'negotiations': 60,
#  'building': 3130,
#  'okc': 1084,
#  'lives': 2952,
#  'island': 1447,
#  'wan': 14323,
#  'shoot': 4055,
#  'least': 8620,
#  'sane': 176,
#  'players': 3097,
#  'tebowing': 53,
#  'before': 18649,
#  'sat': 3182,
#  'nfl': 2550,
#  'astroturf': 3,
#  'collegiate': 73,
#  'bowl': 2734,
#  'praying': 1207,
#  'zone': 1049,
#  'stite': 1,
#  'yes': 27791,
#  'hahahahaha': 516,
#  'lesson': 1305,
#  'almost': 8904,
#  'youu': 686,
#  'spy': 268,
#  'zeitgeist': 12,
#  'coffee': 7398,
#  'retweet': 3481,
#  'quiet': 1541,
#  'poo': 185,
#  'writing': 5557,
#  'wall': 2234,
#  'sarkozy': 47,
#  'sarkohnohedidntzy': 1,
#  'rnrchi': 1,
#  'bag': 2277,
#  'wondering': 2514,
#  'pay': 5346,
#  'run': 10446,
#  'mile': 1277,
#  'training': 3235,
#  'thats': 41321,
#  'lost': 7376,
#  'heat': 3800,
#  'marlins': 353,
#  'wish': 18133,
#  'attendance': 387,
#  'nelson': 399,
#  'tweetin': 207,
#  'while': 14352,
#  'walk': 5874,
#  'walkin': 183,
#  'soundtrack': 505,
#  'visiting': 1218,
#  'again': 22078,
#  'would': 51621,
#  'awesome': 24523,
#  'told': 7461,
#  'member': 1795,
#  'has': 46372,
#  'bigger': 1735,
#  'stick': 1838,
#  'late': 8262,
#  'walks': 733,
#  'religion': 624,
#  'thank': 39230,
#  'goodness': 1386,
#  'rhetorical': 90,
#  'question': 6517,
#  'phone': 11534,
#  'case': 4030,
#  'preferably': 171,
#  'sparkly': 92,
#  'everybody': 4424,
#  'laughing': 1812,
#  'part': 9953,
#  'said': 17963,
#  'p': 10247,
#  'bestfriend': 683,
#  'hit': 11471,
#  'something': 22192,
#  'old': 16162,
#  'boo': 2634,
#  'here': 36795,
#  'promoting': 480,
#  'friend': 12763,
#  'cobbler': 45,
#  'collaboration': 578,
#  'addresses': 144,
#  'complex': 578,
#  'problems': 2826,
#  'effectively': 207,
#  'there': 60325,
#  'perspectives': 130,
#  'roomgary': 1,
#  'mangiofico': 3,
#  'cinco': 1149,
#  'de': 2784,
#  'mayo': 1299,
#  'fiesta': 306,
#  'la': 8047,
#  'carreta': 3,
#  'packed': 1172,
#  'dallas': 2190,
#  'slapped': 203,
#  'red': 6876,
#  'cherries': 80,
#  'sunburn': 128,
#  'crying': 2031,
#  'aftr': 23,
#  'mins': 1436,
#  'kind': 8552,
#  'place': 11284,
#  'ladybugs': 17,
#  'lurv': 8,
#  'born': 2365,
#  'weeks': 6923,
#  'early': 9709,
#  'till': 5576,
#  'em': 4679,
#  'wanted': 6411,
#  'rework': 26,
#  'adele': 554,
#  'gets': 8303,
#  'standing': 1554,
#  'ovation': 153,
#  'moving': 4162,
#  'yeah': 21303,
#  'l': 1647,
#  'shut': 3223,
#  'fuck': 12074,
#  'intriguing': 201,
#  'any': 27050,
#  'clues': 105,
#  'browns': 766,
#  'draft': 2409,
#  'chauffeured': 6,
#  'range': 660,
#  'rover': 84,
#  'w': 18089,
#  'happy': 48545,
#  'derby': 911,
#  'pounds': 585,
#  'sweating': 214,
#  'sparring': 40,
#  'peace': 3163,
#  'toe': 466,
#  'hold': 4115,
#  'tumultuous': 7,
#  'world': 20548,
#  'reminder': 1197,
#  'play': 16719,
#  'den': 445,
#  'start': 17430,
#  'yall': 7758,
#  'taken': 2629,
#  'listen': 6120,
#  'hp': 267,
#  'md': 574,
#  'miaaa': 1,
#  'lax': 459,
#  'st': 12963,
#  'marys': 170,
#  'annapolis': 66,
#  'loyolablakefields': 1,
#  'leaves': 979,
#  'victory': 1060,
#  'fridaytheth': 33,
#  'best': 36037,
#  'everand': 4,
#  'todays': 4038,
#  'date': 4723,
#  'poor': 2812,
#  'relief': 507,
#  'somebody': 3342,
#  'okay': 8197,
#  'apparently': 2919,
#  'listening': 7688,
#  'broncos': 860,
#  'facility': 247,
#  'hour': 8617,
#  'hilarious': 2741,
#  'young': 5092,
#  'weirdest': 276,
#  'dreams': 4047,
#  'scrapbook': 34,
#  'hinged': 4,
#  'reattachment': 1,
#  'enclosures': 6,
#  'wheat': 292,
#  'paste': 152,
#  'japanese': 500,
#  'tissue': 143,
#  'nerd': 643,
#  'camp': 1642,
#  'girlfriends': 274,
#  'parents': 3738,
#  'cell': 1235,
#  'bill': 3196,
#  'ill': 32819,
#  'definitely': 7173,
#  'using': 6204,
#  'edmundson': 1,
#  'cady': 26,
#  'groves': 36,
#  'yourkoz': 1,
#  'gamesfind': 1,
#  'isshe': 6,
#  'concentrates': 16,
#  'calibre': 10,
#  'quality': 2107,
#  'education': 2599,
#  'jordanian': 2,
#  'children': 3191,
#  'global': 1162,
#  'biggest': 2736,
#  'tea': 2671,
#  'movement': 1081,
#  'filled': 1331,
#  'gap': 338,
#  ...}

# %%
def handling_oov(tokenized_sentences, count_threshold) -> 'list':

  # Empty list for closed vocabulary
  closed_vocabulary = []

  # Obtain frequency dictionary using previously defined function
  words_count = count_the_words(tokenized_sentences)

  # Iterate over words and counts
  for word, count in words_count.items():

    # Append if it's more(or equal) to the threshold
    if count >= count_threshold :
      closed_vocabulary.append(word)

  return closed_vocabulary

# %%
def unk_tokenize(tokenized_sentences, vocabulary, unknown_token = "<unk>") -> 'list':

  # Convert Vocabulary into a set
  vocabulary = set(vocabulary)

  # Create empty list for sentences
  new_tokenized_sentences = []

  # Iterate over sentences
  for sentence in tokenized_sentences:

    # Iterate over sentence and add <unk>
    # if the token is absent from the vocabulary
    new_sentence = []
    for token in sentence:
      if token in vocabulary:
        new_sentence.append(token)
      else:
        new_sentence.append(unknown_token)

    # Append sentece to the new list
    new_tokenized_sentences.append(new_sentence)

  return new_tokenized_sentences

# %%
def cleansing(train_data, test_data, count_threshold):

  # Get closed Vocabulary
  vocabulary = handling_oov(train_data, count_threshold)

  # Updated Training Dataset
  new_train_data = unk_tokenize(train_data, vocabulary)

  # Updated Test Dataset
  new_test_data = unk_tokenize(test_data, vocabulary)

  return new_train_data, new_test_data, vocabulary

# %%
min_freq = 50
final_train, final_test, vocabulary = cleansing(train, test, min_freq)

# %%
vocabulary
# Out:
# ['lol',
#  'my',
#  'fave',
#  'besides',
#  'prince',
#  'royce',
#  'of',
#  'course',
#  'chillin',
#  'on',
#  'it',
#  'waiting',
#  'the',
#  'fam',
#  'to',
#  'get',
#  'in',
#  'wats',
#  'good',
#  'wit',
#  'u',
#  'buzzing',
#  'great',
#  'working',
#  'space',
#  'thanks',
#  'breed',
#  'bet',
#  'they',
#  'say',
#  'that',
#  'gon',
#  'na',
#  'be',
#  'a',
#  'few',
#  'more',
#  'county',
#  'nothing',
#  'but',
#  'pure',
#  'desert',
#  'i',
#  'middle',
#  'conversation',
#  'wen',
#  'got',
#  'cut',
#  'off',
#  'only',
#  'minutes',
#  'till',
#  'leadership',
#  'opportunities',
#  'for',
#  'grad',
#  'students',
#  'pm',
#  'est',
#  'today',
#  'ok',
#  'think',
#  'can',
#  'find',
#  'line',
#  'so',
#  'far',
#  'from',
#  'hands',
#  'up',
#  'who',
#  'wants',
#  'die',
#  'he',
#  'seemed',
#  'jolly',
#  'his',
#  'craft',
#  'naturally',
#  'wished',
#  'him',
#  'ill',
#  'is',
#  'thing',
#  'or',
#  'bad',
#  'use',
#  'social',
#  'media',
#  'learn',
#  'about',
#  'their',
#  'instructor',
#  'il',
#  'share',
#  'sharing',
#  'start',
#  'game',
#  'already',
#  'will',
#  'ya',
#  'awh',
#  'thats',
#  'sweet',
#  'jake',
#  'rt',
#  'youu',
#  'needa',
#  'follow',
#  'back',
#  'order',
#  'me',
#  'too',
#  'do',
#  'this',
#  'down',
#  'new',
#  'txt',
#  'buddies',
#  's',
#  'dope',
#  'we',
#  'doing',
#  'remix',
#  'tomorrow',
#  'shit',
#  'stupid',
#  'crazy',
#  'wait',
#  'you',
#  'hear',
#  'ish',
#  'depends',
#  'drivers',
#  'because',
#  'cloud',
#  'determine',
#  'investment',
#  'plz',
#  'dont',
#  'tell',
#  'serious',
#  'smh',
#  'city',
#  'sd',
#  'close',
#  'every',
#  'collective',
#  'and',
#  'de',
#  'ban',
#  'them',
#  'dumb',
#  'ass',
#  'hes',
#  'just',
#  'contemplating',
#  'life',
#  'waking',
#  'early',
#  'amazing',
#  'want',
#  'shout',
#  'outs',
#  'then',
#  'ask',
#  'smell',
#  'roses',
#  'why',
#  'stay',
#  'myself',
#  'cause',
#  'niggas',
#  'bugging',
#  'oh',
#  'okay',
#  'were',
#  'everything',
#  'though',
#  'someone',
#  'always',
#  'thought',
#  'could',
#  'never',
#  'live',
#  'without',
#  'did',
#  'see',
#  'all',
#  'house',
#  'hunter',
#  'type',
#  'shows',
#  'show',
#  'people',
#  'master',
#  'bedroom',
#  'has',
#  'an',
#  'en',
#  'suite',
#  'pronounced',
#  'mike',
#  'make',
#  'following',
#  'beloved',
#  'wild',
#  'easy',
#  'even',
#  'portland',
#  'appreciate',
#  'didnt',
#  'look',
#  'old',
#  'there',
#  'june',
#  'met',
#  'with',
#  'secret',
#  'go',
#  'pac',
#  'except',
#  'mars',
#  'league',
#  'kidding',
#  'theyre',
#  'delayed',
#  'q',
#  'write',
#  'activities',
#  'liked',
#  'those',
#  'taught',
#  'most',
#  'm',
#  'breakfast',
#  'tacos',
#  'happy',
#  'now',
#  'posting',
#  'your',
#  'hour',
#  'our',
#  'specials',
#  'list',
#  'frustrating',
#  'productive',
#  'call',
#  'week',
#  'viva',
#  'team',
#  'last',
#  'yards',
#  'until',
#  'alpha',
#  'launch',
#  'remember',
#  'writing',
#  'ive',
#  'been',
#  'tweeting',
#  'anyone',
#  'seen',
#  'motivation',
#  'laying',
#  'around',
#  'going',
#  'ourselves',
#  'w',
#  'handle',
#  'thurs',
#  'not',
#  'worry',
#  'wont',
#  'affect',
#  'status',
#  'tuned',
#  'aw',
#  'none',
#  'jk',
#  'nice',
#  'first',
#  'yankees',
#  'win',
#  'out',
#  'if',
#  'way',
#  'almost',
#  'as',
#  'much',
#  'guy',
#  'math',
#  'learning',
#  'things',
#  'sounds',
#  'its',
#  'time',
#  'needs',
#  'ate',
#  'pizza',
#  'alrighty',
#  'wendys',
#  'looked',
#  'better',
#  'how',
#  'feel',
#  'monday',
#  'evening',
#  'was',
#  'really',
#  'seeing',
#  'have',
#  'fun',
#  'at',
#  'tonights',
#  'miss',
#  'sound',
#  'voice',
#  'shes',
#  'lady',
#  'ladies',
#  'shouldnt',
#  'messed',
#  'no',
#  'join',
#  'us',
#  'todays',
#  'money',
#  'workshop',
#  'meeting',
#  'room',
#  'count',
#  'dollar',
#  'haha',
#  'id',
#  'heat',
#  'are',
#  'golden',
#  'yes',
#  'brag',
#  'national',
#  'security',
#  'issues',
#  'el',
#  'thang',
#  'mitt',
#  'put',
#  'into',
#  'mind',
#  'matters',
#  'conscious',
#  'same',
#  'here',
#  'lot',
#  'weird',
#  'looks',
#  'after',
#  'speak',
#  'some',
#  'reason',
#  'im',
#  'starting',
#  'like',
#  'pitbull',
#  'describe',
#  'together',
#  'peanut',
#  'butter',
#  'jelly',
#  'sonny',
#  'cher',
#  'batman',
#  'robin',
#  'chips',
#  'gin',
#  'what',
#  'missing',
#  'next',
#  'three',
#  'weeks',
#  'epic',
#  'two',
#  'days',
#  'karaoke',
#  'birthday',
#  'beer',
#  'festival',
#  'beach',
#  'vacation',
#  'wonder',
#  'punk',
#  'entourage',
#  'jail',
#  'hits',
#  'woman',
#  'shoutout',
#  'interest',
#  'hadnt',
#  'pretty',
#  'cool',
#  'ring',
#  'bell',
#  'hope',
#  'smile',
#  'works',
#  'read',
#  'very',
#  'long',
#  'detailed',
#  'rather',
#  'watch',
#  'song',
#  'feeling',
#  'freaking',
#  'fact',
#  'babies',
#  'produce',
#  'tears',
#  'least',
#  'six',
#  'eight',
#  'san',
#  'diego',
#  'labor',
#  'council',
#  'leader',
#  'gonzalez',
#  'told',
#  'local',
#  'unions',
#  'stand',
#  'behind',
#  'movement',
#  'crowd',
#  'knew',
#  'printing',
#  'recycled',
#  'paper',
#  'fashion',
#  'well',
#  'love',
#  'earth',
#  'yay',
#  'man',
#  'ta',
#  'resign',
#  'clippers',
#  'homeboy',
#  'bg',
#  'fans',
#  'doesnt',
#  'wear',
#  'celebrate',
#  'xmas',
#  'mom',
#  'mean',
#  'trevor',
#  'swag',
#  'labels',
#  'songs',
#  'exactly',
#  'sell',
#  'sort',
#  'know',
#  'late',
#  'day',
#  'ff',
#  'schedule',
#  'seems',
#  'bit',
#  'am',
#  'beautiful',
#  'selling',
#  'autographed',
#  'book',
#  'within',
#  'power',
#  'universal',
#  'direct',
#  'site',
#  'check',
#  'bro',
#  'tweet',
#  'sure',
#  'moral',
#  'story',
#  'classy',
#  'also',
#  'being',
#  'starving',
#  'writer',
#  'law',
#  'school',
#  'damn',
#  'momma',
#  'test',
#  'her',
#  'mothers',
#  'she',
#  'text',
#  'when',
#  'wakes',
#  'thrilled',
#  'part',
#  'soc',
#  'seminar',
#  'right',
#  'r',
#  'promoting',
#  'alien',
#  'pants',
#  'cant',
#  'seem',
#  'problem',
#  'ones',
#  'rubber',
#  'before',
#  'touching',
#  'baltimore',
#  'pals',
#  'best',
#  'restaurant',
#  'try',
#  'crab',
#  'believe',
#  'everythings',
#  'bike',
#  'census',
#  'falls',
#  'maryland',
#  'ave',
#  'til',
#  'interesting',
#  'discussions',
#  'whether',
#  'covers',
#  'necessary',
#  'ebooks',
#  'data',
#  'saying',
#  'encourage',
#  'reading',
#  'chocolates',
#  'alright',
#  'lets',
#  'stop',
#  'debating',
#  'noon',
#  'bring',
#  'coffee',
#  'damon',
#  'ran',
#  'cactus',
#  'had',
#  'under',
#  'extensive',
#  'surgery',
#  'remove',
#  'couldnt',
#  'listening',
#  'wonderful',
#  'betty',
#  'seth',
#  'wow',
#  'talented',
#  'yeah',
#  'gets',
#  'ego',
#  'let',
#  'by',
#  'inspired',
#  'intentionally',
#  'running',
#  'knows',
#  'these',
#  'nc',
#  'access',
#  'gearing',
#  'release',
#  'music',
#  'feedback',
#  'loser',
#  'lemonade',
#  'home',
#  'nfl',
#  'wealthy',
#  'assumed',
#  'made',
#  'recent',
#  'moves',
#  'coming',
#  'need',
#  'orlando',
#  'florida',
#  'isnt',
#  'south',
#  'safe',
#  'assume',
#  'state',
#  'based',
#  'one',
#  'smallest',
#  'cities',
#  'looking',
#  'full',
#  'account',
#  'manager',
#  'position',
#  'chicago',
#  'front',
#  'bitch',
#  'xd',
#  'transportation',
#  'wine',
#  'tour',
#  'party',
#  'bus',
#  'details',
#  'bed',
#  'wondering',
#  'mail',
#  'costs',
#  'graduation',
#  'excited',
#  'proud',
#  'does',
#  'myers',
#  'hashtag',
#  'passport',
#  'mixer',
#  'open',
#  'everyone',
#  'friend',
#  'networking',
#  'cheers',
#  'chi',
#  'town',
#  'would',
#  'yea',
#  'girl',
#  'rep',
#  'stage',
#  'tru',
#  'artistic',
#  'point',
#  'career',
#  'makes',
#  'tbh',
#  'roosevelt',
#  'sandra',
#  'loyal',
#  'devoted',
#  'bought',
#  'mac',
#  'helping',
#  'process',
#  'ah',
#  'welcome',
#  'real',
#  'world',
#  'followed',
#  'thank',
#  'morning',
#  'take',
#  'balance',
#  'spent',
#  'researching',
#  'producing',
#  'sacrifice',
#  'other',
#  'watching',
#  'coyote',
#  'ugly',
#  'between',
#  'games',
#  'ice',
#  'cream',
#  'done',
#  'locally',
#  'cedar',
#  'scoop',
#  'ever',
#  'watched',
#  'affair',
#  'cary',
#  'grant',
#  'favs',
#  'button',
#  'run',
#  'startup',
#  'tab',
#  'programs',
#  'automatically',
#  'overtime',
#  'killing',
#  'number',
#  'facebook',
#  'followback',
#  'earned',
#  'stamp',
#  'travel',
#  'costa',
#  'rica',
#  'meetup',
#  'group',
#  'exist',
#  'anymore',
#  'tech',
#  'please',
#  'seriously',
#  'black',
#  'keys',
#  'staring',
#  'edge',
#  'screen',
#  'k',
#  'talk',
#  'than',
#  'bother',
#  'sofa',
#  'provides',
#  'plenty',
#  'muscle',
#  'confusion',
#  'free',
#  'heard',
#  'might',
#  'anything',
#  'including',
#  'ps',
#  'place',
#  'opening',
#  'thai',
#  'usually',
#  'block',
#  'little',
#  'whats',
#  'outcome',
#  'undefeated',
#  'defeated',
#  'defeat',
#  'ppl',
#  'care',
#  'environment',
#  'come',
#  'impossible',
#  'anywhere',
#  'car',
#  'maybe',
#  'stress',
#  'something',
#  'hurt',
#  'earlier',
#  'asked',
#  'again',
#  'self',
#  'help',
#  'books',
#  'donate',
#  'charity',
#  'stfu',
#  'morons',
#  'women',
#  'famous',
#  'fight',
#  'rogue',
#  'app',
#  'twitter',
#  'acc',
#  'gave',
#  'happened',
#  'ruby',
#  'forever',
#  'sense',
#  'humor',
#  'major',
#  'defense',
#  'against',
#  'minor',
#  'troubles',
#  'john',
#  'denver',
#  'sold',
#  'went',
#  'muppets',
#  'yup',
#  'lakers',
#  'guard',
#  'pic',
#  'roll',
#  'hopefully',
#  'baron',
#  'losing',
#  'guys',
#  'hey',
#  'iz',
#  'spoke',
#  'said',
#  'hurting',
#  'felt',
#  'pain',
#  'heart',
#  'e',
#  'extreme',
#  'makeover',
#  'mistake',
#  'ep',
#  'raise',
#  'ai',
#  'bb',
#  'stacks',
#  'blinds',
#  'shoot',
#  'frame',
#  'film',
#  'cameras',
#  'smiles',
#  'laughs',
#  'comes',
#  'thru',
#  'definitely',
#  'hit',
#  'parade',
#  'idk',
#  'laughing',
#  'cus',
#  'mask',
#  'omg',
#  'night',
#  'sunshine',
#  'hows',
#  'buddy',
#  'da',
#  'bears',
#  'butt',
#  'truth',
#  'hurts',
#  'lie',
#  'worse',
#  'forget',
#  'died',
#  'innocent',
#  'treating',
#  'packers',
#  'fan',
#  'ted',
#  'owen',
#  'nike',
#  'still',
#  'trying',
#  'figure',
#  'blocked',
#  'hi',
#  'david',
#  'pharmacy',
#  'downstairs',
#  'massive',
#  'fuckin',
#  'holy',
#  'crap',
#  'knicks',
#  'points',
#  'quiz',
#  'bout',
#  'l',
#  'favorite',
#  'artist',
#  'moment',
#  'youve',
#  'relaxing',
#  'sunday',
#  'ready',
#  'classic',
#  'hamburger',
#  'belgian',
#  'fries',
#  'side',
#  'jack',
#  'daniels',
#  'ketchup',
#  'cop',
#  'probably',
#  'rob',
#  'bank',
#  'away',
#  'must',
#  'awkward',
#  'park',
#  'gay',
#  'jokes',
#  'directed',
#  'towards',
#  'kids',
#  'months',
#  'imagine',
#  'financing',
#  'cat',
#  'food',
#  'water',
#  'toys',
#  'etc',
#  'crying',
#  'past',
#  'client',
#  'sent',
#  'own',
#  'work',
#  'reference',
#  'picking',
#  'winners',
#  'often',
#  'stories',
#  'challenge',
#  'accepted',
#  'whos',
#  'paying',
#  'gem',
#  'across',
#  'smelled',
#  'eat',
#  'king',
#  'rip',
#  'super',
#  'webinar',
#  'jay',
#  'bag',
#  'follows',
#  'where',
#  'children',
#  'congrats',
#  'whoa',
#  'obey',
#  'rules',
#  'policies',
#  'businesses',
#  'choose',
#  'create',
#  'ur',
#  'spot',
#  'tha',
#  'strip',
#  'pole',
#  'club',
#  'wish',
#  'channel',
#  'ima',
#  'sleep',
#  'took',
#  'lost',
#  'inviting',
#  'tiring',
#  'totally',
#  'addicted',
#  'feed',
#  'cheering',
#  'competing',
#  'anaheim',
#  'end',
#  'season',
#  'college',
#  'intro',
#  'dreams',
#  'may',
#  'consider',
#  'resume',
#  'exciting',
#  'hr',
#  'positions',
#  'posted',
#  'daily',
#  'youre',
#  'album',
#  'tools',
#  'hand',
#  'eye',
#  'doodle',
#  'jump',
#  'updated',
#  'destroyed',
#  'satellite',
#  'which',
#  'european',
#  'xx',
#  'pea',
#  'irish',
#  'sausage',
#  'english',
#  'peas',
#  'hash',
#  'brown',
#  'potatoes',
#  'onion',
#  'topped',
#  'jameson',
#  'cheese',
#  'sauce',
#  'act',
#  'flirt',
#  'girls',
#  'intuition',
#  ...]

# %%
final_train
# Out:
# [['lol', 'my', 'fave', 'besides', 'prince', 'royce', 'of', 'course'],
#  ['chillin',
#   'on',
#   'it',
#   'waiting',
#   'on',
#   'the',
#   'fam',
#   'to',
#   'get',
#   'in',
#   'wats',
#   'good',
#   'wit',
#   'u'],
#  ['buzzing', 'in', 'the', '<unk>', 'great', 'working', 'space', 'thanks'],
#  ['<unk>',
#   'breed',
#   '<unk>',
#   'bet',
#   'they',
#   'say',
#   'that',
#   'gon',
#   'na',
#   'be',
#   'a',
#   'few',
#   'more',
#   '<unk>'],
#  ['<unk>', 'county', 'nothing', 'but', 'pure', 'desert'],
#  ['lol',
#   'i',
#   '<unk>',
#   'in',
#   'the',
#   'middle',
#   'of',
#   'a',
#   'good',
#   'conversation',
#   'wen',
#   'it',
#   'got',
#   'cut',
#   'off'],
#  ['only',
#   'minutes',
#   'till',
#   '<unk>',
#   'on',
#   'leadership',
#   'opportunities',
#   'for',
#   'grad',
#   'students',
#   'pm',
#   'est',
#   'today'],
#  ['ok', 'i', 'think', 'i', 'can', 'find', 'it'],
#  ['my',
#   'fave',
#   'line',
#   'so',
#   'far',
#   'from',
#   'hands',
#   'up',
#   'who',
#   'wants',
#   'to',
#   'die',
#   'in',
#   'he',
#   'seemed',
#   'so',
#   'jolly',
#   'in',
#   'his',
#   'craft',
#   'i',
#   'naturally',
#   'wished',
#   'him',
#   'ill'],
#  ['is',
#   'it',
#   'a',
#   'good',
#   'thing',
#   'or',
#   'a',
#   'bad',
#   'thing',
#   'for',
#   'students',
#   'to',
#   'use',
#   'social',
#   'media',
#   'to',
#   'learn',
#   'more',
#   'about',
#   'their',
#   'instructor'],
#  ['ok', 'il', 'share', 'sharing', 'is', '<unk>'],
#  ['start', 'the', 'game', 'already', 'will', 'ya'],
#  ['awh', 'thats', 'so', 'sweet', 'jake'],
#  ['rt',
#   'youu',
#   'needa',
#   'follow',
#   'back',
#   'in',
#   'order',
#   'for',
#   'me',
#   'too',
#   'do',
#   'this',
#   'down',
#   'to',
#   'be',
#   'my',
#   'new',
#   'txt',
#   'buddies',
#   '<unk>',
#   's'],
#  ['dope',
#   '<unk>',
#   'we',
#   'doing',
#   'the',
#   'remix',
#   'tomorrow',
#   'shit',
#   'is',
#   'stupid',
#   'crazy',
#   'wait',
#   'to',
#   'you',
#   'hear',
#   'that',
#   'ish'],
#  ['a',
#   'it',
#   'depends',
#   'on',
#   'the',
#   'drivers',
#   'because',
#   'the',
#   'drivers',
#   'of',
#   'cloud',
#   'determine',
#   'cloud',
#   'investment'],
#  ['plz', 'dont', 'tell', 'me', 'this', 'is', 'serious', 'smh', 'lol'],
#  ['thats',
#   'only',
#   'the',
#   'start',
#   'a',
#   'new',
#   '<unk>',
#   'in',
#   'the',
#   'city',
#   'of',
#   'sd',
#   'will',
#   'close',
#   'down',
#   'every',
#   'collective',
#   'and',
#   'be',
#   'a',
#   'de',
#   '<unk>',
#   'ban',
#   'on',
#   'them',
#   '<unk>'],
#  ['dumb', 'ass', '<unk>'],
#  ['<unk>', 'hes', 'just', 'contemplating', 'life', 'hes', 'a', '<unk>'],
#  ['waking', 'up', 'early', 'is', 'amazing'],
#  ['want', 'me', 'to', 'to', 'shout', 'outs', 'then', 'just', 'ask'],
#  ['i', 'smell', 'roses'],
#  ['<unk>',
#   'why',
#   'i',
#   'stay',
#   'to',
#   'myself',
#   'cause',
#   'niggas',
#   'do',
#   'be',
#   'bugging'],
#  ['oh', 'okay', 'lol'],
#  ['you',
#   'were',
#   'my',
#   '<unk>',
#   'were',
#   'everything',
#   'i',
#   'though',
#   'about',
#   'you',
#   'were',
#   'someone',
#   'i',
#   'always',
#   'thought',
#   'i',
#   'could',
#   'never',
#   'live',
#   'without',
#   'did',
#   'you',
#   'see',
#   'the',
#   'were'],
#  ['all',
#   'of',
#   'the',
#   'house',
#   'hunter',
#   'type',
#   'shows',
#   'show',
#   'people',
#   'the',
#   'master',
#   'bedroom',
#   'and',
#   'tell',
#   'them',
#   'it',
#   'has',
#   'an',
#   'en',
#   'suite',
#   'pronounced',
#   '<unk>'],
#  ['thanks',
#   'for',
#   'everything',
#   'you',
#   'do',
#   'mike',
#   'make',
#   'following',
#   'my',
#   'beloved',
#   'wild',
#   'easy',
#   'even',
#   'though',
#   'i',
#   'live',
#   'in',
#   'portland',
#   'appreciate',
#   'you'],
#  ['didnt', 'look', 'old', 'there'],
#  ['see', 'you', 'in', 'june'],
#  ['so',
#   'i',
#   'just',
#   'met',
#   'with',
#   'my',
#   'secret',
#   '<unk>',
#   'and',
#   'they',
#   'say',
#   'go',
#   'to',
#   'the',
#   'pac',
#   'except',
#   'for',
#   'who',
#   'want',
#   'to',
#   'go',
#   'to',
#   'the',
#   'mars',
#   'league'],
#  ['just', 'kidding', 'theyre', 'delayed'],
#  ['q',
#   'students',
#   'write',
#   'me',
#   '<unk>',
#   'on',
#   'activities',
#   'that',
#   'they',
#   'liked',
#   'those',
#   'that',
#   'they',
#   'didnt',
#   'and',
#   'those',
#   'that',
#   'taught',
#   'them',
#   'the',
#   'most'],
#  ['m', 'breakfast', 'tacos'],
#  ['happy',
#   'to',
#   'now',
#   'be',
#   'posting',
#   'your',
#   'happy',
#   'hour',
#   'on',
#   'our',
#   'specials',
#   'list'],
#  ['frustrating',
#   'but',
#   'productive',
#   'call',
#   'this',
#   'week',
#   'with',
#   'the',
#   'viva',
#   '<unk>',
#   'team',
#   'last',
#   'few',
#   'yards',
#   'now',
#   'until',
#   'our',
#   'alpha',
#   'launch'],
#  ['remember',
#   'all',
#   'the',
#   'writing',
#   'ive',
#   'been',
#   'tweeting',
#   'about',
#   'anyone',
#   'seen',
#   'of',
#   'that',
#   'motivation',
#   'laying',
#   'around'],
#  ['were',
#   'going',
#   'to',
#   'be',
#   '<unk>',
#   'ourselves',
#   'w',
#   'a',
#   'new',
#   'handle',
#   'thurs',
#   'not',
#   'to',
#   'worry',
#   'it',
#   'wont',
#   'affect',
#   'your',
#   'following',
#   'status',
#   'stay',
#   'tuned'],
#  ['aw', 'thats', 'sweet', 'but', 'none', 'for', 'me', 'jk'],
#  ['nice',
#   'to',
#   'get',
#   'the',
#   'first',
#   'yankees',
#   'win',
#   'out',
#   'if',
#   'the',
#   'way'],
#  ['almost',
#   'as',
#   'much',
#   'as',
#   'the',
#   'guy',
#   'who',
#   '<unk>',
#   'the',
#   '<unk>',
#   '<unk>'],
#  ['in', 'math', 'learning', 'new', 'things'],
#  ['sounds', 'good'],
#  ['its', 'almost', 'show', 'time', 'for', 'new', 'show'],
#  ['can', 'you', 'say', 's', 'do', 'needs', 'cut'],
#  ['you', 'ate', 'pizza', '<unk>'],
#  ['alrighty', 'just', '<unk>', 'wendys', 'looked', 'better'],
#  ['how', 'do', 'you', 'feel', 'in', 'monday', 'evening'],
#  ['thanks',
#   'it',
#   'was',
#   'really',
#   'great',
#   'seeing',
#   'you',
#   'too',
#   'have',
#   'fun',
#   'at',
#   'tonights',
#   'show'],
#  ['miss', 'the', 'sound', 'of', 'your', 'voice'],
#  ['shes', 'a', 'lady', 'and', 'ladies', 'shouldnt', 'be', 'messed', 'with'],
#  ['no', 'i', 'dont'],
#  ['join',
#   'us',
#   'for',
#   'todays',
#   'money',
#   'week',
#   'workshop',
#   'from',
#   '<unk>',
#   'in',
#   'meeting',
#   'room',
#   'count',
#   'every',
#   'dollar'],
#  ['haha', 'id', 'say', 'the', 'heat', 'are', 'the', 'golden', 'team'],
#  ['okay', 'good'],
#  ['yes',
#   'he',
#   'can',
#   'brag',
#   'all',
#   'he',
#   'wants',
#   'on',
#   'national',
#   'security',
#   'issues',
#   '<unk>',
#   'el',
#   '<unk>',
#   'do',
#   'your',
#   'thang',
#   'mitt',
#   '<unk>',
#   'on',
#   'his',
#   'money',
#   '<unk>',
#   '<unk>'],
#  ['everything',
#   'you',
#   'put',
#   'into',
#   'your',
#   'mind',
#   'matters',
#   'so',
#   'stay',
#   'conscious'],
#  ['same',
#   'here',
#   'i',
#   'get',
#   'a',
#   'lot',
#   'of',
#   'weird',
#   'looks',
#   'after',
#   'i',
#   'speak'],
#  ['for', 'some', 'reason', 'im', 'starting', 'to', 'like', 'pitbull'],
#  ['how', 'to', 'describe', '<unk>', '<unk>', 'first', 'thing'],
#  ['things',
#   'that',
#   'are',
#   'better',
#   'together',
#   'peanut',
#   'butter',
#   'and',
#   'jelly',
#   'sonny',
#   'and',
#   'cher',
#   'batman',
#   'and',
#   'robin',
#   'chips',
#   'and',
#   '<unk>',
#   'gin',
#   'and',
#   '<unk>',
#   'what',
#   'is',
#   'missing'],
#  ['the',
#   'next',
#   'three',
#   'weeks',
#   'are',
#   'going',
#   'to',
#   'be',
#   'epic',
#   'two',
#   'more',
#   'days',
#   'with',
#   '<unk>',
#   'a',
#   'karaoke',
#   'birthday',
#   'a',
#   'beer',
#   'festival',
#   'and',
#   'a',
#   'beach',
#   'vacation'],
#  ['wonder',
#   'what',
#   'the',
#   'punk',
#   'is',
#   'going',
#   'to',
#   'do',
#   'without',
#   'his',
#   'entourage',
#   'in',
#   'jail',
#   'only',
#   'a',
#   '<unk>',
#   'hits',
#   'a',
#   'woman'],
#  ['thanks', 'and', 'i', 'shoutout', 'u'],
#  ['good',
#   'to',
#   'hear',
#   'there',
#   'is',
#   'interest',
#   'in',
#   'it',
#   'i',
#   'hadnt',
#   'thought',
#   'about',
#   'the',
#   '<unk>',
#   'that',
#   'be',
#   'pretty',
#   'cool'],
#  ['about',
#   'to',
#   'ring',
#   'the',
#   'bell',
#   'at',
#   '<unk>',
#   'hope',
#   'my',
#   'smile',
#   'works'],
#  ['lol',
#   'you',
#   'have',
#   'to',
#   'read',
#   'them',
#   'then',
#   'write',
#   'a',
#   'very',
#   'long',
#   'detailed',
#   '<unk>',
#   'rather',
#   'watch',
#   'them',
#   'or',
#   'write',
#   'a',
#   'song'],
#  ['its', 'an', 'amazing', 'feeling'],
#  ['im', 'freaking', 'out'],
#  ['fun',
#   'fact',
#   'babies',
#   'dont',
#   'produce',
#   'tears',
#   'until',
#   'they',
#   'are',
#   'at',
#   'least',
#   'six',
#   'to',
#   'eight',
#   'weeks',
#   'old'],
#  ['san',
#   'diego',
#   'labor',
#   'council',
#   'leader',
#   '<unk>',
#   'gonzalez',
#   'told',
#   '<unk>',
#   'that',
#   'local',
#   'labor',
#   'unions',
#   'stand',
#   'behind',
#   'the',
#   'movement',
#   'crowd',
#   'is',
#   '<unk>'],
#  ['who',
#   'knew',
#   'that',
#   'printing',
#   'on',
#   'recycled',
#   'paper',
#   'is',
#   'out',
#   'of',
#   'fashion',
#   'well',
#   'were',
#   'doing',
#   'it',
#   'because',
#   'we',
#   'love',
#   'the',
#   'earth',
#   'yay'],
#  ['man',
#   'you',
#   'got',
#   'ta',
#   'resign',
#   'with',
#   'the',
#   'clippers',
#   'and',
#   'your',
#   'homeboy',
#   'bg',
#   'do',
#   'it',
#   'for',
#   'the',
#   'fans',
#   'man'],
#  ['he',
#   'doesnt',
#   'make',
#   '<unk>',
#   'wear',
#   'the',
#   '<unk>',
#   'bell',
#   'we',
#   'celebrate',
#   'xmas',
#   '<unk>',
#   'happy',
#   '<unk>',
#   'u',
#   'your',
#   'pretty',
#   'mom'],
#  ['i', 'didnt', 'mean', 'to', 'but', 'trevor', 'told', 'me', 'to'],
#  ['swag', 'swag'],
#  ['labels',
#   'and',
#   'songs',
#   'are',
#   'exactly',
#   'what',
#   'sell',
#   'beer',
#   'of',
#   'that',
#   'sort',
#   'though'],
#  ['i',
#   'know',
#   'it',
#   'is',
#   'late',
#   'in',
#   'the',
#   'day',
#   'for',
#   'ff',
#   'but',
#   'my',
#   'schedule',
#   'seems',
#   'a',
#   'bit',
#   'off',
#   'happy',
#   'day'],
#  ['lol', 'am', 'i', 'beautiful'],
#  ['now',
#   'selling',
#   'our',
#   'autographed',
#   'book',
#   'within',
#   'the',
#   'power',
#   'of',
#   'universal',
#   'mind',
#   'direct',
#   'from',
#   'our',
#   'site',
#   '<unk>',
#   'check',
#   'it',
#   'out'],
#  ['bro', 'you', 'dont', 'even', 'tweet'],
#  ['sure', 'thing', 'see', 'you', 'in', 'a', 'bit'],
#  ['moral',
#   'of',
#   'this',
#   'story',
#   'im',
#   'not',
#   'classy',
#   'also',
#   'not',
#   'good',
#   'at',
#   'being',
#   'a',
#   'starving',
#   'writer',
#   '<unk>',
#   'law',
#   'school',
#   'every',
#   'damn',
#   'day'],
#  ['i',
#   'know',
#   'my',
#   'momma',
#   'gon',
#   'na',
#   'test',
#   'me',
#   'and',
#   'see',
#   'if',
#   'i',
#   'tell',
#   'her',
#   'happy',
#   'mothers',
#   'day',
#   'she',
#   'gon',
#   'get',
#   'a',
#   'text',
#   'when',
#   'she',
#   'wakes',
#   'up'],
#  ['i',
#   'am',
#   'thrilled',
#   'be',
#   'part',
#   'of',
#   'soc',
#   'media',
#   'seminar',
#   'right',
#   'now',
#   'do',
#   'u',
#   'know',
#   'that',
#   'at',
#   'her',
#   '<unk>',
#   'we',
#   'r',
#   '<unk>',
#   'promoting',
#   'her',
#   'all',
#   'of',
#   'u'],
#  ['alien', 'in', 'my', 'pants'],
#  ['i',
#   'got',
#   'a',
#   'new',
#   'book',
#   'and',
#   'i',
#   'cant',
#   'seem',
#   'to',
#   'put',
#   'it',
#   'down',
#   'thats',
#   'the',
#   'problem',
#   'with',
#   '<unk>',
#   'ones',
#   'hands',
#   'with',
#   'rubber',
#   '<unk>',
#   'before',
#   'touching',
#   'things'],
#  ['baltimore',
#   'pals',
#   'best',
#   'restaurant',
#   'in',
#   'the',
#   'city',
#   'to',
#   'try',
#   'to',
#   'get',
#   'into',
#   '<unk>',
#   'crab'],
#  ['believe', 'in', '<unk>', 'because', 'everythings', '<unk>'],
#  ['doing',
#   'a',
#   'bike',
#   'census',
#   'at',
#   'falls',
#   'and',
#   'maryland',
#   'ave',
#   'til',
#   'pm'],
#  ['interesting',
#   'discussions',
#   'this',
#   'week',
#   'on',
#   'whether',
#   'book',
#   'covers',
#   'are',
#   'necessary',
#   'with',
#   'ebooks',
#   '<unk>',
#   'data',
#   'saying',
#   'that',
#   'covers',
#   'encourage',
#   'reading'],
#  ['too', 'much', 'chocolates'],
#  ['alright', 'lets', 'stop', 'the', 'debating', 'then'],
#  ['and',
#   'me',
#   'starting',
#   'at',
#   'noon',
#   'tomorrow',
#   'want',
#   'me',
#   'to',
#   'bring',
#   'the',
#   'coffee',
#   '<unk>'],
#  ['damon', 'and', '<unk>'],
#  ['i',
#   'ran',
#   'into',
#   'a',
#   'cactus',
#   'and',
#   'had',
#   'to',
#   'go',
#   'under',
#   'extensive',
#   'surgery',
#   'to',
#   'remove',
#   'all',
#   'the',
#   '<unk>',
#   'so',
#   'i',
#   'couldnt',
#   'make',
#   'it',
#   'in'],
#  ['listening',
#   'to',
#   'the',
#   'wonderful',
#   'betty',
#   '<unk>',
#   'on',
#   'seth',
#   '<unk>',
#   '<unk>',
#   'best',
#   'love',
#   'her',
#   'wow',
#   'and',
#   'shes',
#   'from',
#   'a',
#   'talented',
#   '<unk>',
#   '<unk>',
#   'knew'],
#  ['yeah', 'you', 'are'],
#  ['the',
#   'thing',
#   'that',
#   'i',
#   'believe',
#   'gets',
#   'in',
#   'our',
#   'way',
#   'is',
#   'our',
#   'ego',
#   'watch',
#   'your',
#   'ego',
#   'do',
#   'not',
#   'let',
#   'it',
#   'get',
#   'the',
#   'best',
#   'of',
#   'you',
#   'by',
#   '<unk>'],
#  ['has',
#   'inspired',
#   'me',
#   'to',
#   'look',
#   'into',
#   'intentionally',
#   '<unk>',
#   'running',
#   '<unk>',
#   'if',
#   'anyone',
#   'knows',
#   'of',
#   'these',
#   'in',
#   'nc',
#   'share',
#   'access',
#   'to',
#   'these',
#   '<unk>'],
#  ['i', '<unk>', 'to', 'tweet', '<unk>', 'my', 'new', '<unk>'],
#  ['gearing',
#   'up',
#   'to',
#   'release',
#   'a',
#   '<unk>',
#   'of',
#   'new',
#   'music',
#   'cant',
#   'wait',
#   'to',
#   'hear',
#   'your',
#   'feedback',
#   'loser',
#   'lemonade',
#   'home',
#   'of',
#   'the'],
#  ['happy', 'birthday'],
#  ['and',
#   'its',
#   'people',
#   'like',
#   'me',
#   'who',
#   'make',
#   'the',
#   'nfl',
#   'so',
#   'wealthy'],
#  ['i',
#   'assumed',
#   'he',
#   'made',
#   'all',
#   'those',
#   'recent',
#   '<unk>',
#   'moves',
#   'because',
#   'even',
#   'he',
#   'doesnt',
#   'think',
#   'he',
#   'is',
#   'coming',
#   'back'],
#  ['<unk>', 'just', 'need', 'to', '<unk>', 'up', 'haha', 'i', 'love', 'it'],
#  ['to',
#   'people',
#   'in',
#   'orlando',
#   'who',
#   'say',
#   'florida',
#   'isnt',
#   'the',
#   'south',
#   'its',
#   'safe',
#   'to',
#   'assume',
#   'how',
#   'a',
#   'state',
#   'is',
#   'based',
#   'off',
#   'of',
#   'one',
#   'its',
#   'smallest',
#   'cities'],
#  ['looking',
#   'for',
#   'a',
#   'full',
#   'time',
#   'account',
#   'manager',
#   'position',
#   'in',
#   'chicago'],
#  ['thats',
#   'when',
#   'i',
#   '<unk>',
#   'out',
#   'and',
#   'cut',
#   'in',
#   'front',
#   'of',
#   'that',
#   'bitch',
#   'xd'],
#  ['get',
#   'safe',
#   'transportation',
#   'for',
#   'your',
#   'next',
#   'wine',
#   'tour',
#   'in',
#   'our',
#   '<unk>',
#   'party',
#   'bus',
#   'call',
#   'today',
#   'for',
#   'details'],
#  ['today',
#   'what',
#   'got',
#   'me',
#   'out',
#   'of',
#   'bed',
#   'is',
#   'wondering',
#   'how',
#   'much',
#   'media',
#   'mail',
#   'costs'],
#  ['and',
#   'happy',
#   'graduation',
#   'im',
#   'excited',
#   'for',
#   'you',
#   'and',
#   'proud',
#   'of',
#   'you'],
#  ['how', 'does', 'myers', 'get', 'a', 'hashtag', 'before', 'me'],
#  ['passport',
#   'mixer',
#   'today',
#   'at',
#   '<unk>',
#   '<unk>',
#   'open',
#   'to',
#   'everyone',
#   'today',
#   'so',
#   'bring',
#   'a',
#   'friend',
#   'and',
#   'get',
#   'your',
#   'networking',
#   'on',
#   'cheers'],
#  ['some', 'people', 'just', 'cant', 'handle', 'chi', 'town'],
#  ['i',
#   'knew',
#   'you',
#   'would',
#   'see',
#   'it',
#   'that',
#   'way',
#   'lol',
#   'but',
#   'yea',
#   'its',
#   'a',
#   'good',
#   'song'],
#  ['my', 'girl', 'just', 'rep', 'the', 'stage', 'at', '<unk>', 'tru'],
#  ['and', 'why', 'is', 'that'],
#  ['from',
#   'an',
#   'artistic',
#   'stand',
#   'point',
#   'yes',
#   'from',
#   'a',
#   'career',
#   '<unk>',
#   'id',
#   'do',
#   'what',
#   'makes',
#   'the',
#   'most',
#   'money',
#   '<unk>',
#   'and',
#   'tbh'],
#  ['oh',
#   'yea',
#   'the',
#   'one',
#   'i',
#   'roosevelt',
#   'yea',
#   'i',
#   'been',
#   '<unk>',
#   'lol'],
#  ['<unk>', 'just', 'never', 'gets', 'old'],
#  ['sandra', 'it', 'isnt', 'loyal', 'and', 'devoted'],
#  ['what', 'they', '<unk>'],
#  ['i',
#   'did',
#   'it',
#   'i',
#   'bought',
#   'my',
#   'very',
#   'first',
#   'mac',
#   'thanks',
#   'to',
#   'and',
#   'for',
#   'helping',
#   'with',
#   'the',
#   'process',
#   'ah'],
#  ['welcome', 'back', 'to', 'the', 'real', 'world'],
#  ['oh',
#   'no',
#   'were',
#   'being',
#   'followed',
#   'by',
#   'the',
#   'thank',
#   'you',
#   '<unk>'],
#  ['good', 'morning', 'gon', 'na', 'take', 'my', '<unk>', 'in', 'an', 'hour'],
#  ['how',
#   'do',
#   'you',
#   'balance',
#   'your',
#   'time',
#   'spent',
#   'researching',
#   'with',
#   'time',
#   'spent',
#   'producing',
#   'i',
#   'find',
#   'its',
#   'easy',
#   'to',
#   'sacrifice',
#   'one',
#   'for',
#   'other'],
#  ['watching', 'coyote', 'ugly'],
#  ['i', '<unk>', 'between', 'games', 'lol'],
#  ['just', '<unk>'],
#  ['ice',
#   'cream',
#   'done',
#   'right',
#   'locally',
#   'by',
#   'cedar',
#   '<unk>',
#   'one',
#   'scoop',
#   'only',
#   'only',
#   'today'],
#  ['ever',
#   'watched',
#   'an',
#   'affair',
#   'to',
#   'remember',
#   'with',
#   'cary',
#   'grant',
#   '<unk>',
#   '<unk>',
#   'one',
#   'of',
#   'my',
#   'favs',
#   'gets',
#   'me',
#   'every',
#   'time'],
#  ['start',
#   'button',
#   'run',
#   'type',
#   '<unk>',
#   'and',
#   'on',
#   'the',
#   'startup',
#   'tab',
#   '<unk>',
#   'the',
#   'programs',
#   'you',
#   'dont',
#   'want',
#   'to',
#   'start',
#   'automatically'],
#  ['im', 'a', '<unk>'],
#  ['yeah',
#   'the',
#   'overtime',
#   'was',
#   'killing',
#   'me',
#   'i',
#   'dont',
#   'think',
#   'i',
#   'have',
#   'your',
#   'number',
#   'is',
#   'it',
#   'on',
#   'facebook'],
#  ['<unk>',
#   'my',
#   'followback',
#   'is',
#   'have',
#   'even',
#   'earned',
#   'the',
#   '<unk>',
#   'stamp',
#   'from',
#   '<unk>'],
#  ['haha', 'u', 'know', 'it'],
#  ['make',
#   'sure',
#   'you',
#   'dont',
#   'travel',
#   'to',
#   'costa',
#   'rica',
#   'for',
#   'a',
#   'meetup',
#   'group',
#   'and',
#   'then',
#   'find',
#   'out',
#   'that',
#   'meetup',
#   'group',
#   'doesnt',
#   'exist',
#   'anymore',
#   'damn',
#   'you',
#   '<unk>',
#   'tech'],
#  ['haha', 'yes', 'please'],
#  ['seriously',
#   'im',
#   'sure',
#   'hes',
#   'a',
#   'nice',
#   'man',
#   'who',
#   'makes',
#   'good',
#   'music',
#   'but',
#   'i',
#   'cant',
#   'take',
#   'that',
#   'black',
#   'keys',
#   '<unk>',
#   'staring',
#   'at',
#   'me',
#   'from',
#   'the',
#   'edge',
#   'of',
#   'the',
#   'screen'],
#  ['k', 'talk', 'to', 'you', 'than'],
#  ['dont',
#   'bother',
#   'our',
#   'sofa',
#   'provides',
#   'plenty',
#   'of',
#   'muscle',
#   'confusion',
#   'for',
#   'free',
#   'heard',
#   'you',
#   'might',
#   'be',
#   '<unk>',
#   'us',
#   'if',
#   'you',
#   'need',
#   'anything'],
#  ['thanks',
#   'for',
#   'including',
#   'me',
#   'ps',
#   'did',
#   'you',
#   'see',
#   'a',
#   '<unk>',
#   'place',
#   '<unk>',
#   'opening',
#   'at',
#   'old',
#   '<unk>',
#   'thai',
#   'in',
#   '<unk>'],
#  ['i', 'usually', 'just', 'block', 'those'],
#  ['love',
#   'it',
#   'im',
#   'going',
#   'to',
#   'start',
#   'it',
#   'in',
#   'a',
#   'few',
#   'weeks',
#   'when',
#   'i',
#   'have',
#   'a',
#   'little',
#   'more',
#   'down',
#   'time',
#   'whats',
#   'the',
#   'outcome',
#   'are',
#   'you',
#   'feeling',
#   'great'],
#  ['the', 'undefeated', 'are', 'defeated', 'and', 'the', 'defeated', 'defeat'],
#  ['seriously',
#   'if',
#   'ppl',
#   'really',
#   'care',
#   'about',
#   'the',
#   'environment',
#   'social',
#   '<unk>',
#   'come',
#   'its',
#   'impossible',
#   'to',
#   'get',
#   'anywhere',
#   'without',
#   'car',
#   'in',
#   'some',
#   'us',
#   'cities'],
#  ['maybe',
#   'you',
#   'have',
#   'like',
#   'a',
#   '<unk>',
#   'or',
#   'stress',
#   '<unk>',
#   'or',
#   'something',
#   'does',
#   'it',
#   'hurt'],
#  ['earlier',
#   'i',
#   'asked',
#   'myself',
#   'and',
#   'why',
#   'am',
#   'i',
#   'not',
#   'happy',
#   'again'],
#  ['read',
#   'a',
#   'few',
#   'self',
#   'help',
#   'books',
#   'donate',
#   'some',
#   'of',
#   'your',
#   'time',
#   'to',
#   'charity',
#   'and',
#   'stfu'],
#  ['are', 'these', 'morons', 'serious'],
#  ['i',
#   'think',
#   'most',
#   'women',
#   'know',
#   '<unk>',
#   'famous',
#   '<unk>',
#   'my',
#   'life',
#   'i',
#   'had',
#   'to',
#   'fight'],
#  ['usually',
#   'its',
#   'some',
#   'rogue',
#   'app',
#   'u',
#   'let',
#   'have',
#   'access',
#   'to',
#   'your',
#   'twitter',
#   'acc',
#   'id',
#   'check',
#   'those',
#   'u',
#   'gave',
#   '<unk>'],
#  ['what', 'happened', 'to', 'ruby', 'rt', 'ruby', 'wont', 'run', 'forever'],
#  ['a',
#   'sense',
#   'of',
#   'humor',
#   'is',
#   'a',
#   'major',
#   'defense',
#   'against',
#   'minor',
#   'troubles'],
#  ['i',
#   'was',
#   'into',
#   'john',
#   'denver',
#   'before',
#   'he',
#   'sold',
#   'out',
#   'and',
#   'went',
#   'on',
#   'the',
#   'muppets'],
#  ['yup',
#   'haha',
#   'waiting',
#   'for',
#   'that',
#   'lakers',
#   'game',
#   'do',
#   'or',
#   'die'],
#  ['you',
#   'need',
#   'a',
#   'guard',
#   'that',
#   'will',
#   'run',
#   'the',
#   'pic',
#   'and',
#   'roll',
#   'hopefully',
#   'baron',
#   'is',
#   'up',
#   'to',
#   'it',
#   'losing',
#   '<unk>',
#   'hurt',
#   'you',
#   'guys'],
#  ['hey', 'little', 'one', 'how', 'iz', 'it', 'going', 'for', 'yeah'],
#  ['last',
#   'time',
#   'we',
#   'spoke',
#   'you',
#   'said',
#   'you',
#   'were',
#   'hurting',
#   'and',
#   'i',
#   'felt',
#   'your',
#   'pain',
#   'in',
#   'my',
#   'heart'],
#  ['e', 'extreme', 'makeover', 'my'],
#  ['im',
#   '<unk>',
#   'made',
#   'a',
#   'mistake',
#   'didnt',
#   'see',
#   'an',
#   'ep',
#   'raise',
#   'a',
#   '<unk>',
#   'ai',
#   '<unk>',
#   '<unk>',
#   'bb',
#   'stacks',
#   'in',
#   'the',
#   'blinds',
#   'i',
#   'had',
#   'k',
#   'at',
#   '<unk>',
#   'he',
#   'had',
#   '<unk>'],
#  ['just', 'shoot', 'nice', '<unk>', 'full', 'frame', 'film', 'cameras'],
#  ['smiles', 'and', 'laughs'],
#  ['<unk>',
#   'comes',
#   'thru',
#   'its',
#   'definitely',
#   'a',
#   'hit',
#   'parade',
#   'today'],
#  ['idk',
#   'i',
#   'was',
#   'just',
#   'laughing',
#   'cus',
#   'u',
#   'guys',
#   'r',
#   'dumb',
#   'and',
#   'i',
#   'couldnt',
#   'take',
#   'you',
#   'seriously',
#   'with',
#   'your',
#   'mask',
#   'omg'],
#  ['<unk>', 'good', 'night'],
#  ['hey',
#   'there',
#   'sunshine',
#   'hows',
#   '<unk>',
#   'how',
#   'long',
#   'are',
#   'you',
#   'here'],
#  ['yeah', 'buddy', 'da', 'bears'],
#  ['i', 'need', 'to', 'get', 'my', 'butt', 'up', 'and', 'out', 'there'],
#  ['the', 'truth', 'hurts', 'but', 'a', 'lie', 'is', 'worse'],
#  ['never',
#   'forget',
#   'remember',
#   'all',
#   'those',
#   'who',
#   'died',
#   'innocent',
#   'people'],
#  ['hows', 'the', 'day', 'treating', 'you'],
#  ['im',
#   'a',
#   'packers',
#   'fan',
#   'so',
#   'this',
#   'isnt',
#   '<unk>',
#   'a',
#   'lot',
#   'ted'],
#  ['owen',
#   'i',
#   'dont',
#   'think',
#   'the',
#   '<unk>',
#   'are',
#   'going',
#   'to',
#   'make',
#   'it',
#   'to',
#   'the',
#   '<unk>'],
#  ['i', 'think', 'i', 'love', 'nike'],
#  ['still', 'trying', 'to', 'figure', 'out', 'why', 'blocked', 'me'],
#  ['yay',
#   'stop',
#   'in',
#   'and',
#   'say',
#   'hi',
#   'to',
#   'david',
#   'hes',
#   'in',
#   'the',
#   'pharmacy',
#   'downstairs',
#   'have',
#   'fun'],
#  ['this',
#   'ep',
#   'is',
#   'the',
#   'shit',
#   'cant',
#   'wait',
#   'for',
#   'you',
#   'guys',
#   'to',
#   'hear',
#   'it',
#   'shit',
#   'is',
#   'massive',
#   'is',
#   'the',
#   'fuckin',
#   'man'],
#  ['holy',
#   'crap',
#   'just',
#   'tuned',
#   'into',
#   '<unk>',
#   'knicks',
#   'are',
#   'we',
#   'sure',
#   'the',
#   'knicks',
#   'have',
#   'points',
#   'and',
#   'that',
#   'number',
#   'isnt',
#   '<unk>'],
#  ['math', 'quiz', 'tomorrow', 'bout', 'to', 'take', 'a', 'l'],
#  ['we',
#   'always',
#   'love',
#   'to',
#   'hear',
#   'your',
#   'favorite',
#   'artist',
#   'is',
#   'at',
#   'the',
#   'moment'],
#  ['hope',
#   'youve',
#   'had',
#   'a',
#   'relaxing',
#   'sunday',
#   'so',
#   'far',
#   'were',
#   'ready',
#   'for',
#   '<unk>',
#   'classic',
#   'hamburger',
#   'and',
#   'belgian',
#   'fries',
#   'with',
#   'a',
#   'side',
#   'of',
#   'jack',
#   'daniels',
#   'ketchup'],
#  ['im',
#   'pretty',
#   'sure',
#   'every',
#   'cop',
#   'in',
#   'nc',
#   'is',
#   'at',
#   'the',
#   '<unk>',
#   '<unk>',
#   'you',
#   'could',
#   'probably',
#   'rob',
#   'a',
#   'bank',
#   'and',
#   'get',
#   'away',
#   'with',
#   'it',
#   'today'],
#  ['it',
#   'must',
#   'be',
#   'pretty',
#   'awkward',
#   'watching',
#   'south',
#   'park',
#   'with',
#   'a',
#   'black',
#   '<unk>',
#   'or',
#   'a',
#   'gay',
#   '<unk>',
#   'the',
#   'jokes',
#   'are',
#   'directed',
#   'towards',
#   'them'],
#  ['thats',
#   'kids',
#   'in',
#   'almost',
#   'months',
#   'imagine',
#   'what',
#   'we',
#   'could',
#   'do',
#   'with',
#   'some',
#   'serious',
#   'financing'],
#  ['my',
#   'cat',
#   'who',
#   'is',
#   'downstairs',
#   '<unk>',
#   'has',
#   'food',
#   'water',
#   'toys',
#   'etc',
#   'has',
#   'been',
#   'crying',
#   'for',
#   'me',
#   'for',
#   'the',
#   'past',
#   'minutes',
#   'its',
#   'am'],
#  ['first',
#   'new',
#   'client',
#   'ever',
#   'that',
#   'has',
#   '<unk>',
#   'sent',
#   'me',
#   'my',
#   'own',
#   'work',
#   'as',
#   'a',
#   'reference',
#   'for',
#   'the',
#   'work',
#   'he',
#   'wants',
#   'me',
#   'to',
#   'produce'],
#  ['are',
#   'you',
#   'picking',
#   'the',
#   'winners',
#   'for',
#   'the',
#   '<unk>',
#   'tomorrow'],
#  ['thanks',
#   'for',
#   'reading',
#   'and',
#   'yes',
#   'often',
#   'working',
#   'on',
#   '<unk>',
#   'stories'],
#  ['challenge',
#   'accepted',
#   'whos',
#   'paying',
#   'rt',
#   'i',
#   'assume',
#   'can',
#   'find',
#   'us',
#   'an',
#   '<unk>',
#   'gem',
#   'of',
#   'a',
#   'restaurant',
#   'in',
#   '<unk>'],
#  ['then',
#   'from',
#   'far',
#   'away',
#   'across',
#   'the',
#   'world',
#   'he',
#   'smelled',
#   'good',
#   'things',
#   'to',
#   'eat',
#   'so',
#   'he',
#   'gave',
#   'up',
#   'being',
#   'king',
#   'of',
#   'the',
#   'wild',
#   'things',
#   'rip'],
#  ['super', 'webinar', 'jay', 'thanks'],
#  ['have', 'a', 'great', 'one'],
#  ['crap', 'i', 'need', 'to', 'find', 'my', 'book', 'bag'],
#  ['thanks', 'for', 'the', 'recent', 'follows'],
#  ['its', 'am', 'do', 'you', 'know', 'where', 'your', 'children', 'are'],
#  ['congrats', '<unk>'],
#  ['whoa', 'there'],
#  ['you',
#   'obey',
#   'the',
#   'rules',
#   'and',
#   'policies',
#   'of',
#   'the',
#   'businesses',
#   'you',
#   'choose',
#   'to',
#   '<unk>',
#   'you',
#   'do',
#   'not',
#   'create',
#   'ur',
#   'own'],
#  ['all',
#   'them',
#   'ladies',
#   'in',
#   'one',
#   'spot',
#   'working',
#   'tha',
#   'strip',
#   'pole',
#   'got',
#   'ta',
#   'open',
#   '<unk>',
#   '<unk>',
#   'club',
#   'lol'],
#  ['i',
#   'wish',
#   'there',
#   'was',
#   'a',
#   'channel',
#   'for',
#   'all',
#   'the',
#   'old',
#   's',
#   'shows'],
#  ['ima', 'try', 'this', 'sleep', 'thing', 'one', 'more', 'time'],
#  ['let',
#   'me',
#   'find',
#   'u',
#   'took',
#   'a',
#   'vacation',
#   'and',
#   'lost',
#   'all',
#   'your',
#   'money',
#   'with',
#   'out',
#   'inviting',
#   'me',
#   'lol'],
#  ['works',
#   'always',
#   'tiring',
#   'haha',
#   'my',
#   'days',
#   'going',
#   'pretty',
#   'good',
#   'its',
#   'mothers',
#   'day',
#   'so',
#   'just',
#   'happy',
#   'to',
#   'see',
#   'my',
#   'mom',
#   'happy'],
#  ['totally',
#   'addicted',
#   'to',
#   'the',
#   '<unk>',
#   'live',
#   'feed',
#   'cheering',
#   'on',
#   'all',
#   'of',
#   'the',
#   'amazing',
#   'ladies',
#   'competing',
#   'in',
#   'anaheim',
#   'this',
#   'week'],
#  ['well', '<unk>', 'thats', 'the', 'end', 'of', 'that'],
#  ['watching',
#   'season',
#   'college',
#   'new',
#   'intro',
#   'music',
#   'what',
#   'dreams',
#   'may',
#   'come'],
#  ['consider',
#   'posting',
#   'your',
#   'resume',
#   'to',
#   '<unk>',
#   'new',
#   'and',
#   'exciting',
#   'hr',
#   'positions',
#   'posted',
#   'daily'],
#  ['cause', 'youre', 'working', 'on', 's', 'album', 'xd'],
#  ['an',
#   'artist',
#   'must',
#   'have',
#   'his',
#   '<unk>',
#   'tools',
#   'not',
#   'in',
#   'the',
#   'hand',
#   'but',
#   'in',
#   'the',
#   'eye',
#   'happy',
#   'birthday',
#   'to',
#   '<unk>'],
#  ['this', 'game', 'doodle', 'jump', 'is', '<unk>', 'me', 'off'],
#  ['updated',
#   'a',
#   '<unk>',
#   'has',
#   'only',
#   'destroyed',
#   'one',
#   'satellite',
#   'which',
#   'was',
#   'the',
#   'european',
#   'space',
#   '<unk>',
#   '<unk>',
#   'in'],
#  ['love', 'this', '<unk>', 'done', 'xx'],
#  ['today',
#   'pea',
#   '<unk>',
#   '<unk>',
#   'irish',
#   'sausage',
#   'english',
#   'peas',
#   'hash',
#   'brown',
#   'potatoes',
#   '<unk>',
#   'onion',
#   'topped',
#   'with',
#   'jameson',
#   'cheese',
#   'sauce'],
#  ['you',
#   'act',
#   'like',
#   'you',
#   'really',
#   'like',
#   'me',
#   'then',
#   'behind',
#   'my',
#   'back',
#   'all',
#   'you',
#   'do',
#   'is',
#   'flirt',
#   'with',
#   'girls',
#   'not',
#   'cool'],
#  ['follow',
#   'your',
#   'heart',
#   'and',
#   'intuition',
#   'they',
#   'somehow',
#   'already',
#   'know',
#   'what',
#   'you',
#   'truly',
#   'want',
#   'to',
#   'become',
#   'everything',
#   'else',
#   'is',
#   'secondary',
#   'steve',
#   'jobs'],
#  ['it', 'took', 'me', 'minutes', 'to', 'eat', 'one', 'protein', 'bar'],
#  ['and',
#   'they',
#   'try',
#   'to',
#   'fit',
#   'in',
#   'clothes',
#   'they',
#   'cant',
#   'because',
#   'they',
#   'need',
#   'that',
#   'lip',
#   'reader',
#   'to',
#   'tell',
#   'them',
#   'they',
#   'are',
#   'too',
#   'fat',
#   'to',
#   'fit'],
#  ['don',
#   '<unk>',
#   'author',
#   'of',
#   'high',
#   '<unk>',
#   'leadership',
#   'the',
#   'code',
#   'of',
#   'the',
#   'executive',
#   'will',
#   'be',
#   'presenting',
#   'the',
#   'md',
#   'cio',
#   'roundtable',
#   'mtg',
#   'tomorrow'],
#  ['taking', 'care', 'of', 'home', 'then', 'im', 'out'],
#  ['thanks', 'frank', 'for', 'following'],
#  ['anne', 'romney', 'is', 'using', '<unk>'],
#  ['nap',
#   'has',
#   'found',
#   'your',
#   'previous',
#   'reviews',
#   'honest',
#   'and',
#   'full',
#   'the',
#   'review',
#   'of',
#   'i',
#   'am',
#   'breaks',
#   'from',
#   'that',
#   'nap',
#   'wonders',
#   'about',
#   'this'],
#  ['thoughtsduringschool',
#   'i',
#   'hope',
#   'to',
#   'god',
#   'i',
#   'dont',
#   'run',
#   'into',
#   '<unk>',
#   'madden'],
#  ['so',
#   'exciting',
#   'so',
#   'proud',
#   'of',
#   'you',
#   'your',
#   'journey',
#   'and',
#   'what',
#   'youve',
#   'become',
#   'miss',
#   'you',
#   'all'],
#  ['i', 'love', 'yours', 'the', 'most', 'i', 'miss', 'yours'],
#  ['very',
#   'true',
#   'yet',
#   'i',
#   'had',
#   'to',
#   'lose',
#   'at',
#   'least',
#   'the',
#   'stiff',
#   'sense',
#   'of',
#   'i',
#   'to',
#   'know',
#   'that',
#   'to',
#   'be',
#   'so'],
#  ['if',
#   'you',
#   'want',
#   'creative',
#   'workers',
#   'give',
#   'them',
#   'enough',
#   'time',
#   'to',
#   'play',
#   'john',
#   '<unk>',
#   'actor',
#   'comedian',
#   'writer',
#   'and',
#   'film',
#   'producer'],
#  ['<unk>',
#   'hey',
#   'any',
#   'time',
#   'for',
#   'another',
#   '<unk>',
#   'sometime',
#   'soon'],
#  ['belated', 'thanks', 'for', 'the', 'ff'],
#  ['cause', 'you', 'make', 'my', 'heart', 'race'],
#  ['individual', 'academic', '<unk>'],
#  ['<unk>', 'when', 'u', 'with', 'metro', 'pcs'],
#  ['let', 'the', '<unk>', 'festivities', 'commence', '<unk>'],
#  ['chicks',
#   'got',
#   'an',
#   'ass',
#   'like',
#   'an',
#   'onion',
#   'making',
#   'me',
#   'wan',
#   'na',
#   'cry'],
#  ['this',
#   'book',
#   'has',
#   'got',
#   'to',
#   'be',
#   'the',
#   'stupidest',
#   'thing',
#   'ive',
#   'ever',
#   'read',
#   'how',
#   'a',
#   '<unk>',
#   'book',
#   'can',
#   'suck',
#   'this',
#   'hard',
#   'blows',
#   'my',
#   'mind'],
#  ['why', 'did', 'they', 'remake', 'footloose', 'is', 'nothing', 'sacred'],
#  ['lets', 'go', 'heat', '<unk>'],
#  ['rise',
#   'and',
#   'grind',
#   'lets',
#   'get',
#   'it',
#   'today',
#   'just',
#   'kidding',
#   'back',
#   'to',
#   'mw'],
#  ['coke', 'or', 'pepsi', 'lol'],
#  ['happy',
#   'to',
#   'hear',
#   'that',
#   '<unk>',
#   'own',
#   'free',
#   'energy',
#   'is',
#   'coming',
#   'out',
#   'with',
#   'a',
#   'new',
#   'album',
#   'this',
#   '<unk>',
#   'summer',
#   'really',
#   'like',
#   'these',
#   'guys'],
#  ['yep',
#   'and',
#   'yep',
#   'surprisingly',
#   'little',
#   'making',
#   'fun',
#   'but',
#   'i',
#   'made',
#   'sure',
#   'to',
#   'ride',
#   'my',
#   'least',
#   '<unk>',
#   '<unk>',
#   'just',
#   'in',
#   'case',
#   'read',
#   'not',
#   'my',
#   '<unk>'],
#  ['not',
#   'to',
#   'mention',
#   'killing',
#   'it',
#   'in',
#   'two',
#   'separate',
#   'interviews',
#   'in'],
#  ['i',
#   'feel',
#   'like',
#   'a',
#   'lame',
#   'staying',
#   'home',
#   'on',
#   'a',
#   'nice',
#   'saturday',
#   'night',
#   'but',
#   'then',
#   'i',
#   'think',
#   'about',
#   'my',
#   'three',
#   'work',
#   'days',
#   'ahead',
#   'and',
#   'now',
#   'i',
#   'have',
#   'no',
#   'regrets'],
#  ['bon',
#   '<unk>',
#   'makes',
#   '<unk>',
#   'with',
#   '<unk>',
#   'animal',
#   'welfare',
#   'policy'],
#  ['today', 'sucks'],
#  ['edward',
#   'isnt',
#   'a',
#   'vampire',
#   'he',
#   'lives',
#   'in',
#   'the',
#   'forest',
#   'he',
#   'doesnt',
#   'eat',
#   'people',
#   'and',
#   'he',
#   '<unk>',
#   'hes',
#   'obviously',
#   'a',
#   'fairy'],
#  ['thanks', 'dude', 'huge', 'of', 'hits', 'today'],
#  ['what', 'makes', 'you', 'say', 'that'],
#  ['me',
#   'thinks',
#   'its',
#   'gone',
#   'went',
#   'live',
#   'a',
#   'bit',
#   'before',
#   'numbers',
#   'were',
#   'there'],
#  ['thanks',
#   'all',
#   'for',
#   'the',
#   'congratulations',
#   'today',
#   'proud',
#   'to',
#   'contribute',
#   'to',
#   '<unk>',
#   'vibrant',
#   'tech',
#   'community'],
#  ['ive',
#   'hash',
#   'tagged',
#   '<unk>',
#   'so',
#   'damn',
#   'much',
#   'that',
#   'should',
#   'make',
#   'your',
#   'boy',
#   'an',
#   'honorary',
#   'jet',
#   'lol'],
#  ['after',
#   'trying',
#   'to',
#   'make',
#   'this',
#   'dough',
#   'into',
#   'a',
#   'perfect',
#   'even',
#   'circle',
#   'i',
#   'just',
#   'want',
#   'to',
#   'say',
#   'that',
#   'i',
#   'love',
#   'people',
#   'who',
#   'professionally',
#   'make',
#   'pizza'],
#  ['im', 'missing', 'this', 'panda', 'person'],
#  ['a',
#   'movie',
#   'its',
#   'really',
#   'rude',
#   'haha',
#   'aww',
#   'have',
#   'fun',
#   'i',
#   'was',
#   'having',
#   'friend',
#   'to',
#   'sleep',
#   'but',
#   'she',
#   'canceled',
#   'x'],
#  ['im', 'a', 'bitch', 'deal', 'with', 'it'],
#  ['i',
#   'hate',
#   'getting',
#   'a',
#   'trim',
#   'i',
#   'feel',
#   'like',
#   'shes',
#   'gon',
#   'na',
#   'accidentally',
#   'cut',
#   'off',
#   'too',
#   'much'],
#  ['begin',
#   'to',
#   'wonder',
#   'if',
#   '<unk>',
#   'message',
#   'is',
#   'starting',
#   'to',
#   'go',
#   '<unk>',
#   'in',
#   'locker',
#   'room',
#   'yrs',
#   'with',
#   'the',
#   'team',
#   'and',
#   'no',
#   'progress'],
#  ['natalie',
#   'on',
#   'today',
#   'used',
#   'pier',
#   '<unk>',
#   'splash',
#   'makes',
#   'national',
#   'news',
#   'on',
#   'wisconsin'],
#  ['rt',
#   'i',
#   'heard',
#   'that',
#   'april',
#   'is',
#   'wear',
#   'a',
#   '<unk>',
#   'in',
#   'solidarity',
#   'month',
#   'is',
#   'this',
#   'just',
#   'in',
#   'san',
#   'diego'],
#  ['need', 'to', 'go', 'somewhere'],
#  ['not',
#   'found',
#   'a',
#   'single',
#   '<unk>',
#   '<unk>',
#   'for',
#   '<unk>',
#   'collins',
#   'plays',
#   'ca',
#   'in',
#   'our',
#   'magnificent',
#   '<unk>',
#   'collection',
#   'cant',
#   'win',
#   'em',
#   'all'],
#  ['merry', 'christmas', 'have', 'a', 'great', 'day'],
#  ['be',
#   'on',
#   'the',
#   'lookout',
#   'my',
#   'latest',
#   'all',
#   'house',
#   'edm',
#   'mix',
#   'entitled',
#   'i',
#   'put',
#   'my',
#   '<unk>',
#   'on',
#   'volume',
#   'on',
#   'the',
#   'th',
#   'of',
#   'this',
#   'month',
#   'every',
#   'month',
#   'after'],
#  ['relieve',
#   'pain',
#   'shoes',
#   'control',
#   'the',
#   'way',
#   'ur',
#   'foot',
#   'rolls',
#   'w',
#   'the',
#   'right',
#   'amount',
#   'of',
#   'force',
#   'stability',
#   '<unk>',
#   'foot',
#   'leg',
#   'hip',
#   'back',
#   'pain'],
#  ['in',
#   'your',
#   'opinion',
#   'other',
#   'than',
#   'lack',
#   'of',
#   'quality',
#   'communication',
#   'and',
#   'finances',
#   'why',
#   'do',
#   'intimate',
#   'relationships',
#   'fail'],
#  ['i',
#   'just',
#   'seen',
#   'someone',
#   'that',
#   'has',
#   'a',
#   'face',
#   'even',
#   'an',
#   'instagram',
#   'filter',
#   'couldnt',
#   'fix'],
#  ['i',
#   'refuse',
#   'to',
#   'let',
#   'someone',
#   'elses',
#   'anger',
#   'hurt',
#   'destroy',
#   'my',
#   'spirit',
#   'i',
#   'am',
#   'made',
#   'new',
#   'in',
#   'god',
#   'thru',
#   'him',
#   'alone',
#   'i',
#   'take',
#   '<unk>'],
#  ['if',
#   'you',
#   'could',
#   'choose',
#   'one',
#   'last',
#   'great',
#   'edit',
#   'what',
#   'would',
#   'it',
#   'be',
#   'a',
#   'movie',
#   'documentary',
#   'commercial',
#   'news',
#   'package'],
#  ['no',
#   'as',
#   'long',
#   'as',
#   'the',
#   'adaptation',
#   'isnt',
#   '<unk>',
#   'trying',
#   'to',
#   'make',
#   'a',
#   'modern',
#   '<unk>',
#   'point',
#   'im',
#   'happy',
#   'to',
#   'play',
#   'along'],
#  ['tune', 'in', 'to', 'on', 'am', 'in', 'a', 'few', 'im', 'talking'],
#  ['i', 'hate', 'to', 'see', 'what', 'jealousy', 'can', 'create'],
#  ['go',
#   'to',
#   'thunder',
#   'bay',
#   'ontario',
#   'where',
#   'they',
#   'have',
#   'a',
#   'hr',
#   'booze',
#   'taxi'],
#  ['<unk>', 'and', '<unk>', 'minor', 'league', '<unk>'],
#  ['who',
#   'are',
#   'some',
#   'of',
#   '<unk>',
#   '<unk>',
#   'heres',
#   'a',
#   'hint',
#   'jackson',
#   '<unk>',
#   'and',
#   'mark',
#   '<unk>'],
#  ['tips', 'on', 'how', 'to', 'get', 'a', 'flat', 'stomach', '<unk>'],
#  ['so',
#   'weird',
#   'to',
#   'look',
#   'in',
#   'the',
#   '<unk>',
#   'of',
#   'someone',
#   'you',
#   'interact',
#   'with',
#   'regularly',
#   'and',
#   'see',
#   'all',
#   'kinds',
#   'of',
#   '<unk>',
#   'stuff'],
#  ['thanks', 'for', 'the', 'shout', 'out'],
#  ['good', 'idea'],
#  ['salt',
#   'lake',
#   'city',
#   'for',
#   'the',
#   'weekend',
#   'to',
#   'celebrate',
#   'birthdays'],
#  ['families',
#   'spending',
#   'over',
#   'on',
#   'prom',
#   'this',
#   'year',
#   'we',
#   'make',
#   'prom',
#   'dreams',
#   'cone',
#   'true',
#   'for',
#   'not',
#   'even',
#   'of',
#   'that'],
#  ['headed', 'to', '<unk>', '<unk>', 'for', 'owens', 'birthday'],
#  ['wow',
#   'thats',
#   'a',
#   '<unk>',
#   'foul',
#   'jones',
#   'did',
#   'not',
#   'knock',
#   'noah',
#   'to',
#   'the',
#   'floor',
#   'bad',
#   'call'],
#  ['i',
#   'wish',
#   'i',
#   'could',
#   'dance',
#   'so',
#   'jealous',
#   'of',
#   'people',
#   'who',
#   'can',
#   'hahaha'],
#  ['thx',
#   'sitting',
#   'on',
#   'a',
#   'bus',
#   'right',
#   'now',
#   'waiting',
#   'to',
#   'march',
#   'in',
#   'mlk',
#   'parade',
#   'with',
#   'its',
#   'always',
#   'a',
#   'fun',
#   'cold',
#   'event'],
#  ['still', 'pissed', 'the', 'as', 'didnt', 'sign', 'him'],
#  ['both', 'thumbs', 'sprained', 'awesome'],
#  ['rt',
#   'this',
#   'latest',
#   'post',
#   'goes',
#   'out',
#   'to',
#   'the',
#   'beer',
#   'that',
#   'made',
#   'milwaukee',
#   'famous'],
#  ['anyways',
#   'at',
#   '<unk>',
#   '<unk>',
#   'to',
#   'work',
#   '<unk>',
#   '<unk>',
#   'tonight'],
#  ['haha',
#   'its',
#   'not',
#   'except',
#   'they',
#   'had',
#   '<unk>',
#   'purple',
#   'haze',
#   'on',
#   'tap',
#   'and',
#   'had',
#   'been',
#   '<unk>',
#   'me',
#   'to',
#   'try'],
#  ['i',
#   'hear',
#   'is',
#   'gon',
#   'na',
#   'be',
#   'on',
#   'a',
#   'show',
#   'on',
#   'cbs',
#   'in',
#   'like',
#   'a',
#   'a',
#   'min'],
#  ['<unk>',
#   'she',
#   'lays',
#   'on',
#   'her',
#   'stomach',
#   'while',
#   '<unk>',
#   'my',
#   'dick',
#   'as',
#   'i',
#   'rub',
#   'massage',
#   'and',
#   'smack',
#   'that',
#   '<unk>',
#   'retweet'],
#  ['this',
#   'is',
#   'needed',
#   'in',
#   'advance',
#   'a',
#   'gigantic',
#   'thank',
#   'you',
#   'for',
#   'all',
#   'of',
#   'the',
#   'advice'],
#  ['happy', 'birthday'],
#  ['woke',
#   'up',
#   'to',
#   'the',
#   'alarm',
#   'going',
#   'off',
#   'because',
#   'someone',
#   'just',
#   'tried',
#   'to',
#   'break',
#   'in',
#   'our',
#   'house',
#   'i',
#   'need',
#   'a',
#   'gun',
#   'or',
#   'a',
#   'man',
#   'with',
#   'one'],
#  ['what',
#   'you',
#   'got',
#   'your',
#   'mom',
#   'flowers',
#   'bitch',
#   'i',
#   'got',
#   'my',
#   'mom',
#   'a',
#   'fucking',
#   'tree'],
#  ['omg', 'im', 'starving'],
#  ['big', 'gun'],
#  ['just',
#   'saw',
#   'secretary',
#   'of',
#   'state',
#   'hillary',
#   'clinton',
#   'speak',
#   'at',
#   'georgetown',
#   'university'],
#  ['hr',
#   'rep',
#   '<unk>',
#   'online',
#   'poker',
#   'act',
#   'raises',
#   'wo',
#   'raising',
#   'taxes',
#   'plz',
#   'support',
#   'on',
#   'deficit',
#   '<unk>',
#   'thx'],
#  ['thanks',
#   'so',
#   'much',
#   'for',
#   'your',
#   'vote',
#   'to',
#   '<unk>',
#   'tell',
#   'us',
#   'in',
#   'a',
#   'tweet',
#   'why',
#   'does',
#   'the',
#   'alice',
#   '<unk>',
#   'house',
#   'matter',
#   'to',
#   'you'],
#  ['nice', '<unk>'],
#  ['for',
#   'some',
#   'reason',
#   'i',
#   'am',
#   'feeling',
#   'cocky',
#   'and',
#   'happily',
#   'independent',
#   'today',
#   'headed',
#   'for',
#   'the',
#   '<unk>',
#   'totally',
#   'green',
#   'independent',
#   'farmers',
#   'market'],
#  ['you',
#   'truly',
#   'are',
#   'a',
#   'blessing',
#   'on',
#   'this',
#   'earth',
#   'and',
#   'a',
#   'wonderful',
#   'mother',
#   'and',
#   'friend'],
#  ['nice', 'to', 'virtually', 'meet', 'you'],
#  ['people',
#   'who',
#   'follow',
#   'me',
#   'on',
#   'here',
#   'please',
#   'follow',
#   'my',
#   'other',
#   'account',
#   'im',
#   'going',
#   'to',
#   'delete',
#   'this',
#   '<unk>',
#   'very',
#   'soon',
#   'thanks',
#   'xx'],
#  ['nah',
#   'its',
#   '<unk>',
#   'radio',
#   'decisions',
#   'are',
#   'ultimately',
#   'about',
#   'ratings',
#   'and',
#   'revenue',
#   'hence',
#   'the',
#   '<unk>',
#   'of',
#   'air',
#   'america'],
#  ['are', 'you', 'going', 'to', 'kiss', 'me', 'or', 'not'],
#  ['<unk>',
#   'sry',
#   'i',
#   'like',
#   'to',
#   'debate',
#   'always',
#   'surprised',
#   'by',
#   'what',
#   'ppl',
#   'say',
#   'when',
#   'challenged',
#   'that',
#   'is',
#   'when',
#   'the',
#   'best',
#   'ideas',
#   'happen'],
#  ['i', 'miss', 'you', 'lets', 'hang', 'out', 'soon'],
#  ['its',
#   'a',
#   'beautiful',
#   'day',
#   'a',
#   'beautiful',
#   'marriage',
#   'starts',
#   'with',
#   'the',
#   '<unk>',
#   'ultimate',
#   'wedding',
#   'package'],
#  ['i', 'go', 'with', 'them', 'bron', '<unk>'],
#  ['other', 'times', 'i', 'wish', 'i', 'lived', 'in', 'new', 'york', 'city'],
#  ['how',
#   'the',
#   'heck',
#   'am',
#   'i',
#   'supposed',
#   'to',
#   'quote',
#   '<unk>',
#   'his',
#   'sentences',
#   'are',
#   'as',
#   'long',
#   'as',
#   'my',
#   'whole',
#   'essay'],
#  ['i',
#   'wonder',
#   'if',
#   'you',
#   'could',
#   'use',
#   'js',
#   'to',
#   'control',
#   'an',
#   'animated',
#   'gif',
#   'the',
#   'same',
#   'way',
#   'you',
#   'use',
#   'css',
#   'to',
#   'control',
#   '<unk>'],
#  ['blowing',
#   'up',
#   'this',
#   'isnt',
#   'indiana',
#   'we',
#   'dont',
#   'have',
#   'any',
#   'fireworks'],
#  ['putting', 'it', 'out', 'there', 'just', 'gives', 'it', 'life'],
#  ['when', 'i', 'get', 'bored', 'i', 'get', 'mad', 'lol'],
#  ['i',
#   'cant',
#   'wait',
#   'until',
#   'tonights',
#   'game',
#   'i',
#   'feel',
#   'like',
#   'im',
#   'playing'],
#  ['sup',
#   '<unk>',
#   'sure',
#   'u',
#   '<unk>',
#   'me',
#   'luke',
#   'waters',
#   'friend',
#   'met',
#   'u',
#   'in',
#   '<unk>',
#   'keep',
#   'up',
#   'the',
#   'good',
#   'work',
#   'for',
#   'the',
#   'lord',
#   'congrats',
#   'on',
#   'a',
#   'good',
#   'yr'],
#  ['james',
#   '<unk>',
#   'james',
#   '<unk>',
#   'james',
#   '<unk>',
#   'james',
#   '<unk>',
#   'inside',
#   'the',
#   'actors',
#   'studio',
#   'on',
#   'the',
#   'last',
#   'word',
#   'with',
#   'lawrence',
#   '<unk>'],
#  ['its', '<unk>', '<unk>', 'no', 'work', 'party', 'party'],
#  ['bourbon',
#   'is',
#   'always',
#   'a',
#   'good',
#   'idea',
#   'i',
#   'mean',
#   'it',
#   'is',
#   'usually',
#   'except',
#   'for',
#   'when',
#   'it',
#   'isnt'],
#  ['sure',
#   'same',
#   'number',
#   'or',
#   'is',
#   'live',
#   'at',
#   'the',
#   'scene',
#   'if',
#   'you',
#   'want',
#   'her',
#   'to',
#   'describe',
#   'it',
#   'for',
#   'you',
#   'here',
#   'to',
#   'help'],
#  ['people',
#   'that',
#   'wait',
#   'until',
#   'i',
#   'do',
#   'days',
#   'of',
#   'research',
#   'to',
#   'figure',
#   'something',
#   'out',
#   'then',
#   'make',
#   'a',
#   'suggestion'],
#  ['rt',
#   'ive',
#   'submitted',
#   'two',
#   'workshop',
#   'proposals',
#   'for',
#   'a',
#   'letter',
#   'writing',
#   'workshop',
#   'one',
#   'for',
#   'another',
#   '<unk>',
#   'organizers',
#   'event'],
#  ['dang',
#   'most',
#   'cliche',
#   'crime',
#   'americans',
#   'fear',
#   'did',
#   'happen',
#   'cruise',
#   'passengers',
#   'on',
#   'tour',
#   'bus',
#   'held',
#   'up',
#   'at',
#   '<unk>',
#   'in',
#   'mexico',
#   'hard',
#   'country',
#   'to',
#   'sell'],
#  ['over',
#   'glen',
#   'davis',
#   'got',
#   'around',
#   'mil',
#   'per',
#   'year',
#   'over',
#   'years'],
#  ['key', 'to', 'startup', 'success', 'be', 'boring'],
#  ['back', 'in', 'the', 'game', 'thank', 'you', 'rangers'],
#  ['i',
#   'was',
#   'having',
#   'a',
#   'discussion',
#   'the',
#   'other',
#   'day',
#   'if',
#   'you',
#   'had',
#   'a',
#   'chance',
#   'to',
#   'live',
#   'years',
#   'longer',
#   'or',
#   'dollars',
#   'which',
#   'one',
#   'would',
#   'you',
#   'choose'],
#  ['she',
#   'just',
#   'wanted',
#   'to',
#   'know',
#   'what',
#   'it',
#   'felt',
#   'like',
#   'to',
#   'be',
#   'the',
#   'man',
#   'the',
#   'myth',
#   'the',
#   'legend',
#   'hahaha'],
#  ['did',
#   'you',
#   '<unk>',
#   'the',
#   'blue',
#   'goofy',
#   'jackets',
#   'at',
#   'the',
#   '<unk>',
#   'expo',
#   'they',
#   'are',
#   'pretty',
#   'sweet'],
#  ['is', 'there', 'a', 'taping', 'tonight'],
#  ['decorating',
#   'the',
#   'apartment',
#   'for',
#   'next',
#   'year',
#   'rt',
#   'just',
#   'saw',
#   'a',
#   '<unk>',
#   'and',
#   'barrel',
#   'truck',
#   'and',
#   'wanted',
#   'to',
#   'rob',
#   'it'],
#  ['see', 'yu', 'later'],
#  ['our',
#   'students',
#   'are',
#   'currently',
#   'talking',
#   'about',
#   'proposed',
#   'budget',
#   'cuts'],
#  ['i',
#   'like',
#   'it',
#   'prefer',
#   'my',
#   'canadian',
#   'club',
#   'however',
#   'hey',
#   'coach',
#   'first',
#   'question',
#   'how',
#   'do',
#   'you',
#   'feel',
#   'about',
#   'iron',
#   'city',
#   'beer'],
#  ['if',
#   'i',
#   'was',
#   'your',
#   'hubby',
#   'those',
#   'tits',
#   'would',
#   'be',
#   '<unk>',
#   '<unk>',
#   'and',
#   '<unk>',
#   'every',
#   'single',
#   'day',
#   'not',
#   'to',
#   'mention',
#   '<unk>',
#   'sucked'],
#  ['try', 'new', 'york'],
#  ['i', 'your', 'tweets', 'so', 'much', 'they', 'inspire', 'me'],
#  ['thank', 'you', 'for', 'asking', 'folks', 'to', 'follow', 'me', 'and'],
#  ['hey', 'figure', 'out', 'what', 'shelby', 'wants', 'for', 'her', 'birthday'],
#  ['start', 'at', '<unk>', 'next', 'week'],
#  ['yea',
#   'im',
#   'always',
#   'his',
#   'regret',
#   'yea',
#   'im',
#   'always',
#   'his',
#   'regret'],
#  ['thats',
#   'a',
#   'weird',
#   'combo',
#   'but',
#   'a',
#   'good',
#   'one',
#   'check',
#   'me',
#   'out',
#   'fam',
#   '<unk>',
#   'dope',
#   'gear'],
#  ['will', 'def', 'check', 'out', 'your', 'blog', 'looking', 'forward', 'f'],
#  ['no',
#   'internet',
#   '<unk>',
#   'not',
#   'follow',
#   'back',
#   'my',
#   'followers',
#   'until',
#   'internet',
#   'is',
#   'set',
#   'up'],
#  ['dodgers', '<unk>', '<unk>', 'put', 'on', 'disabled', 'list'],
#  ['hahahaha', 'those', 'are', 'far', 'from', 'dead'],
#  ['nothing',
#   'like',
#   'a',
#   'burger',
#   'from',
#   '<unk>',
#   'on',
#   'a',
#   'beautiful',
#   'night',
#   'in',
#   'springfield',
#   'mo',
#   '<unk>',
#   '<unk>',
#   'cc',
#   'yum'],
#  ['i', 'am', 'so', 'grateful', 'for', 'you', 'have', 'great', 'days'],
#  ['cheers',
#   'to',
#   'taking',
#   'a',
#   'random',
#   'free',
#   'shot',
#   'with',
#   'sketchy',
#   'bartender',
#   'on',
#   'your',
#   'way',
#   'back',
#   'from',
#   'the',
#   'gym',
#   '<unk>',
#   '<unk>'],
#  ['i',
#   'think',
#   'but',
#   'i',
#   'think',
#   'they',
#   'actually',
#   'helped',
#   'blocking',
#   'the',
#   'ball',
#   'it',
#   'couldve',
#   'been',
#   'worse'],
#  ['man',
#   'jeff',
#   'teague',
#   'just',
#   'had',
#   'one',
#   'of',
#   'the',
#   'best',
#   'blocks',
#   'ive',
#   'seen',
#   'this',
#   'year'],
#  ['have',
#   'you',
#   'tried',
#   'the',
#   '<unk>',
#   '<unk>',
#   'they',
#   'are',
#   'delicious',
#   'a',
#   'big',
#   'thanks',
#   'to'],
#  ['all', 'hail', '<unk>', 'man'],
#  ['maybe',
#   'if',
#   'i',
#   'was',
#   'a',
#   'girl',
#   'who',
#   'wore',
#   'barely',
#   'any',
#   'clothes',
#   'and',
#   'posted',
#   'body',
#   'shots',
#   'by',
#   'the',
#   'pool',
#   'then',
#   'my',
#   'instagram',
#   'would',
#   'get',
#   'thousands',
#   'of',
#   'followers'],
#  ['with',
#   'handling',
#   'image',
#   'download',
#   'after',
#   'shooting',
#   'richard',
#   'chai'],
#  ['never',
#   'hate',
#   'people',
#   'wha',
#   'are',
#   'jealous',
#   'of',
#   'you',
#   'but',
#   'respect',
#   'their',
#   'jealousy',
#   'theyre',
#   'there',
#   'people',
#   'who',
#   'think',
#   'youre',
#   'better',
#   'than',
#   'them'],
#  ['about',
#   'for',
#   'my',
#   'tattoo',
#   'hell',
#   'yeah',
#   'think',
#   'ill',
#   'be',
#   'gettin',
#   'that',
#   '<unk>',
#   'real',
#   'soon'],
#  ['thx',
#   'we',
#   'enjoyed',
#   'a',
#   'great',
#   'day',
#   'today',
#   'with',
#   'thanks',
#   'david',
#   'cc'],
#  ['just',
#   'putting',
#   'finishing',
#   'touches',
#   'on',
#   'story',
#   'about',
#   'year',
#   'old',
#   'driver',
#   'pulled',
#   'from',
#   'burning',
#   'car',
#   'shes',
#   'got',
#   'quite',
#   'a',
#   'story',
#   'to',
#   'tell',
#   'airs',
#   'in',
#   'min'],
#  ['thanks', 'kay'],
#  ['thanks',
#   'to',
#   'to',
#   'all',
#   'the',
#   'people',
#   'who',
#   'came',
#   'out',
#   'for',
#   'a',
#   'great',
#   'night',
#   'saturday',
#   'hope',
#   'to',
#   'play',
#   'there',
#   'again',
#   'really',
#   'soon'],
#  ['is',
#   'the',
#   'funniest',
#   'nigga',
#   'on',
#   'my',
#   'timeline',
#   'got',
#   'me',
#   'rollin'],
#  ['ok', 'bro', 'im', 'out', 'talk', 'to', 'u', 'tomorrow'],
#  ['thanks', 'will', 'keep', 'trying'],
#  ['angels', 'walk', 'off', 'win', 'in', 'extra', 'frames'],
#  ['its',
#   'always',
#   'fun',
#   'seeing',
#   'a',
#   'what',
#   'they',
#   'think',
#   'is',
#   'a',
#   'dynamite',
#   'turn',
#   'into',
#   'a',
#   'little',
#   '<unk>',
#   '<unk>',
#   'thankyou',
#   'come',
#   'again',
#   'wish',
#   'you',
#   'had',
#   'tried',
#   'harder'],
#  ['ur', 'to', 'gangsta', 'to', 'kick', 'it', 'with', 'me', 'haha'],
#  ['rt',
#   '<unk>',
#   'concrete',
#   'atlanta',
#   'ga',
#   'acid',
#   'stain',
#   'floors',
#   'etc',
#   'and',
#   '<unk>',
#   'concrete',
#   '<unk>',
#   '<unk>',
#   '<unk>',
#   'etc',
#   '<unk>'],
#  ['to',
#   'be',
#   'honest',
#   'i',
#   'barely',
#   'ever',
#   'read',
#   'him',
#   'anymore',
#   'he',
#   'could',
#   'have',
#   'changed',
#   'it',
#   'i',
#   'wouldnt',
#   'even',
#   'know'],
#  ['ill',
#   'definitely',
#   'visit',
#   '<unk>',
#   'and',
#   '<unk>',
#   'when',
#   'im',
#   'there',
#   'craving',
#   'for',
#   'some',
#   'effing',
#   '<unk>'],
#  ['<unk>',
#   'theres',
#   'never',
#   'been',
#   'a',
#   'better',
#   'time',
#   'to',
#   'make',
#   'a',
#   'paper',
#   'based',
#   'book'],
#  ['went',
#   'book',
#   'shopping',
#   'today',
#   'for',
#   'the',
#   'first',
#   'time',
#   'in',
#   'months',
#   'better',
#   'than',
#   'sex'],
#  ['is',
#   'it',
#   'weird',
#   'that',
#   'i',
#   'just',
#   'got',
#   'hit',
#   'by',
#   'a',
#   '<unk>',
#   'and',
#   'after',
#   'i',
#   'kicked',
#   'him',
#   'off',
#   'his',
#   'bike',
#   'yeah',
#   'that',
#   'just',
#   'happened'],
#  ['the',
#   'store',
#   'where',
#   'i',
#   'buy',
#   'most',
#   'of',
#   'my',
#   'cigarettes',
#   'has',
#   'newport',
#   '<unk>',
#   'significantly',
#   'cheaper',
#   'than',
#   'regular',
#   '<unk>'],
#  ['<unk>',
#   '<unk>',
#   'joins',
#   'ricky',
#   'martin',
#   'and',
#   'in',
#   'american',
#   'cancer',
#   'society',
#   '<unk>',
#   'campaign'],
#  ['the', 'intellect', 'never', 'helped', 'anyone', 'only', 'love', 'does'],
#  ['id', 'dedicate', 'everybodys', 'workin', 'for', 'the', 'weekend'],
#  ['they', 'are', 'doing', 'it', 'for', 'chipper', 'jones', 'too', 'idiots'],
#  ['good',
#   'morning',
#   'venues',
#   'event',
#   'promoters',
#   'contact',
#   'us',
#   'if',
#   'youd',
#   'like',
#   'to',
#   'use',
#   'social',
#   'phenom',
#   'of',
#   '<unk>',
#   'to',
#   'promote',
#   'sell',
#   'out',
#   'ur',
#   'events'],
# ...
#   'some',
#   'librarians',
#   'should',
#   'learn',
#   'to',
#   'program',
#   'some',
#   'programmers',
#   'should',
#   'learn',
#   '<unk>'],
#  ['i', 'mess', 'wit', 'the', 'song', 'amen', 'heavy', 'bra'],
#  ['i', 'watch', 'ur', 'show', 'everyday', 'love', 'u', 'girl'],
#  ['getting',
#   'ready',
#   'for',
#   'revival',
#   'service',
#   'tonight',
#   'at',
#   'river',
#   'of',
#   'life',
#   'in',
#   '<unk>',
#   'tn'],
#  ['thanks',
#   'for',
#   'the',
#   'shout',
#   'out',
#   '<unk>',
#   'will',
#   'we',
#   'be',
#   'seeing',
#   'you',
#   'at',
#   'the',
#   'went',
#   'tonight'],
#  ['rip', 'heavy', 'd'],
#  ['my', 'favorite', 'coco', '<unk>', 'pretty', 'good', 'also'],
#  ['yes', 'i', 'think', 'so', 'too'],
#  ['who',
#   'drinks',
#   'beers',
#   'at',
#   'their',
#   'kids',
#   'soccer',
#   'games',
#   'must',
#   'be',
#   'an',
#   'illinois',
#   'thing'],
#  ['dinner', 'beers', 'ncaa', 'tourney'],
#  ['love',
#   'to',
#   'all',
#   'of',
#   'my',
#   'followers',
#   'and',
#   'ones',
#   'that',
#   'will',
#   'become',
#   'my',
#   'followers',
#   'and',
#   'every',
#   'else',
#   'out',
#   'there',
#   'love',
#   'u',
#   'and',
#   'now',
#   'i',
#   'am',
#   'getting',
#   'off',
#   'of',
#   'twitter',
#   'ily'],
#  ['the',
#   'secret',
#   'of',
#   '<unk>',
#   'is',
#   'knowing',
#   'how',
#   'to',
#   'enjoy',
#   'what',
#   'you',
#   'have',
#   'and',
#   'to',
#   'be',
#   'able',
#   'to',
#   'lose',
#   'all',
#   'desire',
#   'for',
#   'the',
#   'things',
#   'beyond',
#   'your',
#   'reach'],
#  ['if',
#   'you',
#   'could',
#   'golf',
#   'w',
#   'any',
#   'local',
#   'portland',
#   'celebrity',
#   'who',
#   'would',
#   'it',
#   'be'],
#  ['are',
#   'you',
#   'still',
#   'not',
#   'going',
#   'to',
#   'enter',
#   'in',
#   'the',
#   'contest'],
#  ['yea', 'too', 'bad', 'i', 'missed', 'that', 'was', 'quite', 'the', 'mess'],
#  ['first',
#   'show',
#   'for',
#   'the',
#   'pinch',
#   'on',
#   'friday',
#   'at',
#   'pm',
#   'or',
#   'so',
#   'at',
#   'the',
#   'triple',
#   'rock',
#   'im',
#   'ready'],
#  ['get',
#   'yo',
#   'gee',
#   'tar',
#   'on',
#   'acoustic',
#   'or',
#   'electric',
#   '<unk>',
#   'close'],
#  ['i', 'can', 'seriously', 'not', 'get', 'enough', 'of', '<unk>', 'by', 'jlo'],
#  ['yea',
#   'yea',
#   'thats',
#   'more',
#   'obsession',
#   'than',
#   'luv',
#   'but',
#   'whatever',
#   'i',
#   'think',
#   'we',
#   'should',
#   'go',
#   'to',
#   'sleep',
#   'soon',
#   'its',
#   'almost',
#   '<unk>',
#   'nd',
#   'we',
#   'have',
#   'skool',
#   'tom'],
#  ['via',
#   'tickets',
#   'for',
#   'match',
#   'against',
#   'sounders',
#   'fc',
#   'on',
#   'go',
#   'on',
#   'sale',
#   'today',
#   'at',
#   'am',
#   'last',
#   'years',
#   'match',
#   'sold',
#   'out',
#   'dont',
#   'wait'],
#  ['its',
#   'a',
#   'snake',
#   'skin',
#   'no',
#   'its',
#   'a',
#   'used',
#   'condom',
#   'lmfao',
#   'hangover',
#   'lmfao'],
#  ['if',
#   'ronpaul',
#   'well',
#   'per',
#   '<unk>',
#   'pulls',
#   'votes',
#   'from',
#   'obama',
#   'is',
#   '<unk>',
#   'the',
#   'new',
#   '<unk>',
#   'may',
#   'hope',
#   'not'],
#  ['smokin',
#   'deals',
#   'on',
#   '<unk>',
#   'ipods',
#   'off',
#   'all',
#   'orders',
#   'on',
#   'the',
#   'website',
#   'just',
#   'type',
#   'in',
#   '<unk>'],
#  ['ppl',
#   'are',
#   'celebrating',
#   'justice',
#   'not',
#   'death',
#   'chill',
#   'with',
#   'all',
#   'that',
#   'super',
#   'deep',
#   'nonsense',
#   'eye',
#   'for',
#   'an',
#   'eye',
#   'if',
#   'u',
#   'live',
#   'by',
#   'the',
#   'sword',
#   'youll',
#   'die',
#   'by',
#   'it'],
#  ['looks', 'like', 'magazines', 'to', 'me'],
#  ['does',
#   'anyone',
#   'know',
#   'a',
#   'way',
#   'to',
#   'view',
#   'the',
#   'activity',
#   'of',
#   'that',
#   'external',
#   'applications',
#   'that',
#   'i',
#   'have',
#   'connected',
#   'to',
#   'my',
#   'twitter',
#   'account'],
#  ['the', 'hard', 'times', 'of', '<unk>', '<unk>', 'is', 'so', 'funny'],
#  ['we',
#   'are',
#   'going',
#   'play',
#   'the',
#   'powerful',
#   'international',
#   'basketball',
#   'team',
#   '<unk>',
#   '<unk>',
#   'on',
#   'tuesday',
#   'at',
#   'grant',
#   'high',
#   'school',
#   '<unk>'],
#  ['i',
#   'wont',
#   'be',
#   'leaving',
#   'sweet',
#   'tweets',
#   'like',
#   'i',
#   'usually',
#   'do',
#   'but',
#   'im',
#   'still',
#   'here',
#   'in',
#   'spirit',
#   'some',
#   'bull',
#   'junk',
#   'happened',
#   'got',
#   'ta',
#   'clean',
#   'it',
#   'up',
#   '<unk>'],
#  ['pens',
#   'winning',
#   'after',
#   'the',
#   'first',
#   'and',
#   'i',
#   'couldnt',
#   'be',
#   'happier'],
#  ['noo',
#   'no',
#   'no',
#   'i',
#   'need',
#   'to',
#   'wake',
#   'up',
#   'and',
#   'get',
#   'to',
#   'school',
#   'are',
#   'you',
#   'going',
#   'to',
#   'bed',
#   'right',
#   '<unk>'],
#  ['a', 'proper', 'response', 'is', 'i', 'love', 'u', 'too'],
#  ['stop', 'shooting', 's'],
#  ['birthday', 'swagger'],
#  ['swear', 'i', 'rt', 'everything', 'when', 'im', 'high'],
#  ['do', 'you', 'like', 'edgar', 'allan'],
#  ['haha',
#   'and',
#   'thats',
#   'cuz',
#   'youre',
#   '<unk>',
#   'awesome',
#   'thank',
#   'you',
#   'ive',
#   'never',
#   'gotten',
#   'even',
#   'half',
#   'that',
#   'many',
#   'views',
#   'before',
#   'on',
#   'a',
#   'video'],
#  ['i', 'need', 'a', 'good', 'weekend'],
#  ['whoa', 'missed', '<unk>', 'belated', '<unk>'],
#  ['i',
#   'said',
#   'one',
#   'smile',
#   'at',
#   'a',
#   'time',
#   'sounds',
#   '<unk>',
#   'lmao',
#   '<unk>',
#   'p',
#   'omg',
#   'i',
#   'got',
#   'a',
#   'in',
#   'my',
#   'report',
#   'card',
#   'for',
#   'history',
#   's'],
#  ['your', 'welcome', 'xox'],
#  ['<unk>',
#   'are',
#   '<unk>',
#   'until',
#   'you',
#   'are',
#   'born',
#   'then',
#   'they',
#   'throw',
#   'you',
#   'under',
#   'the',
#   'bus'],
#  ['someone',
#   'force',
#   'me',
#   'to',
#   'clean',
#   'my',
#   'room',
#   'tonight',
#   'so',
#   'my',
#   'husband',
#   'will',
#   'let',
#   'me',
#   'take',
#   'to',
#   'see',
#   'cabin',
#   'in',
#   'the',
#   'woods',
#   'tomorrow',
#   'hes',
#   'so',
#   'mean'],
#  ['haha',
#   'ill',
#   'be',
#   'sure',
#   'to',
#   'relay',
#   'your',
#   'review',
#   'to',
#   'them',
#   'whenever',
#   'we',
#   'eventually',
#   'bump',
#   'into',
#   'each',
#   'other',
#   'in',
#   'the',
#   'hallway'],
#  ['you', 'have', 'an', 'awesome', 'job'],
#  ['i', 'heard', 'of', 'them', 'they', 'are', 'good'],
#  ['is', 'really', 'rocking', 'it'],
#  ['i', 'didnt', 'win', 'did', 'i'],
#  ['<unk>',
#   'interviewing',
#   'the',
#   'actor',
#   'bill',
#   '<unk>',
#   'tonight',
#   'he',
#   'plays',
#   'mr',
#   '<unk>',
#   'on',
#   'wizards',
#   'of',
#   '<unk>',
#   'place',
#   '<unk>',
#   'in',
#   'the',
#   'ringer'],
#  ['one', 'week', 'closer', 'to', 'summer'],
#  ['time', 'for', 'the', 'avengers'],
#  ['no',
#   'you',
#   'dont',
#   'the',
#   '<unk>',
#   'ladies',
#   'in',
#   'the',
#   'commercial',
#   'use',
#   'the',
#   'word',
#   'juicy',
#   'way',
#   'too',
#   'much'],
#  ['looking',
#   'into',
#   'an',
#   'email',
#   'issue',
#   'with',
#   'the',
#   '<unk>',
#   'be',
#   'fixed',
#   'soon'],
#  ['thats',
#   'funny',
#   'and',
#   'i',
#   'had',
#   'exactly',
#   'the',
#   'same',
#   'idea',
#   'on',
#   'the',
#   'way',
#   'over',
#   'here'],
#  ['thanks', 'for', 'the', 'rt'],
#  ['so',
#   'jealous',
#   'rt',
#   'just',
#   'received',
#   'official',
#   'approval',
#   'for',
#   'my',
#   'rose',
#   'bowl',
#   '<unk>',
#   'can',
#   'not',
#   'wait',
#   'to',
#   'go',
#   'to',
#   'pasadena'],
#  ['around',
#   'skylar',
#   '<unk>',
#   'and',
#   'the',
#   'command',
#   'sisters',
#   'are',
#   'playing',
#   'and',
#   'me',
#   'of',
#   'course'],
#  ['oh', 'my', 'packers'],
#  ['chicken', '<unk>', 'for', 'din', 'din', 'p'],
#  ['i', 'am', 'the', 'i', 'am', 'that', 'i', 'am'],
#  ['happy', 'birthday', 'to'],
#  ['oh', 'god', 'its', 'the', 'worst'],
#  ['indeed', 'ideas', 'are', 'the', 'least', 'perfect', 'of', 'all', 'things'],
#  ['<unk>',
#   'i',
#   'agree',
#   'notice',
#   'she',
#   'dont',
#   'fk',
#   'with',
#   'tami',
#   'ghetto',
#   'a',
#   'anymore'],
#  ['hey', 'atl', 'go', 'see', '<unk>', '<unk>', 'tommorow', 'awesome', 'band'],
#  ['happy', 'you', 'yours'],
#  ['as',
#   'winds',
#   'down',
#   'david',
#   '<unk>',
#   'picks',
#   'his',
#   'top',
#   'albums',
#   'of',
#   'the',
#   'year'],
#  ['ignorance', 'is', 'bliss'],
#  ['air', 'conditioning'],
#  ['love',
#   'it',
#   'i',
#   'can',
#   'not',
#   'wait',
#   'until',
#   '<unk>',
#   'snap',
#   'its',
#   'gon',
#   'na',
#   'be',
#   '<unk>',
#   'whats',
#   'up',
#   'with',
#   'me',
#   'and',
#   'these',
#   'letters',
#   'lol'],
#  ['many',
#   'blessings',
#   'on',
#   'this',
#   'easter',
#   'day',
#   'thank',
#   'you',
#   'for',
#   'your',
#   'many',
#   'blessings',
#   'for',
#   'allowing',
#   'me',
#   'to',
#   'have',
#   'just',
#   'enough'],
#  ['rt',
#   'prediction',
#   'economy',
#   'matters',
#   'more',
#   'to',
#   'than',
#   'bin',
#   'laden',
#   'capture',
#   'if',
#   '<unk>',
#   'still',
#   'over',
#   'obamas',
#   'still',
#   'quite',
#   'vulnerable'],
#  ['happy', 'birthday', 'd'],
#  ['birthday',
#   'so',
#   'to',
#   'do',
#   'it',
#   'big',
#   'sorry',
#   'i',
#   'couldnt',
#   'make',
#   'it',
#   'out',
#   'take',
#   'a',
#   'shot',
#   'or',
#   'two',
#   'for',
#   'me'],
#  ['im', 'about', 'to', 'jump', 'off', 'the', '<unk>', 'cruise'],
#  ['id', 'be', 'honored', 'if', 'you', 'did'],
#  ['dont',
#   '<unk>',
#   'to',
#   'download',
#   '<unk>',
#   'for',
#   'the',
#   'ipad',
#   'its',
#   'a',
#   'very',
#   'cool',
#   'way',
#   'to',
#   'organize',
#   'your',
#   'tunes'],
#  ['twitter', 'is', 'the', 'same', 'way'],
#  ['fuck',
#   'my',
#   'fucking',
#   'life',
#   'i',
#   'always',
#   'get',
#   'treated',
#   'like',
#   'shit'],
#  ['aint',
#   'never',
#   'seen',
#   'it',
#   'i',
#   'have',
#   'an',
#   'allergic',
#   'reaction',
#   'to',
#   'tom',
#   'cruise',
#   'that',
#   'i',
#   'wont',
#   'risk',
#   '<unk>'],
#  ['<unk>',
#   'doing',
#   'the',
#   'trick',
#   'today',
#   'blinds',
#   'are',
#   'up',
#   'about',
#   'k'],
#  ['i', 'can', 'make', 'it', 'work', 'if', 'yall', 'can'],
#  ['<unk>',
#   'drugs',
#   'guns',
#   'dirt',
#   'weed',
#   'w',
#   'a',
#   'lotta',
#   'seeds',
#   'in',
#   'the',
#   'bags',
#   '<unk>',
#   'stolen',
#   'items',
#   '<unk>',
#   'from',
#   'the',
#   '<unk>'],
#  ['follow', 'me', 'on', 'twitter', 'follow', 'me', 'on', 'twitter'],
#  ['last',
#   'regular',
#   'season',
#   'home',
#   'game',
#   'tonight',
#   'lets',
#   'get',
#   'that',
#   'win',
#   'fellas',
#   'blazers',
#   '<unk>',
#   '<unk>'],
#  ['this', 'popular', 'science', 'is', 'your', 'brand', 'new', '<unk>'],
#  ['hey',
#   'pam',
#   'just',
#   'curious',
#   'what',
#   'does',
#   'your',
#   '<unk>',
#   'look',
#   'like',
#   'the',
#   'new',
#   'patch',
#   'stuff',
#   'looks',
#   'interesting'],
#  ['thats',
#   'also',
#   'an',
#   'important',
#   'aspect',
#   'know',
#   'that',
#   'can',
#   'help',
#   'price',
#   '<unk>',
#   'better',
#   'and',
#   'possibly',
#   'have',
#   '<unk>',
#   'pricing'],
#  ['shit', 'i', 'just', 'missed', 'the', 'shuttle'],
#  ['thats', 'an', 'awesome', 'n', 'true', 'statement'],
#  ['well', 'its', 'a', 'family', 'dog', 'lol'],
#  ['u', 'all', 'ready', 'have', 'one', 'of', 'those'],
#  ['havnt', 'used', 'tweeter', 'in', 'awhile'],
#  ['your',
#   '<unk>',
#   '<unk>',
#   'cat',
#   'is',
#   'incredible',
#   'but',
#   'please',
#   'dont',
#   'use',
#   'it',
#   'as',
#   'a',
#   '<unk>',
#   '<unk>',
#   'to',
#   '<unk>',
#   'me',
#   'into',
#   'your',
#   'yard',
#   'of',
#   'sales'],
#  ['reading',
#   'outside',
#   'again',
#   'for',
#   'lunch',
#   'just',
#   'over',
#   'heard',
#   'yeah',
#   'there',
#   'were',
#   'a',
#   'bunch',
#   'of',
#   'older',
#   'women',
#   'there',
#   'they',
#   'were',
#   'like',
#   'lol',
#   'ouch'],
#  ['that',
#   'we',
#   'are',
#   'his',
#   'people',
#   'by',
#   'reaching',
#   'out',
#   'to',
#   'our',
#   'fellow',
#   'man',
#   'in',
#   'love',
#   'caring',
#   'compassion',
#   'and',
#   '<unk>',
#   'the',
#   'world',
#   'that',
#   'there',
#   'is',
#   'hope'],
#  ['brand', 'worship', 'russell', 'brand', 'elton', 'brand', '<unk>', 'brand'],
#  ['thanks', 'a', 'mint', 'big', 'will'],
#  ['hadnt',
#   'seen',
#   'the',
#   'pc',
#   'version',
#   'nice',
#   'have',
#   'it',
#   'for',
#   '<unk>',
#   'but',
#   'it',
#   'doesnt',
#   'ever',
#   'connect'],
#  ['i',
#   'love',
#   'how',
#   'the',
#   'people',
#   'with',
#   'the',
#   'most',
#   'followers',
#   'and',
#   'shit',
#   'are',
#   'usually',
#   'the',
#   'ugliest',
#   'lmao'],
#  ['learned', 'striking', '<unk>', 'and', 'and', 'now', '<unk>'],
#  ['watched',
#   'very',
#   'moving',
#   'memorial',
#   'for',
#   'former',
#   'marine',
#   'and',
#   'amazing',
#   'human',
#   'charles',
#   '<unk>',
#   '<unk>'],
#  ['driving',
#   'behind',
#   'a',
#   'mustang',
#   'on',
#   'the',
#   'way',
#   'to',
#   'work',
#   'interesting',
#   'turn',
#   'signal',
#   'i',
#   'had',
#   'no',
#   'idea',
#   'that',
#   '<unk>',
#   'were',
#   'really',
#   'among',
#   'us'],
#  ['most', 'likely'],
#  ['he',
#   'is',
#   'well',
#   'known',
#   'by',
#   'all',
#   'for',
#   'being',
#   'friendly',
#   'awesome',
#   'and',
#   'annoying'],
#  ['had',
#   'fun',
#   'with',
#   'friends',
#   'both',
#   'nights',
#   'this',
#   'weekend',
#   'but',
#   'the',
#   'fact',
#   'that',
#   'ive',
#   'gotten',
#   'home',
#   'by',
#   'both',
#   'nights',
#   'makes',
#   'me',
#   'feel',
#   'like',
#   'i',
#   'havent',
#   'done',
#   'anything'],
#  ['miss', 'you', 'logan', 'things', 'will', 'never', 'be', 'the', 'same'],
#  ['hehe',
#   'bear',
#   'is',
#   'used',
#   'to',
#   'describe',
#   'a',
#   'hairy',
#   'or',
#   '<unk>',
#   'man',
#   'sometimes',
#   '<unk>',
#   'but',
#   'not',
#   'always',
#   'in',
#   'the',
#   'lgbt',
#   'world'],
#  ['like',
#   'damn',
#   'girl',
#   'ima',
#   'be',
#   'a',
#   '<unk>',
#   'doctor',
#   'save',
#   'lives',
#   'n',
#   '<unk>'],
#  ['lol',
#   'well',
#   'its',
#   'about',
#   'time',
#   'missy',
#   'it',
#   'took',
#   'u',
#   'years',
#   'to',
#   'follow',
#   'me',
#   'lol',
#   'u',
#   'still',
#   'bored'],
#  ['omg', 'she', 'is', 'so', 'great'],
#  ['awww',
#   'you',
#   'beat',
#   'me',
#   'to',
#   'the',
#   'twitter',
#   'world',
#   'i',
#   'scared',
#   'the',
#   '<unk>',
#   'outta',
#   'you',
#   'ahahah'],
#  ['things',
#   'we',
#   'say',
#   'in',
#   'school',
#   'im',
#   'tired',
#   'im',
#   'cold',
#   'i',
#   'dont',
#   'get',
#   'it',
#   'im',
#   'hungry',
#   'what',
#   'time',
#   'is',
#   'it',
#   'i',
#   'want',
#   'to',
#   'go',
#   'home'],
#  ['alas',
#   'for',
#   'those',
#   'that',
#   'never',
#   'sing',
#   'but',
#   'die',
#   'with',
#   'all',
#   'their',
#   'music',
#   'in',
#   'them',
#   'oliver',
#   '<unk>',
#   'holmes'],
#  ['great', 'trick'],
#  ['cant',
#   'wait',
#   'to',
#   'get',
#   'the',
#   'f',
#   'outta',
#   '<unk>',
#   'ready',
#   'to',
#   'dip'],
#  ['ill',
#   'say',
#   'it',
#   'again',
#   'i',
#   'better',
#   'find',
#   'an',
#   'awesome',
#   '<unk>',
#   '<unk>',
#   'celebration',
#   'in',
#   'philly',
#   'or',
#   'someones',
#   'going',
#   'to',
#   'bleed'],
#  ['can',
#   'you',
#   'please',
#   'come',
#   'to',
#   'my',
#   'house',
#   'friday',
#   'and',
#   'do',
#   'my',
#   'hair',
#   'and',
#   'makeup',
#   'for',
#   'prom',
#   'im',
#   'stressed'],
#  ['i', 'love', 'the', 'first', 'song', 'and', 'the', 'great', 'salt', 'lake'],
#  ['why',
#   'did',
#   'you',
#   'call',
#   'me',
#   'at',
#   'when',
#   'i',
#   'was',
#   'passed',
#   'out',
#   'lol'],
#  ['so',
#   'on',
#   'law',
#   'and',
#   'order',
#   'they',
#   'give',
#   'ppl',
#   'coffee',
#   'during',
#   '<unk>',
#   'bad',
#   'strategy',
#   'give',
#   'me',
#   'a',
#   'few',
#   '<unk>',
#   'and',
#   'ill',
#   'spill',
#   'my',
#   'guts'],
#  ['what',
#   'a',
#   'beautiful',
#   '<unk>',
#   'thinking',
#   'about',
#   'school',
#   'when',
#   'will',
#   'sunday',
#   'nights',
#   'stop',
#   'being',
#   'so',
#   '<unk>',
#   'will',
#   'i',
#   'sleep',
#   'on',
#   'sundays'],
#  ['omfg',
#   'today',
#   'was',
#   'a',
#   'kind',
#   'of',
#   'low',
#   'me',
#   'cuz',
#   'my',
#   '<unk>',
#   'beat',
#   'me',
#   'at',
#   '<unk>',
#   '<unk>',
#   'experience'],
#  ['love', 'the', 'myspace', 'page', 'good', 'music', 'too'],
#  ['odd',
#   'that',
#   'it',
#   'used',
#   'to',
#   'be',
#   'up',
#   'to',
#   'c',
#   'owner',
#   'to',
#   'claim',
#   'c',
#   'now',
#   'its',
#   'up',
#   'to',
#   'info',
#   'users',
#   'to',
#   'find',
#   'them'],
#  ['agreed',
#   'for',
#   'good',
#   'or',
#   'bad',
#   'we',
#   'always',
#   'get',
#   'the',
#   '<unk>',
#   'versions',
#   'of',
#   'ads'],
#  ['it', 'seems', 'like', 'such', 'an', 'easy', 'concept', 'right'],
#  ['my',
#   'sales',
#   'ebook',
#   'is',
#   'more',
#   'about',
#   'you',
#   'inside',
#   'than',
#   'teaching',
#   'you',
#   'sales',
#   'techniques'],
#  ['<unk>',
#   'really',
#   'coworking',
#   'is',
#   'still',
#   'a',
#   'new',
#   'in',
#   'the',
#   'mainstream',
#   'but',
#   'libraries',
#   'have',
#   'served',
#   'as',
#   'those',
#   'spaces',
#   'for',
#   'years'],
#  ['they',
#   'have',
#   'a',
#   'complete',
#   'different',
#   '<unk>',
#   'on',
#   'a',
#   'fade',
#   'here',
#   'it',
#   'basically',
#   'just',
#   'short',
#   'sides',
#   'and',
#   'high',
#   'top',
#   'so',
#   'high',
#   'top',
#   'fade',
#   'lmao'],
#  ['digging', 'eye', 'rocks', 'myself', 'this', 'am'],
#  ['glad',
#   'to',
#   'hear',
#   'well',
#   'read',
#   'that',
#   'were',
#   'helping',
#   'you',
#   '<unk>',
#   'to',
#   'your',
#   'healthy',
#   'eating',
#   'goal',
#   'keep',
#   'at',
#   'it',
#   'and',
#   'remember',
#   'to',
#   'report',
#   'on',
#   'time'],
#  ...]

# %%
final_test
# Out:
# [['seems',
#   'difficult',
#   'to',
#   'find',
#   'people',
#   'on',
#   'twitter',
#   'found',
#   '<unk>',
#   '<unk>',
#   'but',
#   'mainly',
#   'hit',
#   'and',
#   '<unk>',
#   'suggestions',
#   'for',
#   'finding',
#   'content',
#   'sources'],
#  ['sweet', '<unk>', 'awesome', 'just', 'dont', 'get', 'cocky', 'boys'],
#  ['im',
#   'obsessed',
#   'with',
#   's',
#   'youtube',
#   'videos',
#   'ive',
#   'legit',
#   'seen',
#   'every',
#   'single',
#   'one',
#   'lol',
#   'love',
#   'you',
#   'blair'],
#  ['chat', 'rangers', 'host', 'royals'],
#  ['i', 'hate', 'you', 'anyways'],
#  ['i', 'always', 'fall', 'for', 'your', 'type'],
#  ['i',
#   'think',
#   'making',
#   'babies',
#   'falls',
#   'under',
#   'the',
#   'not',
#   'work',
#   'category'],
#  ['rt',
#   'a',
#   'huge',
#   'thank',
#   'you',
#   'to',
#   'all',
#   'our',
#   'writers',
#   'on',
#   'most',
#   'they',
#   'are',
#   'what',
#   'make',
#   'it',
#   'rock'],
#  ['rt',
#   'my',
#   'former',
#   '<unk>',
#   'boss',
#   'told',
#   'me',
#   'u',
#   'can',
#   'be',
#   'an',
#   'expense',
#   'or',
#   'a',
#   'revenue',
#   'but',
#   'know',
#   'expenses',
#   'get',
#   'cut',
#   '<unk>',
#   'get',
#   'promoted'],
#  ['thanks', 'for', 'following'],
#  ['get',
#   'your',
#   'brunch',
#   'on',
#   'before',
#   'you',
#   'head',
#   'out',
#   'to',
#   'summerfest',
#   'free',
#   'shuttle',
#   'starting',
#   'at',
#   'pm'],
#  ['thank', 'you', 'for', 'spreading', 'the', 'word', 'about', 'us'],
#  ['somehow', 'that', 'is', 'awesome'],
#  ['the',
#   'french',
#   '<unk>',
#   'may',
#   'help',
#   'make',
#   'you',
#   'more',
#   'educational',
#   'but',
#   'they',
#   'do',
#   'not',
#   'redeem',
#   'you',
#   'of',
#   'your',
#   '<unk>',
#   'gossip',
#   'girl',
#   'season'],
#  ['congratulations', 'girl', 'is', '<unk>'],
#  ['<unk>',
#   'were',
#   'meant',
#   'to',
#   'fly',
#   'hands',
#   'up',
#   'and',
#   'touch',
#   'the',
#   'sky'],
#  ['im',
#   'never',
#   'really',
#   'that',
#   'insane',
#   'unless',
#   'someone',
#   'steals',
#   'my',
#   'heart'],
#  ['hi',
#   'to',
#   'our',
#   'newest',
#   'followers',
#   'we',
#   'anticipate',
#   'volunteering',
#   'w',
#   'u',
#   'pls',
#   'rt'],
#  ['need', 'more', '<unk>', 'team', 'follow', 'back'],
#  ['just', 'scored', 'free', 'tix', 'to', 'great', 'lake', '<unk>', 'tonight'],
#  ['located',
#   'in',
#   'us',
#   'states',
#   'across',
#   'the',
#   'country',
#   'i',
#   'know',
#   'there',
#   'is',
#   'a',
#   '<unk>',
#   'franchise',
#   'that',
#   'can',
#   'deliver',
#   'directly',
#   'to',
#   'where',
#   'you',
#   'are'],
#  ['never',
#   'blame',
#   'a',
#   'day',
#   'in',
#   'your',
#   'life',
#   'good',
#   'days',
#   'gives',
#   'you',
#   'happiness',
#   'bad',
#   'days',
#   'gives',
#   'you',
#   'experience',
#   'hope',
#   'everyone',
#   'has',
#   'a',
#   'blessed',
#   'and',
#   'productive',
#   'friday'],
#  ['last',
#   'month',
#   '<unk>',
#   'submitted',
#   'articles',
#   'for',
#   'clients',
#   'on',
#   'topics',
#   '<unk>',
#   'from',
#   'the',
#   'basics',
#   'of',
#   'color',
#   'to',
#   'disaster',
#   'recovery'],
#  ['thank',
#   'you',
#   'and',
#   'especially',
#   'who',
#   'made',
#   'this',
#   'visit',
#   'to',
#   'nashville',
#   'my',
#   'most',
#   'memorable'],
#  ['basketball',
#   'jones',
#   'by',
#   '<unk>',
#   'n',
#   '<unk>',
#   'features',
#   '<unk>',
#   'on',
#   'guitar',
#   '<unk>',
#   'on',
#   'organ',
#   '<unk>',
#   'on',
#   'bass'],
#  ['rt',
#   'fantasy',
#   'football',
#   'is',
#   'close',
#   'rt',
#   'nfl',
#   'and',
#   'players',
#   'accomplished',
#   'a',
#   'ton',
#   'today',
#   'are',
#   'truly',
#   'getting',
#   'close',
#   'to',
#   'deal'],
#  ['i', 'want', 'a', 'bacon', 'tree'],
#  ['neighborhood', 'opens', 'on', 'thursday', 'you', 'will', 'be', 'there'],
#  ['im',
#   'done',
#   '<unk>',
#   '<unk>',
#   'five',
#   'coming',
#   'soon',
#   'for',
#   'all',
#   'of',
#   'my',
#   'true',
#   '<unk>',
#   'quality',
#   'hip',
#   'hop',
#   'fans'],
#  ['starting',
#   'tomorrow',
#   'neil',
#   'jordans',
#   'the',
#   'crying',
#   'game',
#   'come',
#   'see',
#   'the',
#   'film',
#   'that',
#   'had',
#   'everyone',
#   'talking',
#   'nearly',
#   'years',
#   'ago'],
#  ['us', 'too', 'olivia', 'hooray', 'see', 'you', 'soon'],
#  ['the',
#   'profit',
#   'will',
#   'be',
#   'donated',
#   'to',
#   'table',
#   'for',
#   'two',
#   'providing',
#   'school',
#   'meals',
#   'to',
#   'children',
#   'in',
#   'africa'],
#  ['you',
#   'can',
#   'look',
#   'for',
#   'our',
#   'new',
#   'posting',
#   'on',
#   'summer',
#   'camps',
#   'com',
#   'getting',
#   'ready',
#   'to',
#   'audition',
#   'for',
#   'summer',
#   'teen',
#   'arts',
#   'production',
#   'april',
#   '<unk>',
#   'nyc'],
#  ['the',
#   'question',
#   'of',
#   'the',
#   'hour',
#   'should',
#   'my',
#   'new',
#   'iphone',
#   'be',
#   'white',
#   'or',
#   'black'],
#  ['anyone',
#   'got',
#   'an',
#   'iphone',
#   's',
#   'for',
#   'sale',
#   'or',
#   'trade',
#   'for',
#   'an',
#   'ipad'],
#  ['so',
#   'thats',
#   'why',
#   'i',
#   'never',
#   'get',
#   'a',
#   'response',
#   'from',
#   'schools',
#   'i',
#   'reach',
#   'out',
#   'to',
#   'after',
#   'one',
#   'of',
#   'their',
#   'players',
#   'are',
#   '<unk>',
#   'or',
#   'die',
#   'from',
#   'brain',
#   'injury',
#   '<unk>'],
#  ['i', 'wan', 'na', 'be', 'at', 'most'],
#  ['i',
#   'think',
#   'im',
#   'gon',
#   'na',
#   'start',
#   'using',
#   'this',
#   'twitter',
#   'thing',
#   'more',
#   'often'],
#  ['i',
#   'want',
#   'subway',
#   'right',
#   'now',
#   'rt',
#   'if',
#   'you',
#   'do',
#   'too',
#   'kayla'],
#  ['lifes',
#   'too',
#   'short',
#   'to',
#   'hide',
#   'feelings',
#   'express',
#   'how',
#   'you',
#   'feel'],
#  ['hahaha',
#   'what',
#   'are',
#   'you',
#   'looking',
#   'at',
#   'omg',
#   'i',
#   'die',
#   'everytime',
#   'i',
#   'think',
#   'of',
#   'everything',
#   'that',
#   'happened',
#   'love',
#   'u',
#   '<unk>',
#   'next',
#   'weekend'],
#  ['sweet', 'retweet', '<unk>'],
#  ['rt',
#   'my',
#   'foods',
#   'not',
#   'at',
#   'all',
#   'what',
#   'i',
#   'ordered',
#   'thats',
#   'got',
#   'ta',
#   'be',
#   'bad',
#   'sorry',
#   'all',
#   'the',
#   'live',
#   '<unk>',
#   'if',
#   'i',
#   'eat',
#   'in',
#   'your',
#   'face'],
#  ['i', 'met', 'jack', 'once', 'hes', 'such', 'a', 'sweetie'],
#  ['hoping',
#   'to',
#   'do',
#   'an',
#   'olympic',
#   '<unk>',
#   'in',
#   'the',
#   'obstacle',
#   'that',
#   'swim',
#   'i',
#   'need',
#   'to',
#   'become',
#   'a',
#   'stronger',
#   '<unk>',
#   'any',
#   'ideas'],
#  ['<unk>',
#   'crazy',
#   'people',
#   'but',
#   'charlie',
#   'sheen',
#   'is',
#   '<unk>',
#   'at',
#   'home',
#   'p'],
#  ['<unk>',
#   'from',
#   'the',
#   '<unk>',
#   'ghetto',
#   'including',
#   'many',
#   'children',
#   'ages',
#   'to',
#   'were',
#   'killed',
#   'in',
#   'the',
#   'gas',
#   'chambers',
#   'of',
#   '<unk>'],
#  ['going', 'good', 'team', 'lol'],
#  ['i', 'those', 'and', 'save', 'for', 'the', 'other', 'days'],
#  ['to', 'lady', '<unk>', 'concert', 'born', 'this', 'way', 'ball', 'd'],
#  ['why',
#   'use',
#   'the',
#   'phrase',
#   'for',
#   'shits',
#   'and',
#   'giggles',
#   'who',
#   'the',
#   'fuck',
#   'shits',
#   'then',
#   'giggles'],
#  ['you', 'cant', 'do', 'that'],
#  ['when',
#   'did',
#   'it',
#   'become',
#   'normal',
#   'to',
#   'start',
#   'the',
#   'workday',
#   'by',
#   'deleting',
#   'portuguese',
#   'and',
#   'chinese',
#   'spam'],
#  ['smackdown', 'yep', 'im', 'right', 'john', '<unk>', 'going', 'to', 'win'],
#  ['girl',
#   '<unk>',
#   'find',
#   'out',
#   'you',
#   'and',
#   'jasmine',
#   'into',
#   'it',
#   'ha',
#   '<unk>',
#   'as',
#   'lmfaooo'],
#  ['broken', 'link'],
#  ['happy', 'may', 'day', 'tweeters'],
#  ['its',
#   'been',
#   'great',
#   'were',
#   'in',
#   '<unk>',
#   'us',
#   'know',
#   'when',
#   'youre',
#   'singing'],
#  ['savage', 'u'],
#  ['stop',
#   'asking',
#   'why',
#   'to',
#   'every',
#   'little',
#   'thing',
#   'take',
#   'a',
#   'second'],
#  ['lmfaooo',
#   'omfg',
#   'yes',
#   'he',
#   'worked',
#   'at',
#   'the',
#   '<unk>',
#   'i',
#   'live',
#   'right',
#   'night',
#   'to',
#   '<unk>'],
#  ['im', 'gon', 'na', 'try'],
#  ['one', 'less', 'lonely', 'girl'],
#  ['thanks',
#   'to',
#   'whitney',
#   'houston',
#   'my',
#   'kids',
#   'are',
#   'now',
#   'afraid',
#   'of',
#   'the',
#   'bath'],
#  ['ha', 'no', 'he', 'apparently', 'lost', 'feelings', 'for', 'me'],
#  ['their', 'gettin', '<unk>', 'in', 'an', 'old', 'abandoned', 'house'],
#  ['green', 'is', 'wat', 'good', '<unk>', 'is', 'cool'],
#  ['a', 'true', 'follower', 'and', '<unk>', 'here', 'in', 'vegas'],
#  ['ahh',
#   'just',
#   'crashed',
#   'the',
#   'downtown',
#   'marriott',
#   'hotel',
#   'pool',
#   'and',
#   '<unk>',
#   'that',
#   'place',
#   'is',
#   'paradise'],
#  ['please',
#   'please',
#   'follow',
#   'me',
#   'i',
#   'love',
#   'you',
#   'so',
#   'so',
#   'so',
#   '<unk>',
#   'i',
#   '<unk>',
#   'every',
#   'single',
#   'one',
#   'of',
#   'your',
#   'videos',
#   'on',
#   'youtube',
#   'plz',
#   'follow',
#   'me'],
#  ['yeah',
#   'thats',
#   'always',
#   'the',
#   'toughest',
#   'balance',
#   'work',
#   'hard',
#   'play',
#   'harder'],
#  ['fashion', 'is', '<unk>', 'faith', 'is', 'hotter'],
#  ['okay', 'good', 'bestie'],
#  ['time',
#   'to',
#   'get',
#   'up',
#   'and',
#   'get',
#   'dressed',
#   'for',
#   'dinner',
#   'and',
#   'drinks'],
#  ['its', 'so', 'hard', 'to', 'get', 'out', 'of', 'my', 'bed'],
#  ['i',
#   'didnt',
#   'know',
#   'we',
#   'were',
#   'going',
#   'as',
#   'early',
#   'as',
#   'possible'],
#  ['truly',
#   'impressed',
#   'by',
#   'the',
#   'look',
#   'of',
#   'the',
#   'delta',
#   'reach',
#   'ad',
#   'nice',
#   'work'],
#  ['i',
#   'feel',
#   'you',
#   'kinda',
#   'feeling',
#   'like',
#   'taking',
#   'a',
#   'break',
#   'from',
#   'it',
#   'too'],
#  ['microwave', 'pizza'],
#  ['in', 'yankees', 'win', 'first', 'world', 'championship', 'since'],
#  ['and',
#   'here',
#   'i',
#   'am',
#   'still',
#   'three',
#   'hours',
#   '<unk>',
#   'going',
#   'out'],
#  ['<unk>',
#   'is',
#   'offering',
#   'off',
#   'all',
#   'replacement',
#   'laptop',
#   'batteries',
#   'today',
#   'only',
#   'till',
#   'pm',
#   'eastern',
#   'pass',
#   'it',
#   'along'],
#  ['that',
#   'awkward',
#   'moment',
#   'when',
#   'youre',
#   'walking',
#   'around',
#   'in',
#   'heels',
#   'and',
#   'youre',
#   'as',
#   'tall',
#   'as',
#   'your',
#   'dad'],
#  ['bad', 'offensive', 'plays', 'already'],
#  ['im',
#   'such',
#   'an',
#   'old',
#   'man',
#   'just',
#   'had',
#   'my',
#   'first',
#   'skype',
#   'session',
#   'with',
#   'someone',
#   'tonight'],
#  ['more',
#   'rappers',
#   'should',
#   'come',
#   'out',
#   'with',
#   'their',
#   'own',
#   '<unk>',
#   'its',
#   'a',
#   'great',
#   'concept'],
#  ['were', 'happy', 'to', 'have', 'you', 'on', 'board'],
#  ['how', 'are', 'you', '<unk>', 'cabin', 'fever'],
#  ['i', 'love', 'this', 'kid', 'too', 'much', 'stfu', 'you', '<unk>', 'boy'],
#  ['whats', 'up', 'world', 'how', 'is', 'everybody', 'today'],
#  ['i', 'know', 'i', 'was', 'like', 'damn', 'you'],
#  ['haha', 'i', 'almost', 'dipped', 'in', 'the', 'trash', 'can', 'x'],
#  ['anyone', 'got', 'plans', 'for', 'monday', 'night'],
#  ['the',
#   'socially',
#   'good',
#   'train',
#   'keeps',
#   'on',
#   'rolling',
#   'at',
#   'tonight',
#   'join',
#   'us',
#   'for',
#   'a',
#   'date',
#   'auction',
#   'grab',
#   'a',
#   'slap',
#   'cancer',
#   'cocktail',
#   'possibly',
#   'a',
#   'date'],
#  ['second',
#   'first',
#   'semester',
#   'of',
#   'graduate',
#   'school',
#   'complete',
#   'psyched'],
#  ['tip',
#   'figure',
#   'out',
#   'what',
#   'inspires',
#   'you',
#   'is',
#   'it',
#   'something',
#   'you',
#   'listen',
#   'to',
#   'watch',
#   'read',
#   'is',
#   'it',
#   'a',
#   'particular',
#   'person'],
#  ['out', 'of', 'school', 'already', 'districts'],
#  ['im',
#   'back',
#   'baby',
#   'wedding',
#   'and',
#   'honeymoon',
#   'are',
#   'over',
#   'time',
#   'to',
#   'get',
#   'this',
#   'machine',
#   'rolling',
#   'again'],
#  ['justin',
#   'did',
#   'not',
#   'tweet',
#   'that',
#   'i',
#   'have',
#   'to',
#   'move',
#   'on',
#   'tweet',
#   'last',
#   'weekend',
#   'if',
#   'the',
#   'forbes',
#   'interview',
#   'was',
#   'last',
#   'week',
#   'and',
#   'it',
#   'says',
#   'selena',
#   'is',
#   'his',
#   'gf',
#   'in',
#   'it'],
#  ['haha', 'i', 'love', 'leg'],
#  ['fresh', 'cool', 'drinks', 'perhaps'],
#  ['always',
#   'enjoy',
#   'the',
#   'new',
#   '<unk>',
#   'and',
#   'different',
#   'music',
#   'classes',
#   'this',
#   'morning'],
#  ['apparently',
#   'shes',
#   'offline',
#   'maybe',
#   'me',
#   'showing',
#   'up',
#   'was',
#   'the',
#   'last',
#   'straw'],
#  ['classy',
#   'classy',
#   '<unk>',
#   'speech',
#   'by',
#   'tom',
#   '<unk>',
#   'as',
#   'my',
#   'father',
#   'taught',
#   'me',
#   'judgment',
#   'day',
#   'is',
#   'more',
#   'important',
#   'than',
#   'election',
#   'day'],
#  ['if',
#   'we',
#   'only',
#   'had',
#   'faith',
#   'the',
#   'size',
#   'of',
#   'a',
#   'mustard',
#   'seed',
#   'we',
#   'could',
#   'say',
#   'to',
#   'the',
#   'mountains',
#   'move',
#   'and',
#   'they',
#   'would',
#   'move'],
#  ['watching',
#   'jersey',
#   'shore',
#   'and',
#   'waiting',
#   'for',
#   'my',
#   'boyfriend',
#   'to',
#   'bring',
#   'me',
#   'chinese',
#   'food',
#   'yummy'],
#  ['wonderful',
#   'epic',
#   'fail',
#   'presentations',
#   'at',
#   'mw',
#   'thanks',
#   'to',
#   'all',
#   'for',
#   'courage',
#   'insight',
#   'and',
#   'humility'],
#  ['the',
#   'silk',
#   'tie',
#   'likes',
#   '<unk>',
#   'i',
#   'saw',
#   'your',
#   'tie',
#   'and',
#   'think',
#   'we',
#   'could',
#   'give',
#   'you',
#   'a',
#   '<unk>',
#   'one',
#   '<unk>'],
#  ['hi', 'jordan'],
#  ['her',
#   'response',
#   'was',
#   'its',
#   'so',
#   'western',
#   'to',
#   'divorce',
#   'start',
#   'a',
#   'new',
#   'family',
#   'and',
#   'keep',
#   'in',
#   'touch',
#   'w',
#   'your',
#   'first',
#   'set',
#   'of',
#   'kids'],
#  ['tuesday',
#   'and',
#   'one',
#   'up',
#   'early',
#   'on',
#   'mon',
#   'for',
#   'my',
#   '<unk>',
#   'rt',
#   'when',
#   'are',
#   'you',
#   'going',
#   'to',
#   'have',
#   'more',
#   'songs',
#   'on',
#   'itunes'],
#  ['and',
#   'then',
#   'said',
#   'satan',
#   'i',
#   'will',
#   'schedule',
#   'set',
#   'it',
#   'off',
#   'warped',
#   'tour',
#   'on',
#   'the',
#   'same',
#   'day',
#   'lauren'],
#  ['<unk>', 'voice'],
#  ['great',
#   'advice',
#   'from',
#   'writing',
#   'is',
#   'about',
#   'working',
#   'through',
#   'things'],
#  ['the',
#   '<unk>',
#   'guy',
#   'next',
#   'to',
#   'me',
#   'is',
#   'so',
#   '<unk>',
#   'the',
#   'i',
#   '<unk>',
#   'on',
#   'those',
#   'teachers',
#   'here',
#   'for',
#   'a',
#   'conference',
#   'he',
#   'can',
#   'kiss',
#   'my',
#   '<unk>'],
#  ['kids',
#   'who',
#   'exercise',
#   '<unk>',
#   'for',
#   'minutes',
#   'a',
#   'day',
#   'lower',
#   'their',
#   'risk',
#   'of',
#   'heart',
#   'disease'],
#  ['when',
#   'youre',
#   'driving',
#   'and',
#   'a',
#   'nun',
#   'pulls',
#   'up',
#   'next',
#   'too',
#   'you'],
#  ['youre', 'welcome', 'love'],
#  ['lets', 'go', 'mavs', 'lay', 'the', 'smack', 'down', 'on', 'la'],
#  ['<unk>', 'ill', 'check', 'it', 'out'],
#  ['u', 'wrong', 'cuz'],
#  ['just',
#   'finished',
#   'reading',
#   'the',
#   'blog',
#   'post',
#   'about',
#   'making',
#   'a',
#   'beer',
#   'wars',
#   'part',
#   'ii',
#   'got',
#   'ta',
#   'say',
#   'i',
#   'agree',
#   'and',
#   'disagree',
#   'with',
#   'it',
#   'cheers'],
#  ['you',
#   'need',
#   'to',
#   'get',
#   '<unk>',
#   'shoot',
#   'in',
#   'the',
#   'dark',
#   'and',
#   'make',
#   'jealous',
#   'at',
#   'the',
#   'same',
#   'time'],
#  ['ths',
#   'is',
#   'another',
#   'area',
#   'that',
#   'mitt',
#   'romney',
#   'doesnt',
#   'have',
#   'a',
#   'clue',
#   '<unk>',
#   'would',
#   'be',
#   'in',
#   'trouble',
#   'if',
#   'he',
#   'were',
#   'potus',
#   'to',
#   '<unk>',
#   '<unk>'],
#  ['a',
#   'i',
#   'need',
#   'to',
#   'see',
#   'the',
#   'fam',
#   'before',
#   'they',
#   'leave',
#   'b',
#   'were',
#   'all',
#   'going',
#   'out',
#   'tonight',
#   'you',
#   'better',
#   'come',
#   'out'],
#  ['labor',
#   'day',
#   '<unk>',
#   'the',
#   'day',
#   'before',
#   'tuesday',
#   'the',
#   'christmas',
#   'season',
#   'begins',
#   'tomorrow',
#   'do',
#   'you',
#   'have',
#   'a',
#   'plan'],
#  ['never',
#   'let',
#   '<unk>',
#   'like',
#   'that',
#   'get',
#   'you',
#   'down',
#   'did',
#   'saying',
#   'that',
#   'make',
#   'you',
#   'feel',
#   'like',
#   'a',
#   'big',
#   'man',
#   'guess',
#   'what',
#   'you',
#   'arent'],
#  ['what',
#   'if',
#   'oxygen',
#   'was',
#   'what',
#   'made',
#   'our',
#   'voices',
#   'deeper',
#   'and',
#   '<unk>',
#   'brings',
#   'them',
#   'back',
#   'to',
#   'normal'],
#  ['i', 'believe', 'in', 'miracles', 'happy', 'resurrection', 'day', 'xx'],
#  ['yall', 'should', 'do', 'a', 'song', 'to', 'gether', 'for'],
#  ['instant',
#   'fan',
#   'of',
#   'john',
#   '<unk>',
#   'its',
#   'time',
#   'to',
#   'burn',
#   'my',
#   'past'],
#  ['well', 'thank', 'you', 'sir'],
#  ['thanks', 'for', 'stopping', 'by', 'great', 'picture', 'enjoy', 'dinner'],
#  ['<unk>',
#   '<unk>',
#   'modern',
#   'life',
#   'rocket',
#   'power',
#   'the',
#   'amanda',
#   'show',
#   'hey',
#   'arnold',
#   'doug',
#   '<unk>',
#   '<unk>',
#   '<unk>',
#   '<unk>',
#   'back',
#   'when',
#   'tv',
#   'was',
#   'good'],
#  ['sadly',
#   'spotify',
#   'isnt',
#   '<unk>',
#   'my',
#   'thirst',
#   'for',
#   'the',
#   'newest',
#   'tunes'],
#  ['<unk>',
#   'un',
#   '<unk>',
#   '<unk>',
#   '<unk>',
#   'en',
#   'france',
#   'or',
#   'in',
#   'english',
#   'have',
#   'a',
#   '<unk>',
#   'happy',
#   'birthday',
#   'in',
#   'france'],
#  ['you',
#   'can',
#   'do',
#   'anything',
#   'i',
#   'can',
#   'do',
#   'all',
#   'things',
#   'thru',
#   'christ',
#   'who',
#   'gives',
#   'me',
#   'strength',
#   '<unk>',
#   'bible'],
#  ['lets', 'go', 'black', 'mamba'],
#  ['were', '<unk>', 'have', 'some', 'fun', 'tonight'],
#  ['almost',
#   'at',
#   'likes',
#   'which',
#   'means',
#   'another',
#   'song',
#   'will',
#   'go',
#   'up'],
#  ['<unk>',
#   'campaign',
#   'on',
#   'romney',
#   'endorsement',
#   'while',
#   'rep',
#   'bachmann',
#   'is',
#   'in',
#   '<unk>',
#   'va',
#   'today',
#   'jim',
#   '<unk>',
#   'will',
#   'be',
#   'in',
#   'buffalo',
#   'mn',
#   'and',
#   '<unk>',
#   'mn'],
#  ['aww', 'thats', 'good', 'to', 'hear'],
#  ['first',
#   'semester',
#   'of',
#   'scheduling',
#   'that',
#   'i',
#   'didnt',
#   'get',
#   '<unk>',
#   'or',
#   'have',
#   'class',
#   'on',
#   'friday'],
#  ['i', 'wan', 'na', 'get', 'wasted', 'with', '<unk>', 'this', 'weekend'],
#  ['i',
#   'like',
#   '<unk>',
#   'd',
#   'dude',
#   'did',
#   'you',
#   'not',
#   'watch',
#   'his',
#   '<unk>',
#   'hes',
#   'real',
#   'legit',
#   'touched',
#   'me'],
#  ['you',
#   'know',
#   'you',
#   'work',
#   'too',
#   'much',
#   'when',
#   'you',
#   'dont',
#   'even',
#   'have',
#   'time',
#   'to',
#   'commute',
#   'to',
#   'the',
#   'office'],
#  ['so',
#   'when',
#   'i',
#   'left',
#   'for',
#   'church',
#   'i',
#   'had',
#   'followers',
#   'i',
#   'cam',
#   'back',
#   'and',
#   'had',
#   'followers',
#   'you',
#   'guys',
#   'are',
#   'the',
#   'best'],
#  ['people', 'just', 'be', 'mad', '<unk>', 'tho'],
#  ['but',
#   'yes',
#   'thats',
#   'the',
#   'basic',
#   'premise',
#   'he',
#   'has',
#   'c',
#   'talent',
#   'and',
#   'plays',
#   'as',
#   '<unk>',
#   'with',
#   'us'],
#  ['i', 'enjoyed', 'this', 'evening', 'with', 'you', 'good', 'times', '<unk>'],
#  ['these',
#   '<unk>',
#   'things',
#   'help',
#   'to',
#   'shape',
#   'what',
#   'we',
#   'know',
#   'how',
#   'we',
#   'learn',
#   'the',
#   's',
#   'we',
#   'ask',
#   'the',
#   'answers',
#   'we',
#   '<unk>',
#   'we',
#   'see',
#   'the',
#   'world'],
#  ['love', 'how', 'one', 'thing', 'can', 'ruin', 'your', 'whole', 'day'],
#  ['the',
#   'fact',
#   'that',
#   'you',
#   'replied',
#   'gave',
#   'me',
#   'so',
#   'much',
#   'hope',
#   'its',
#   'not',
#   'even',
#   'funny'],
#  ['rt',
#   'at',
#   '<unk>',
#   'community',
#   'is',
#   'no',
#   'longer',
#   'a',
#   '<unk>',
#   'plays',
#   'a',
#   'key',
#   'role',
#   'in',
#   'social',
#   'across',
#   'multiple',
#   '<unk>'],
#  ['not', 'looking', 'good', '<unk>'],
#  ['i', 'got', '<unk>'],
#  ['chipotle',
#   'serves',
#   'us',
#   'kid',
#   'size',
#   'burrito',
#   'bowl',
#   'per',
#   'request',
#   'then',
#   'charges',
#   'full',
#   'price',
#   'explaining',
#   'they',
#   'dont',
#   'offer',
#   'kid',
#   'size',
#   'please'],
#  ['i',
#   'want',
#   'this',
#   'semester',
#   'to',
#   'be',
#   'over',
#   'now',
#   'now',
#   'now',
#   'now',
#   'now',
#   'now'],
#  ['stoked',
#   'about',
#   '<unk>',
#   'map',
#   '<unk>',
#   'and',
#   '<unk>',
#   '<unk>',
#   'good',
#   'times'],
#  ['thanks', 'so', 'much'],
#  ['goodnight', '<unk>', 'love', 'u'],
#  ['im', 'dying', 'laughing', '<unk>'],
#  ['<unk>', 'all', 'the', 'way'],
#  ['sweet', 'frog', 'for', '<unk>', 'and', 'strawberry', 'was', 'good'],
#  ['dam', 'im', 'ready', 'c', 'avengers', 'lol', 'ima', 'kid', 'at', 'heart'],
#  ['thing',
#   'that',
#   'makes',
#   'being',
#   'sick',
#   'with',
#   'a',
#   'cold',
#   'better',
#   'is',
#   'watching',
#   '<unk>',
#   '<unk>',
#   'wait',
#   'for',
#   'the',
#   'new',
#   'season',
#   'tonight'],
#  ['ive',
#   'helped',
#   'with',
#   'thesis',
#   'tonight',
#   'looked',
#   'at',
#   'a',
#   'working',
#   'draft',
#   'helped',
#   'with',
#   '<unk>',
#   'bodies',
#   'ive',
#   'logged',
#   'twenty',
#   'assists',
#   'tonight',
#   'friends'],
#  ['i',
#   'am',
#   'originally',
#   'from',
#   'memphis',
#   'so',
#   'i',
#   'know',
#   'how',
#   'memphis',
#   'q',
#   'is'],
#  ['how',
#   'is',
#   'everyone',
#   'feeling',
#   'after',
#   'the',
#   'milwaukee',
#   'after',
#   'party',
#   'what',
#   'a',
#   'great',
#   'night'],
#  ['the',
#   'trucks',
#   'are',
#   'at',
#   'cooper',
#   'city',
#   'potential',
#   'church',
#   '<unk>',
#   'road',
#   'eat',
#   'at',
#   'they',
#   'are',
#   'amazing'],
#  ['love', 'your', 'white', 'pony', '<unk>'],
#  ['dave', '<unk>', 'justin', 'back', 'he', 'is'],
#  ['finishing',
#   'up',
#   'the',
#   'week',
#   'with',
#   'a',
#   'few',
#   'more',
#   'people',
#   'to',
#   'train'],
#  ['no',
#   'you',
#   'bought',
#   'it',
#   'so',
#   'i',
#   'didnt',
#   'take',
#   'it',
#   'haha',
#   'it',
#   'was',
#   'quite',
#   '<unk>'],
#  ['im', 'not', 'watching', 'the', 'game', 'btw'],
#  ['whats',
#   'up',
#   'with',
#   'this',
#   'noel',
#   'guy',
#   '<unk>',
#   'us',
#   'sports',
#   'knowledge',
#   '<unk>'],
#  ['why',
#   'are',
#   'the',
#   'guys',
#   'so',
#   'goddamn',
#   'cute',
#   '<unk>',
#   'its',
#   'so',
#   'not',
#   'fair'],
#  ['come',
#   'in',
#   'to',
#   'the',
#   'bike',
#   'line',
#   'today',
#   'and',
#   'sign',
#   'the',
#   '<unk>',
#   'petition',
#   'to',
#   'make',
#   'a',
#   'more',
#   'bicycle',
#   'friendly',
#   'america'],
#  ['enjoy', 'your', 'day', 'with', 'sweet', 'baby', 'grant', 'love', 'xo'],
#  ['never',
#   'forget',
#   'to',
#   'daily',
#   'dive',
#   'into',
#   'the',
#   '<unk>',
#   'of',
#   'creativity',
#   'stay',
#   'curious',
#   'explore',
#   'whats',
#   'around',
#   'you',
#   'and',
#   'make',
#   '<unk>'],
#  ['ive',
#   'finally',
#   'told',
#   'shaq',
#   'who',
#   'his',
#   'daddy',
#   'is',
#   'its',
#   '<unk>',
#   'lol'],
#  ['so', 'tired', 'but', 'not', 'sleeping', 'till', 'you', 'choose'],
#  ['news', 'nerds'],
#  ['i',
#   'see',
#   'you',
#   'completely',
#   'changed',
#   'my',
#   'tweet',
#   'to',
#   'fit',
#   'around',
#   'your',
#   'joke'],
#  ['fda',
#   'must',
#   'balance',
#   'evaluation',
#   'of',
#   'product',
#   'safety',
#   'with',
#   'more',
#   'efficient',
#   'approval',
#   'of',
#   'innovative',
#   'new',
#   'drugs',
#   'editorial',
#   'via'],
#  ['sweden', 'kind', 'of', 'owns', 'the', '<unk>', 'thing', 'right', '<unk>'],
#  ['so',
#   'to',
#   'the',
#   'girls',
#   'posting',
#   'pictures',
#   'of',
#   'themselves',
#   'making',
#   'out',
#   'with',
#   'their',
#   'boyfriends',
#   'in',
#   'their',
#   'underwear',
#   'on',
#   'facebook',
#   'way',
#   'to',
#   'keep',
#   'it',
#   'classy'],
#  ['lolol', 'we', 'just', '<unk>', 'i', 'swear'],
#  ['umm',
#   'hello',
#   'why',
#   'did',
#   'you',
#   'not',
#   'share',
#   'your',
#   'good',
#   'news',
#   'wthe',
#   'caucus',
#   'congrats',
#   'btw',
#   'you',
#   'make',
#   'me',
#   'proud'],
#  ['lmao', 'sure', 'p'],
#  ['i', 'hate', 'waiting'],
#  ['always',
#   'be',
#   'shorter',
#   'than',
#   'anybody',
#   '<unk>',
#   'to',
#   'hope',
#   'lord',
#   'reading',
#   'on',
#   '<unk>'],
#  ['ok', 'if', 'you', 'say', 'so'],
#  ['we', 'have', 'some', 'pics', 'is', 'about', 'to', 'post'],
#  ['and', 'kitties', 'she', 'makes', 'kitties', 'look', 'awful'],
#  ['but', 'a', 'little', 'more', 'slowly', 'that', 'i', 'thought'],
#  ['keep',
#   'your',
#   'car',
#   'on',
#   'the',
#   'road',
#   'your',
#   'on',
#   'the',
#   'right',
#   'path',
#   'only',
#   'god',
#   'can',
#   'judge',
#   'you',
#   'have',
#   'my',
#   'support',
#   '<unk>'],
#  ['i', 'never', 'want', 'to', 'go', 'to', 'jail', 'again'],
#  ['i', 'cant', 'get', 'home', 'fast', 'enough', 'ha', 'but', 'truth'],
#  ['they',
#   'dont',
#   'thank',
#   'god',
#   'as',
#   'much',
#   'as',
#   'they',
#   'did',
#   'years',
#   'ago',
#   'at',
#   'the',
#   'oscars'],
#  ['woohoo', 'have', 'fun', 'and', 'enjoy'],
#  ['good',
#   'one',
#   'on',
#   '<unk>',
#   '<unk>',
#   'now',
#   'get',
#   'on',
#   'the',
#   'field',
#   'and',
#   'get',
#   'that',
#   'skirt',
#   'chest',
#   'ready',
#   'to',
#   'scoop',
#   '<unk>'],
#  ['awesome',
#   'rt',
#   'iron',
#   '<unk>',
#   'the',
#   'kobe',
#   'and',
#   'the',
#   'pau',
#   'gasol',
#   'the',
#   '<unk>',
#   '<unk>'],
#  ['im', 'so', 'happy', 'right', 'now'],
#  ['i',
#   'hate',
#   'dt',
#   'when',
#   'its',
#   'humid',
#   'all',
#   'these',
#   'lil',
#   '<unk>',
#   'b',
#   'gettin',
#   'all',
#   'up',
#   'on',
#   'me',
#   'wtf'],
#  ['ready', 'for', 'washington', 'tomorrow'],
#  ['figured', 'id', 'wear', '<unk>', 'today'],
#  ['<unk>', 'love', 'in', 'section', 'row', 's', 'seat'],
#  ['will', 'the', 'georgia', '<unk>', 'be', 'featured', 'in', 'any', 'way'],
#  ['both',
#   'are',
#   'fantastic',
#   'games',
#   'i',
#   'like',
#   'the',
#   'car',
#   'selection',
#   'in',
#   'better',
#   'tho',
#   'if',
#   'you',
#   'like',
#   'cars',
#   'and',
#   'racing',
#   'you',
#   'need',
#   'to',
#   'get',
#   '<unk>'],
#  ['<unk>',
#   'is',
#   'digging',
#   'in',
#   '<unk>',
#   'i',
#   'say',
#   'its',
#   'an',
#   '<unk>',
#   'war',
#   'you',
#   'cant',
#   'win',
#   'i',
#   'poke',
#   'around',
#   'tho'],
#  ['i', 'got', 'ta', 'make', 'these', 'moves'],
#  ['agree',
#   'grt',
#   'site',
#   'for',
#   'govt',
#   'agencies',
#   '<unk>',
#   'rt',
#   'this',
#   'is',
#   'a',
#   'great',
#   'resource',
#   'thanks',
#   'for',
#   'posting',
#   'it'],
#  ['watching',
#   'on',
#   'the',
#   'treadmill',
#   'tv',
#   'at',
#   'the',
#   'gym',
#   'and',
#   'ugly',
#   'crying',
#   'on',
#   'the',
#   'upside',
#   'i',
#   'didnt',
#   'fall',
#   'off'],
#  ['omg',
#   'what',
#   'a',
#   'great',
#   'show',
#   'i',
#   'officially',
#   'have',
#   'been',
#   'through',
#   'the',
#   'shadow',
#   'of',
#   '<unk>',
#   'twice',
#   'and',
#   'cant',
#   'to',
#   'again',
#   'return',
#   'to',
#   'indy',
#   'pronto'],
#  ['thanks',
#   'to',
#   'all',
#   'participants',
#   'in',
#   'todays',
#   '<unk>',
#   '<unk>',
#   'ft',
#   'if',
#   'you',
#   'have',
#   'questions',
#   'about',
#   '<unk>',
#   'email'],
#  ['and',
#   'people',
#   'wonder',
#   'why',
#   'id',
#   'rather',
#   'watch',
#   'sports',
#   'nearly',
#   'constantly',
#   'gosh'],
#  ['lies',
#   'and',
#   'gin',
#   'sounds',
#   'like',
#   'so',
#   'many',
#   'of',
#   'my',
#   'dream',
#   '<unk>'],
#  ['thanks', 'for', 'the', 'shout', 'out'],
#  ['happy',
#   'friday',
#   '<unk>',
#   'starts',
#   'in',
#   'hours',
#   'get',
#   'excited',
#   'to',
#   'get',
#   'yourself',
#   'a',
#   'new',
#   'present',
#   'for',
#   'the',
#   'holiday',
#   'weekend'],
#  ['designers',
#   'do',
#   'you',
#   'have',
#   'online',
#   '<unk>',
#   'where',
#   'do',
#   'you',
#   'keep',
#   'them',
#   'facebook',
#   'pinterest'],
#  ['congrats',
#   'to',
#   'the',
#   'for',
#   '<unk>',
#   'hamilton',
#   'josh',
#   '<unk>',
#   'had',
#   'goals',
#   'assist',
#   'for',
#   'the',
#   '<unk>'],
#  ['dont', '<unk>', '<unk>'],
#  ['people',
#   'act',
#   'like',
#   'the',
#   'human',
#   'race',
#   'is',
#   'going',
#   'to',
#   'stop',
#   'completely',
#   'once',
#   'a',
#   'few',
#   'women',
#   'decide',
#   'not',
#   'to',
#   'get',
#   '<unk>',
#   'smh'],
#  ['thanks', 'james', '<unk>'],
#  ['hows', 'it', 'bruh'],
#  ['thanks', 'for', 'following'],
#  ['lol',
#   '<unk>',
#   'johnson',
#   'was',
#   'the',
#   'last',
#   'company',
#   'i',
#   'figured',
#   'was',
#   'going',
#   'bankrupt',
#   'then',
#   'again',
#   'more',
#   'ppl',
#   'are',
#   'price',
#   'conscious'],
#  ['after',
#   'class',
#   'one',
#   'day',
#   'she',
#   'was',
#   'laughing',
#   'telling',
#   'someone',
#   'i',
#   'just',
#   'have',
#   'a',
#   'big',
#   'imagination',
#   'and',
#   'its',
#   'funny',
#   'not',
#   'really'],
#  ['youre', 'comment', 'just', 'made', 'me', 'die'],
#  ['wheres',
#   'the',
#   'kick',
#   'tutorial',
#   'vid',
#   'thatll',
#   'teach',
#   'my',
#   'wife',
#   'how',
#   'to',
#   'pin',
#   'all',
#   'the',
#   'things',
#   'shes',
#   'not',
#   'getting',
#   'it'],
#  ['<unk>', 'follow', 'back', 'bro'],
#  ['<unk>',
#   'a',
#   'respectful',
#   'suggestion',
#   'for',
#   'another',
#   'to',
#   'achieve',
#   'future',
#   'success',
#   'targeting',
#   'a',
#   'behavior',
#   'that',
#   'they',
#   'have',
#   '<unk>',
#   'as',
#   'critical'],
#  ['yess',
#   'no',
#   'pacers',
#   'grr',
#   'im',
#   'gunna',
#   'fail',
#   'the',
#   'speaking',
#   'final'],
#  ['what', 'website'],
#  ['i',
#   'dont',
#   'have',
#   'high',
#   'hopes',
#   'for',
#   'it',
#   'to',
#   'tell',
#   'you',
#   'the',
#   'truth',
#   'im',
#   'not',
#   'crazy',
#   'about',
#   'previous',
#   'script',
#   'drafts',
#   'or',
#   'the',
#   'current',
#   'production',
#   'team'],
#  ['<unk>',
#   'b',
#   'cool',
#   'if',
#   'u',
#   'lived',
#   'by',
#   'us',
#   'then',
#   'ud',
#   'get',
#   'to',
#   'participate',
#   'in',
#   'our',
#   '<unk>'],
#  ['misses',
#   'football',
#   'way',
#   'too',
#   'much',
#   '<unk>',
#   'runs',
#   'in',
#   'my',
#   '<unk>',
#   'steelers'],
#  ['i',
#   'know',
#   'right',
#   'i',
#   'really',
#   'want',
#   'to',
#   'go',
#   'to',
#   'that',
#   'concert'],
#  ['hearts', 'on', 'fire', 'rocky', 'must', 'be', 'on', 'classic'],
#  ['i', 'always', 'attract', 'the', 'wrong', 'people'],
#  ['she', 'got', 'me', 'in', 'here', '<unk>', 'the', 'vow'],
#  ['there',
#   'are',
#   'so',
#   'many',
#   '<unk>',
#   'this',
#   'year',
#   'that',
#   'are',
#   '<unk>',
#   'do',
#   'you',
#   'take',
#   'your',
#   'furry',
#   'friend',
#   'with',
#   'you',
#   'on',
#   'outdoor',
#   'adventures'],
#  ['or',
#   'hidden',
#   'behind',
#   'the',
#   'giant',
#   'pile',
#   'of',
#   'american',
#   'girl',
#   'dolls'],
#  ['you', 'are', 'a', '<unk>', 'for', 'punishment'],
#  ['no',
#   'no',
#   'no',
#   'not',
#   'yet',
#   'thats',
#   'just',
#   'to',
#   'record',
#   'in',
#   'atlanta'],
#  ['i', 'like', '<unk>'],
#  ['not',
#   'loving',
#   'the',
#   'rain',
#   'i',
#   'would',
#   'prefer',
#   'something',
#   'white',
#   'with',
#   'a',
#   'bit',
#   'of',
#   '<unk>'],
#  ['favorite', 'overhead', 'conversation', 'in', 'india'],
#  ['sweet',
#   'baby',
#   'is',
#   'it',
#   'too',
#   'early',
#   'to',
#   'start',
#   'thinking',
#   'about',
#   'a',
#   '<unk>',
#   'championship',
#   'game'],
#  ['i', 'hate', 'dudes', 'that', 'make', 'fruity', 'tweets'],
#  ['youre',
#   'gon',
#   'na',
#   'kiss',
#   'a',
#   'lot',
#   'of',
#   'frogs',
#   'before',
#   'you',
#   'find',
#   'your',
#   'prince'],
#  ['lindsey', 'lohan', 'needs', 'a', 'makeover'],
#  ['we',
#   'dont',
#   'talk',
#   'about',
#   'our',
#   'own',
#   'folks',
#   'talking',
#   'about',
#   'their',
#   'own',
#   'stuff',
#   'all',
#   'we',
#   'care',
#   'about',
#   'is',
#   'talking',
#   'talking',
#   'about',
#   'you',
#   'and',
#   'me'],
#  ['i',
#   'cant',
#   'wait',
#   'our',
#   'first',
#   'daughter',
#   'will',
#   'be',
#   'graduating',
#   'from',
#   'law',
#   'school'],
#  ['that',
#   'isnt',
#   '<unk>',
#   'it',
#   'was',
#   'clearly',
#   'still',
#   'out',
#   'of',
#   'bounds'],
#  ['our', 'pleasure', 'really', 'hope', 'you', 'like', 'your', 'new', 'swag'],
#  ['email',
#   'me',
#   'lets',
#   'get',
#   'you',
#   'guys',
#   'back',
#   'in',
#   'for',
#   'an',
#   'interview'],
#  ['the', 'cold', 'autumn', '<unk>', 'makes', 'me', 'insanely', 'happy'],
#  ['were',
#   'trying',
#   'to',
#   'interrupt',
#   'the',
#   'cycle',
#   'of',
#   'poverty',
#   'for',
#   'our',
#   'kids',
#   'sterling',
#   '<unk>'],
#  ['i',
#   'hope',
#   'you',
#   'get',
#   'hit',
#   'by',
#   'a',
#   'bus',
#   'and',
#   'then',
#   'it',
#   'backs',
#   'over',
#   'you',
#   'again'],
#  ['skylar', 'is', 'staying', 'i', 'hope'],
#  ['<unk>',
#   'kay',
#   'is',
#   'on',
#   'tomorrow',
#   'am',
#   'ah',
#   'hes',
#   'probs',
#   'in',
#   'chicago',
#   'right',
#   'now'],
#  ['haha', 'i', 'know'],
#  ['been',
#   'to',
#   'the',
#   'last',
#   'in',
#   'a',
#   'row',
#   'only',
#   'an',
#   'hour',
#   'from',
#   'me'],
#  ['thanks', 'bro'],
#  ['<unk>', 'got', 'back', 'now', 'to', 'start', 'to', 'work', 'on', 'school'],
#  ['jennifer',
#   'hudson',
#   'jennifer',
#   'hudson',
#   'would',
#   'have',
#   'been',
#   'in',
#   'murder',
#   'house',
#   'if',
#   'fiance',
#   'hadnt',
#   'called'],
#  ['absolutely', 'perfect', 'tonight', 'love', 'the', 'outfit'],
#  ['foster',
#   'the',
#   'people',
#   'remind',
#   'me',
#   'a',
#   'bit',
#   'of',
#   'the',
#   'wonders'],
#  ['ill', 'play', 'you', 'in', 'a', 'game', 'of', '<unk>'],
#  ['youre', 'such', 'a', 'health', 'nut', 'haha'],
#  ['check', 'out', 'my', 'artist', 'follow'],
#  ['he', 'is', 'risen'],
#  ['yeah',
#   'un',
#   'huh',
#   'and',
#   'i',
#   'would',
#   '<unk>',
#   'buy',
#   'shoes',
#   'from',
#   'the',
#   'villa',
#   'lol',
#   'but',
#   'thats',
#   'just',
#   'me'],
#  ['hey',
#   'its',
#   'harder',
#   'for',
#   'the',
#   'writers',
#   'i',
#   'havent',
#   'updated',
#   'mine',
#   'for',
#   'weeks',
#   'xd',
#   'lmao',
#   'writers',
#   'block',
#   'suck'],
#  ['are',
#   'you',
#   'having',
#   '<unk>',
#   'issues',
#   'i',
#   'cant',
#   'get',
#   'to',
#   'my',
#   'portal',
#   'or',
#   '<unk>',
#   'via',
#   'git'],
#  ['not', 'from', 'charlotte'],
#  ['more',
#   'weeks',
#   'till',
#   'the',
#   'indy',
#   'ready',
#   'to',
#   'spend',
#   'the',
#   'weekend'],
#  ['thoughts', 'on', 'the', 'winner', 'of', 'last', 'nights', 'debate'],
#  ['i',
#   'currently',
#   '<unk>',
#   'in',
#   'academic',
#   '<unk>',
#   'i',
#   'should',
#   'have',
#   'prayed',
#   'more',
#   'or',
#   'changed',
#   'my',
#   'graduation',
#   'date',
#   'to',
#   'august',
#   'or',
#   'something',
#   'or',
#   'something'],
#  ['done',
#   'with',
#   'my',
#   'freshman',
#   'year',
#   'of',
#   'college',
#   'praise',
#   'the',
#   'lord'],
#  ['<unk>',
#   '<unk>',
#   'just',
#   '<unk>',
#   'are',
#   'you',
#   'okay',
#   'to',
#   'his',
#   'wife',
#   'tear'],
#  ['if',
#   'death',
#   'life',
#   'are',
#   'in',
#   'the',
#   'power',
#   'of',
#   'the',
#   'tongue',
#   'have',
#   'u',
#   'thought',
#   'about',
#   'the',
#   'death',
#   'or',
#   'life',
#   'youve',
#   'released',
#   'by',
#   'the',
#   'words',
#   'that',
#   'youve',
#   'spoken'],
#  ['we',
#   'finally',
#   'found',
#   'a',
#   'printer',
#   'for',
#   'our',
#   '<unk>',
#   'as',
#   'penny',
#   'lane',
#   'would',
#   'say',
#   'its',
#   'all',
#   'happening'],
#  ['what', 'are', 'they'],
#  ['<unk>',
#   'just',
#   'made',
#   'a',
#   'new',
#   'animation',
#   'for',
#   'global',
#   'power',
#   '<unk>',
#   'on',
#   '<unk>',
#   'any',
#   'thoughts'],
#  ['aight',
#   'but',
#   'ill',
#   'try',
#   'and',
#   'send',
#   'em',
#   'again',
#   'if',
#   'this',
#   'dont',
#   'work',
#   'this',
#   'time',
#   'then',
#   'you',
#   '<unk>'],
#  ['common',
#   'sense',
#   'is',
#   'the',
#   'collection',
#   'of',
#   '<unk>',
#   'acquired',
#   'by',
#   'the',
#   'age',
#   'of',
#   '<unk>',
#   'albert',
#   'einstein',
#   'of',
#   '<unk>',
#   'and',
#   '<unk>',
#   'bk'],
#  ['i',
#   'hear',
#   'ya',
#   'mike',
#   'im',
#   'gon',
#   'na',
#   'be',
#   'praying',
#   'for',
#   'a',
#   'week',
#   'after',
#   'the',
#   'w',
#   'today'],
#  ['jefferson',
#   'davis',
#   'crossed',
#   'the',
#   'delaware',
#   'and',
#   'defeated',
#   'hitler'],
#  ['the',
#   'flu',
#   'can',
#   'help',
#   'jump',
#   'start',
#   'your',
#   'diet',
#   'its',
#   'going',
#   'around',
#   'so',
#   'catch',
#   'while',
#   'you',
#   'can'],
#  ['im',
#   'so',
#   'jealous',
#   'where',
#   'are',
#   'you',
#   'going',
#   'in',
#   'the',
#   'caribbean',
#   'st',
#   'john',
#   'is',
#   'my',
#   'favorite',
#   'what',
#   'about',
#   'the',
#   'th',
#   'or',
#   'th'],
#  ['thats',
#   'about',
#   'all',
#   'i',
#   'can',
#   'find',
#   'if',
#   'its',
#   'in',
#   'memory',
#   'then',
#   'there',
#   'isnt',
#   'much',
#   'you',
#   'could',
#   'do',
#   'to',
#   'clear',
#   'besides',
#   '<unk>'],
#  ['check',
#   'out',
#   'my',
#   'upcoming',
#   'master',
#   'classes',
#   'in',
#   '<unk>',
#   'spain',
#   'festival',
#   'july',
#   'not',
#   'on',
#   'their',
#   'website',
#   'yet',
#   'but',
#   'coming',
#   'soon'],
#  ['losing',
#   'hope',
#   'of',
#   'austin',
#   'finally',
#   'noticing',
#   '<unk>',
#   'a',
#   'year',
#   'is',
#   'a',
#   'long',
#   'time'],
#  ['not', 'in', 'the', 'mood', 'to', 'study', 'math', 'today'],
#  ['feels', 'good', 'to', 'be', 'tan'],
#  ['going',
#   'to',
#   'prom',
#   'tonight',
#   'st',
#   'prom',
#   'since',
#   'much',
#   'less',
#   'exciting',
#   'now',
#   'and',
#   'no',
#   '<unk>',
#   'photo',
#   'shoot'],
#  ['number', 'ethiopian', 'queen', 'the', 'well', 'fed', 'ones', 'though'],
#  ['yes',
#   'but',
#   'not',
#   '<unk>',
#   'plastic',
#   'tools',
#   'trust',
#   'me',
#   'on',
#   'that'],
#  ['sschat',
#   'if',
#   'students',
#   'all',
#   'demonstrate',
#   '<unk>',
#   'than',
#   'what',
#   'we',
#   'are',
#   'told',
#   'to',
#   'grade',
#   'tougher',
#   'without',
#   'any',
#   'ideas',
#   'for',
#   'how',
#   'to',
#   'do',
#   'that'],
#  ['so', 'true'],
#  ['was', 'it', 'for', 'literature', 'by', 'women', 'of', 'color'],
#  ['<unk>',
#   'are',
#   'you',
#   'going',
#   'to',
#   'propose',
#   'to',
#   'her',
#   'just',
#   'kidding',
#   'youre',
#   'already',
#   'married'],
#  ['awww', 'thanks', 'we', 'wont', 'get', 'a', 'dime'],
#  ['rt',
#   'see',
#   'for',
#   'updates',
#   'on',
#   'the',
#   'two',
#   'usc',
#   'students',
#   '<unk>',
#   'shot',
#   'this',
#   'morning',
#   'here',
#   'is',
#   'latest',
#   'dt',
#   'story'],
#  ['coming',
#   'soon',
#   'to',
#   '<unk>',
#   'tips',
#   'on',
#   'how',
#   'a',
#   'convicted',
#   '<unk>',
#   'can',
#   'find',
#   'employment'],
#  ['this',
#   'is',
#   'a',
#   'good',
#   'lesson',
#   'not',
#   'just',
#   'for',
#   'startups',
#   'but',
#   'for',
#   'everyday',
#   'life',
#   'rt',
#   'being',
#   'broke',
#   'means',
#   'being',
#   '<unk>',
#   '<unk>'],
#  ['awesome',
#   'well',
#   'see',
#   'ya',
#   'there',
#   'who',
#   'are',
#   'you',
#   'most',
#   'excited',
#   'to',
#   'hear',
#   'speak'],
#  ['idk',
#   'he',
#   'hit',
#   'me',
#   'up',
#   'today',
#   'we',
#   'suppose',
#   'to',
#   'chill',
#   'tomorrow',
#   'if',
#   'the',
#   'doctor',
#   'say',
#   'its',
#   'cool',
#   'for',
#   'me',
#   'to',
#   'be',
#   'out'],
#  ['birds',
#   'of',
#   'a',
#   'feather',
#   'flock',
#   'together',
#   'misery',
#   'loves',
#   'company',
#   'many',
#   'hands',
#   'make',
#   'light',
#   'work'],
#  ['according',
#   'fox',
#   'all',
#   'veterans',
#   'deserve',
#   'highest',
#   'respect',
#   'we',
#   'can',
#   'give',
#   'except',
#   'dr',
#   'ron',
#   'paul',
#   'a',
#   'genuine',
#   'patriot',
#   'of',
#   'the',
#   'th',
#   'degree',
#   'who',
#   'is',
#   'rejected'],
#  ['yes', 'she', 'does'],
#  ['wow',
#   'my',
#   'mama',
#   'got',
#   '<unk>',
#   'in',
#   'church',
#   'tonight',
#   'glad',
#   'i',
#   'made',
#   'her',
#   'laugh',
#   'to',
#   'make',
#   'hee',
#   'feel',
#   'better'],
#  ['surprised', 'it', 'wasnt', 'shorter'],
#  ['rt',
#   'jj',
#   '<unk>',
#   'saved',
#   'the',
#   'magic',
#   'tonite',
#   'with',
#   'a',
#   '<unk>',
#   'hi',
#   'pt',
#   'effort',
#   'his',
#   'back',
#   'to',
#   'back',
#   'th',
#   'qtr',
#   'threes',
#   'were',
#   'huge'],
#  ['<unk>',
#   'users',
#   'info',
#   'in',
#   'the',
#   'app',
#   'has',
#   'just',
#   'been',
#   'updated',
#   'for',
#   'the',
#   'month',
#   'just',
#   'press',
#   'update',
#   'on',
#   'the',
#   'bottom',
#   'tab',
#   'bar',
#   'to',
#   'get',
#   'latest',
#   'information'],
#  ['<unk>',
#   'hilarious',
#   'there',
#   'were',
#   'some',
#   '<unk>',
#   'in',
#   'the',
#   '<unk>',
#   'messages',
#   'like',
#   'women',
#   'bring',
#   'favor',
#   'clarity',
#   'and',
#   '<unk>'],
#  ['photo',
#   'shoot',
#   'for',
#   'my',
#   'new',
#   'knitting',
#   'book',
#   'is',
#   'coming',
#   'up',
#   'in',
#   'weeks',
#   'shot',
#   'by',
#   'the',
#   'fabulous',
#   'jared',
#   'flood',
#   'again'],
#  ['both',
#   'classes',
#   'canceled',
#   'tomorrow',
#   'f',
#   'yeah',
#   'greatest',
#   'day',
#   'ever',
#   '<unk>',
#   'im',
#   'praying',
#   'for',
#   'a',
#   'day',
#   'like',
#   'that',
#   'lol'],
#  ['thanks',
#   'chris',
#   '<unk>',
#   'ill',
#   'email',
#   'you',
#   'more',
#   'information',
#   'on',
#   'how',
#   'social',
#   'commerce',
#   'is',
#   'driving',
#   'our',
#   'business'],
#  ['<unk>',
#   'is',
#   'not',
#   'popping',
#   'only',
#   'one',
#   'bitch',
#   '<unk>',
#   'the',
#   'stage',
#   'red',
#   'aka',
#   '<unk>'],
#  ['this', 'week'],
#  ['suck', 'a', '<unk>'],
#  ['im',
#   '<unk>',
#   'i',
#   'know',
#   'it',
#   'could',
#   'be',
#   'worse',
#   'it',
#   'could',
#   'be',
#   'raining',
#   'or',
#   'monday'],
#  ['two', 'weeks', 'from', 'friday', 'we', 'will', 'be', '<unk>'],
#  ['wow', 'which', '<unk>'],
#  ['im',
#   'not',
#   'sure',
#   'if',
#   'i',
#   'wan',
#   'na',
#   'go',
#   'back',
#   'through',
#   'my',
#   'feed',
#   'try',
#   'to',
#   'figure',
#   'out',
#   'what',
#   'youre',
#   'talking',
#   'about'],
#  ['omg', 'i', 'hate', 'getting', 'up', 'at', 'in', 'the', 'morning', 'ewww'],
#  ['tupac', 'is', 'back', 'from', 'the', 'dead'],
#  ['however',
#   'grown',
#   'ups',
#   'can',
#   'control',
#   'themselves',
#   'should',
#   'be',
#   'able',
#   'to',
#   'conduct',
#   'themselves',
#   '<unk>'],
#  ['virginia',
#   '<unk>',
#   'runners',
#   'for',
#   'the',
#   'third',
#   'consecutive',
#   'inning',
#   'but',
#   '<unk>',
#   'hr',
#   'puts',
#   '<unk>',
#   'up',
#   'thru',
#   'complete',
#   'innings'],
#  ['my', 'sweet', 'one'],
#  ['<unk>',
#   'why',
#   'did',
#   'i',
#   'never',
#   'think',
#   'of',
#   'that',
#   'its',
#   'ok',
#   'though',
#   'they',
#   'left'],
#  ['imagine',
#   'you',
#   'ally',
#   'will',
#   'you',
#   'marry',
#   'me',
#   'justin',
#   'what',
#   'you',
#   'what',
#   'did',
#   'i',
#   'say',
#   'justin',
#   'ally',
#   'will',
#   'u',
#   'marry',
#   'me',
#   'you',
#   'yes',
#   'of',
#   'course',
#   'jb',
#   'wait',
#   'what'],
#  ['lol',
#   'no',
#   'i',
#   'am',
#   'not',
#   'in',
#   'mexico',
#   'what',
#   'made',
#   'you',
#   'think',
#   'that'],
#  ['excellent',
#   'advice',
#   'rt',
#   '<unk>',
#   'granola',
#   'bars',
#   '<unk>',
#   'granola',
#   'bars',
#   'increase',
#   'the',
#   'quality',
#   'of',
#   'your',
#   'life'],
#  ['im',
#   'sure',
#   'this',
#   'tweet',
#   'would',
#   'make',
#   'more',
#   'sense',
#   'to',
#   'me',
#   'if',
#   'i',
#   'had',
#   '<unk>',
#   'any',
#   'attention',
#   'in',
#   'physics',
#   'today',
#   'lol'],
#  ['how',
#   'can',
#   'you',
#   'have',
#   'a',
#   'hall',
#   'and',
#   '<unk>',
#   '<unk>',
#   'wo',
#   'shes',
#   'gone',
#   'disaster'],
#  ['girl',
#   'it',
#   'was',
#   'ridiculous',
#   'there',
#   'was',
#   'no',
#   'control',
#   'whatsoever',
#   'it',
#   'was',
#   'sad',
#   'to',
#   '<unk>',
#   'onto',
#   'a',
#   'show',
#   'i',
#   'love',
#   'one',
#   'born',
#   'every',
#   'minute'],
#  ['the',
#   'truth',
#   'isnt',
#   'out',
#   'there',
#   'its',
#   'in',
#   'the',
#   'tweets',
#   'of',
#   'this',
#   'account',
#   'which',
#   'if',
#   'read',
#   'correctly',
#   'contain',
#   'followfriday',
#   'via'],
#  ['who',
#   'am',
#   'i',
#   'if',
#   'you',
#   'read',
#   'through',
#   'my',
#   'tweets',
#   'you',
#   'will',
#   'find',
#   'clues',
#   'that',
#   'lead',
#   'to',
#   'my',
#   'identity',
#   'but',
#   'is',
#   'it',
#   'worth',
#   'the',
#   'trouble'],
#  ['i',
#   'really',
#   'want',
#   'the',
#   'hi',
#   'my',
#   'name',
#   'is',
#   'slim',
#   'shady',
#   '<unk>'],
#  ['me',
#   'watching',
#   'melo',
#   'play',
#   'defense',
#   'is',
#   'like',
#   '<unk>',
#   'gore',
#   'watching',
#   '<unk>',
#   'the',
#   'killer'],
#  ['come', 'in', 'to', 'brake', '<unk>', 'plus', 'call'],
#  ['at',
#   'least',
#   'im',
#   'not',
#   'ugly',
#   'rt',
#   'lmao',
#   'im',
#   'done',
#   'with',
#   'you',
#   'lol',
#   'i',
#   'cant',
#   'deal',
#   'with',
#   'a',
#   'emotional',
#   'niggas'],
#  ['i', 'love', 'you', 'guys'],
#  ['super', 'excited'],
#  ['i',
#   'feel',
#   'like',
#   'a',
#   'good',
#   'view',
#   'is',
#   'a',
#   'great',
#   'distraction',
#   'from',
#   'people',
#   'digging',
#   'around',
#   'in',
#   'your',
#   'grill'],
#  ['met',
#   'her',
#   'aunt',
#   'from',
#   'the',
#   'philippines',
#   'it',
#   'was',
#   'her',
#   'first',
#   'time',
#   'in',
#   'america',
#   'and',
#   'she',
#   'was',
#   'very',
#   'nice',
#   'we',
#   'went',
#   'to',
#   'the',
#   'mall'],
#  ['the', 'hunger', 'bro'],
#  ['there',
#   'are',
#   'million',
#   'african',
#   'americans',
#   'who',
#   'are',
#   'eligible',
#   'to',
#   'vote',
#   'who',
#   'have',
#   'not',
#   'registered',
#   'and',
#   'thats',
#   'just',
#   'african',
#   'americans'],
#  ['whats', 'wrong'],
#  ['why',
#   'dis',
#   'bitch',
#   'stay',
#   'tweeting',
#   'my',
#   'minor',
#   'ass',
#   'tho',
#   'lol',
#   'you',
#   'right',
#   'about',
#   'that',
#   'but',
#   'chill',
#   'hoe'],
#  ['whatd', 'ya', 'think'],
#  ['awesome', 'girls', 'cool', 'background'],
#  ['<unk>', 'u', 'hate', 'wen', 'people', 'r', 'so', 'mean'],
#  ['i',
#   'have',
#   'to',
#   'be',
#   'up',
#   'at',
#   'am',
#   'for',
#   'the',
#   '<unk>',
#   'survival',
#   'job',
#   'but',
#   'i',
#   'still',
#   'got',
#   'a',
#   'lot',
#   'of',
#   'work',
#   'to',
#   'do',
#   'my',
#   'work',
#   'is',
#   'never',
#   'finished'],
#  ['been',
#   'in',
#   'a',
#   'great',
#   'mood',
#   'today',
#   'wonder',
#   'what',
#   'the',
#   'world',
#   'is',
#   'coming',
#   'to'],
#  ['there',
#   'is',
#   'far',
#   'to',
#   'go',
#   'now',
#   'lets',
#   'not',
#   'waste',
#   'a',
#   'minute',
#   'more',
#   'of',
#   'our',
#   'lives'],
#  ['one', 'direction', 'your', 'life'],
#  ['in',
#   'nearly',
#   'of',
#   'people',
#   'with',
#   'disabilities',
#   'were',
#   'unemployed'],
#  ['had',
#   'so',
#   'much',
#   'fun',
#   'at',
#   'the',
#   'show',
#   'last',
#   'night',
#   'guys',
#   'thats',
#   'gon',
#   'na',
#   'be',
#   'our',
#   'last',
#   'show',
#   'for',
#   'the',
#   'year',
#   'but',
#   'weve',
#   'got',
#   'some',
#   'exciting',
#   'stuff',
#   'coming',
#   'in'],
#  ['i',
#   'can',
#   'relate',
#   'to',
#   'your',
#   'mad',
#   'crazy',
#   'life',
#   'thanks',
#   'the',
#   'follow'],
#  ['omg',
#   'wear',
#   'shorts',
#   'or',
#   'leggings',
#   'dont',
#   'wear',
#   'both',
#   'if',
#   'youre',
#   'gona',
#   'wear',
#   'both',
#   'then',
#   'just',
#   'wear',
#   'pants'],
#  ['is', 'my', 'fab', 'to', 'win', 'good', 'luck'],
#  ['i',
#   'hate',
#   'that',
#   'one',
#   'pretty',
#   'girl',
#   'at',
#   'my',
#   'school',
#   'that',
#   'every',
#   'guy',
#   'is',
#   'dying',
#   'to',
#   'date'],
#  ['we',
#   'have',
#   'new',
#   'members',
#   'on',
#   'our',
#   'linkedin',
#   'group',
#   'come',
#   'join',
#   'us',
#   'on',
#   'commercial',
#   '<unk>',
#   'we',
#   'have',
#   '<unk>',
#   'engineers',
#   'and',
#   'scientists',
#   'all'],
#  ['hit', 'up', 'and', 'see', 'what', 'the', '<unk>', 'clan', 'is', 'doing'],
#  ['glad',
#   'to',
#   'have',
#   'all',
#   'of',
#   'you',
#   'at',
#   '<unk>',
#   'love',
#   'having',
#   'great',
#   'neighbors'],
#  ['<unk>', 'great', 'idea'],
#  ['the', 'video', 'is', 'amazing', '<unk>'],
#  ['ohh', 'yes', 'its', 'thursday', 'finally', 'pumped'],
#  ['<unk>',
#   'you',
#   'sit',
#   'in',
#   'a',
#   'towel',
#   'because',
#   'you',
#   'are',
#   'too',
#   'lazy',
#   'to',
#   'get',
#   'clothes',
#   'on'],
#  ['and', 'only', 'day', 'until', 'mine'],
#  ['love',
#   'your',
#   'site',
#   'would',
#   'love',
#   'to',
#   'talk',
#   'with',
#   'you',
#   'more',
#   'about',
#   '<unk>',
#   'and',
#   'exchange',
#   'ideas',
#   'interested'],
#  ['i', 'agree'],
#  ['new',
#   'single',
#   'boyfriend',
#   'has',
#   'been',
#   'in',
#   'my',
#   'head',
#   'all',
#   'day',
#   'well',
#   'done'],
#  ['these',
#   'stickers',
#   'are',
#   '<unk>',
#   '<unk>',
#   'long',
#   'lasting',
#   'and',
#   'creative'],
#  ['this',
#   'morning',
#   'im',
#   'awake',
#   'thanks',
#   'to',
#   'the',
#   'good',
#   'handsome',
#   'peeps',
#   'at',
#   'kings',
#   'road',
#   'cafe',
#   'miles',
#   'away',
#   'thanks',
#   'for',
#   'a',
#   'gift',
#   'of',
#   'beans'],
#  ['hit',
#   '<unk>',
#   'for',
#   'not',
#   'only',
#   'cd',
#   'dvd',
#   '<unk>',
#   'but',
#   'for',
#   'kickin',
#   'custom',
#   'tshirts',
#   'apparel',
#   'for',
#   'your',
#   'band',
#   'cause',
#   'or',
#   'company',
#   '<unk>',
#   'is',
#   'home'],
#  ['hates',
#   'no',
#   '<unk>',
#   'being',
#   'sick',
#   'at',
#   'least',
#   'im',
#   'home',
#   'and',
#   'not',
#   'at',
#   'school',
#   'but',
#   'still',
#   'being',
#   'sick',
#   'stinks'],
#  ['theavengers', 'was', 'awesome'],
#  ['rt',
#   'the',
#   'best',
#   '<unk>',
#   'for',
#   'a',
#   'piece',
#   'of',
#   'land',
#   'is',
#   'the',
#   '<unk>',
#   'of',
#   'its',
#   '<unk>',
#   'b',
#   'johnson'],
#  ['mention', 'me', 'if', 'you', 'want', 'me', 'to'],
#  ['hehe', 'sorry', 'i', 'was', 'cutting', 'my', 'shirt', 'and', 'failed'],
#  ['thank', 'you'],
#  ['so', 'bored', 'in', 'woman', 'terms', 'means', 'so', 'lonely'],
#  ['what', 'is', 'it', 'boo', 'i', 'dont', 'like', 'it'],
#  ['texas',
#   'family',
#   'law',
#   'tip',
#   'of',
#   'the',
#   'day',
#   'a',
#   'gift',
#   'to',
#   'a',
#   'spouse',
#   'is',
#   'separate',
#   'property',
#   'if',
#   'she',
#   'can',
#   'prove',
#   'to',
#   'whom',
#   'the',
#   'gift',
#   'was',
#   'given',
#   'save',
#   'your',
#   'gift',
#   'card'],
#  ['away',
#   'from',
#   'conference',
#   '<unk>',
#   'on',
#   'twitter',
#   'feeds',
#   'now',
#   'thank',
#   'you',
#   'everyone',
#   'who',
#   'is',
#   'tweeting'],
#  ['q',
#   'who',
#   'has',
#   'had',
#   'success',
#   'keeping',
#   'a',
#   'group',
#   'of',
#   'people',
#   'especially',
#   'youth',
#   'quiet',
#   'a',
#   'space',
#   'for',
#   'both',
#   'would',
#   'be',
#   'ideal'],
#  ['i',
#   'just',
#   'seen',
#   'the',
#   'preview',
#   'for',
#   '<unk>',
#   'i',
#   'have',
#   'words',
#   'i',
#   'have',
#   'to',
#   'see',
#   'that'],
#  ['plz',
#   'go',
#   'follow',
#   'she',
#   'follow',
#   'back',
#   'd',
#   'and',
#   'i',
#   'will',
#   'follow',
#   'you',
#   'too',
#   'd'],
#  ['whats',
#   'your',
#   'favorite',
#   'beer',
#   'an',
#   'open',
#   'on',
#   'so',
#   'how',
#   'do',
#   'you',
#   'when',
#   'youre',
#   'done',
#   'theres',
#   'no',
#   'more',
#   'beer',
#   'left',
#   'hahaha',
#   'jeff',
#   '<unk>'],
#  ['my',
#   'mom',
#   'taped',
#   'it',
#   'i',
#   'can',
#   'record',
#   'and',
#   'send',
#   'to',
#   'you'],
#  ['<unk>',
#   'we',
#   'drop',
#   'a',
#   'new',
#   'mixtape',
#   'called',
#   'commencement',
#   'we',
#   'been',
#   'workin',
#   'really',
#   'hard',
#   'on',
#   'this',
#   'one'],
#  ['robert',
#   '<unk>',
#   'make',
#   'visible',
#   'what',
#   'without',
#   'you',
#   'might',
#   'perhaps',
#   'never',
#   'have',
#   'been',
#   'seen'],
#  ['growing', 'my', 'hair', 'out'],
#  ['not',
#   'a',
#   'great',
#   'start',
#   'for',
#   'the',
#   '<unk>',
#   'experiment',
#   'at',
#   'b'],
#  ['who', 'cares', 'his', 'acting', 'sucks', 'and', 'hes', 'a', '<unk>'],
#  ['whitney', 'houston', 'just', 'passed'],
#  ['i',
#   'wish',
#   'it',
#   'was',
#   'breaking',
#   'news',
#   'that',
#   'you',
#   'were',
#   'traded',
#   'to',
#   'green',
#   'bay'],
#  ['hunter', 'hayes'],
#  ['time', 'to', 'get', 'back', 'on', 'the', 'ball'],
#  ['fascinating',
#   'and',
#   'terrible',
#   'are',
#   'good',
#   'criteria',
#   'for',
#   'many',
#   'things',
#   'hope',
#   'you',
#   'like',
#   'it'],
#  ['i',
#   'left',
#   'off',
#   'on',
#   'x',
#   'in',
#   'my',
#   '<unk>',
# ...
#   '<unk>',
#   'being',
#   'the',
#   'future',
#   'of',
#   'social',
#   'no',
#   'one',
#   'uses',
#   'facetime',
#   'and',
#   'video',
#   'chatting',
#   'is',
#   'private',
#   'not',
#   'social'],
#  ['needs', 'to', 'get', 'some', 'good', 'breakfast', 'right', 'now'],
#  ['favre', 'favre', 'favre', 'go', 'away', 'away'],
#  ['weve',
#   'already',
#   'learned',
#   'more',
#   'in',
#   'the',
#   'first',
#   'minutes',
#   'than',
#   'we',
#   'did',
#   'all',
#   'last',
#   'season',
#   'so',
#   'thats',
#   'a',
#   'start'],
#  ['took',
#   'service',
#   'learning',
#   'and',
#   'a',
#   'slavery',
#   'class',
#   'which',
#   'was',
#   'cool',
#   'gim',
#   'me',
#   'a',
#   'list',
#   'of',
#   'ur',
#   'options',
#   'so',
#   'i',
#   'can',
#   'tell',
#   'u',
#   'which',
#   'ones',
#   'lol'],
#  ['sigh',
#   'on',
#   'the',
#   'personal',
#   'side',
#   'got',
#   'ta',
#   'run',
#   'and',
#   'get',
#   'to',
#   'my',
#   '<unk>',
#   'strategic',
#   'credit',
#   'training'],
#  ['how', 'can', 'you', 'be', 'tired', 'one', 'directions', 'on', 'snl'],
#  ['ill',
#   'never',
#   'forget',
#   'the',
#   'mothers',
#   'day',
#   'when',
#   'i',
#   'saw',
#   'score',
#   'a',
#   '<unk>',
#   'vs',
#   '<unk>',
#   'with',
#   'his',
#   'mom',
#   'in',
#   'the',
#   'crowd'],
#  ['<unk>',
#   'of',
#   'snow',
#   'likely',
#   'along',
#   'a',
#   'line',
#   'from',
#   '<unk>',
#   'to',
#   'madison',
#   'to',
#   'green',
#   'bay',
#   'sun',
#   '<unk>',
#   'am',
#   'mon',
#   'am',
#   'travel',
#   'will',
#   'be',
#   '<unk>'],
#  ['spending',
#   'a',
#   'sleepless',
#   'night',
#   'working',
#   'on',
#   'marketing',
#   'and',
#   'advertising',
#   'sounds',
#   'like',
#   'a',
#   'deal',
#   'to',
#   'me'],
#  ['thanks',
#   'for',
#   'the',
#   'rt',
#   'hows',
#   'life',
#   'still',
#   'flying',
#   'around',
#   'the',
#   'country'],
#  ['<unk>', 'r', 'u', 'mad', 'at', 'me', 'now'],
#  ['hey', 'look', '<unk>', 'decided', 'to', 'show', 'up', 'today'],
#  ['madonna',
#   'tells',
#   'her',
#   'fans',
#   'they',
#   'should',
#   'save',
#   'all',
#   'year',
#   'to',
#   'attend',
#   'her',
#   'concert',
#   'id',
#   'rather',
#   'burn',
#   'my',
#   'money',
#   'after',
#   'that',
#   'show'],
#  ['its', 'chill', 'dummy', 'p', 'jk', 'haha', 'no', 'problem'],
#  ['hello',
#   'lovers',
#   'relax',
#   'after',
#   'school',
#   'going',
#   'shopping',
#   'with',
#   'my',
#   'parents',
#   'it',
#   'will',
#   'be',
#   'a',
#   'very',
#   'good',
#   'afternoon',
#   'see',
#   'u',
#   'soon',
#   'tweeps'],
#  ['getting',
#   'myself',
#   'set',
#   'up',
#   'for',
#   'the',
#   'big',
#   'move',
#   'to',
#   'madison',
#   'in',
#   'may',
#   'and',
#   'next',
#   'chapter',
#   'of',
#   'my',
#   'econ',
#   'dev',
#   'career'],
#  ['lolololol',
#   'did',
#   'we',
#   'seriously',
#   'just',
#   'have',
#   'to',
#   'take',
#   'a',
#   'love',
#   'survey'],
#  ['love', 'you'],
#  ['sick', 'movie'],
#  ['i',
#   'know',
#   'i',
#   'saw',
#   'omg',
#   '<unk>',
#   'your',
#   'so',
#   'lucky',
#   'i',
#   'cant',
#   'wait',
#   'until',
#   'the',
#   'day',
#   'ari',
#   'tweets',
#   'me'],
#  ['shouldve',
#   'hit',
#   'up',
#   'off',
#   'the',
#   'grid',
#   'at',
#   'fort',
#   'mason',
#   'great',
#   'weather'],
#  ['trying',
#   'to',
#   'decide',
#   'between',
#   'a',
#   'travel',
#   'destination',
#   'for',
#   'next',
#   'fall',
#   'london',
#   'boston',
#   'new',
#   'york',
#   'or',
#   'austin',
#   'ah',
#   'why',
#   'cant',
#   'i',
#   'be',
#   'in',
#   'four',
#   'places',
#   'at',
#   'once'],
#  ['dont',
#   '<unk>',
#   'dont',
#   'have',
#   'an',
#   'awkward',
#   'photo',
#   'booth',
#   'mt',
#   'its',
#   'drama',
#   'prom',
#   'day',
#   'may',
#   'it',
#   'go',
#   'better',
#   'than',
#   'my',
#   'high',
#   'school',
#   'prom'],
#  ['<unk>',
#   'should',
#   'be',
#   'ashamed',
#   'of',
#   'herself',
#   'no',
#   'class',
#   'what',
#   'so',
#   'ever',
#   'cant',
#   'argue',
#   '<unk>',
#   '<unk>',
#   'gon',
#   'na',
#   'get',
#   'hers',
#   '<unk>',
#   'a',
#   'bitch',
#   'remember',
#   'that'],
#  ['<unk>',
#   'phelps',
#   'is',
#   'lucky',
#   'he',
#   'doesnt',
#   'use',
#   'twitter',
#   'espn',
#   'should',
#   'have',
#   'him',
#   'apologize',
#   'to',
#   'the',
#   'kentucky',
#   'fans',
#   'he',
#   'put',
#   'down',
#   'like',
#   'we',
#   'were',
#   'his',
#   'kids'],
#  ['apparently',
#   'she',
#   'still',
#   'does',
#   'random',
#   'tv',
#   'vo',
#   'and',
#   'was',
#   'in',
#   'theres',
#   'something',
#   'about',
#   'mary',
#   'thanks',
#   'imdb',
#   'for',
#   'pointless',
#   'info'],
#  ['live',
#   'life',
#   'till',
#   'the',
#   'fullest',
#   'cause',
#   'you',
#   'never',
#   'really',
#   'know',
#   'what',
#   'you',
#   'got',
#   'till',
#   'its',
#   'gone'],
#  ['wow',
#   'tonight',
#   'at',
#   'if',
#   'your',
#   'not',
#   'here',
#   'tonight',
#   'you',
#   'have',
#   'no',
#   'right',
#   'to',
#   'call',
#   'yourself',
#   'a',
#   'resident',
#   'of',
#   'miami'],
#  ['best',
#   'present',
#   'i',
#   'got',
#   'for',
#   'xmas',
#   'was',
#   'your',
#   'book',
#   'love',
#   'it'],
#  ['amaze', 'balls', 'absolutely', 'love', 'it'],
#  ['i', 'need', 'to', 'get', 'out', 'of', 'this', 'ignorant', '<unk>', 'town'],
#  ['bout', 'to', 'watch', 'shallow', 'hal', 'and', 'call', 'it', 'a', 'day'],
#  ['playing',
#   'black',
#   'ops',
#   'makes',
#   'me',
#   'want',
#   'to',
#   'go',
#   'to',
#   'war',
#   'and',
#   'kick',
#   'some',
#   'ass',
#   'then',
#   'again',
#   'i',
#   'remember',
#   'the',
#   'times',
#   'i',
#   'die',
#   'so',
#   'fuck',
#   'that'],
#  ['well', 'change', 'that', 'please', 'right', 'on', 'thick', 'mama'],
#  ['like', 'a', 'boss'],
#  ['but', 'was', 'his', 'radio', 'show', 'truly', 'a', 'failure'],
#  ['jp',
#   'morgan',
#   'disaster',
#   'highlights',
#   'obama',
#   'failure',
#   '<unk>',
#   'actually',
#   'i',
#   'think',
#   'it',
#   'highlights',
#   'jp',
#   '<unk>',
#   'failure'],
#  ['didnt',
#   'realize',
#   'that',
#   '<unk>',
#   'won',
#   'best',
#   '<unk>',
#   'wings',
#   'that',
#   'was',
#   'my',
#   '<unk>',
#   'receipt',
#   'hell',
#   'yeah'],
#  ['it', 'most', 'certainly', 'does'],
#  ['taking',
#   '<unk>',
#   'off',
#   'my',
#   'reading',
#   'list',
#   'rt',
#   'you',
#   'must',
#   'live',
#   'for',
#   'another',
#   'if',
#   'you',
#   'wish',
#   'to',
#   'live',
#   'for',
#   'yourself',
#   '<unk>'],
#  ['is', 'weather', 'is', 'playing', 'gotcha', 'with', 'us'],
#  ['an',
#   'example',
#   'of',
#   'what',
#   'kind',
#   'of',
#   'business',
#   'man',
#   'romney',
#   'is',
#   'take',
#   'a',
#   'look',
#   'at',
#   'his',
#   'absolutely',
#   '<unk>',
#   'prediction',
#   'of',
#   'the',
#   'auto',
#   '<unk>'],
#  ['may',
#   'i',
#   '<unk>',
#   'ask',
#   'that',
#   'you',
#   'no',
#   'longer',
#   'send',
#   'any',
#   '<unk>',
#   'after',
#   'pm',
#   'dallas',
#   'time',
#   'thank',
#   'you',
#   'and',
#   'i',
#   'appreciate',
#   'you',
#   'dean'],
#  ['you',
#   'talk',
#   'shit',
#   'behind',
#   'peoples',
#   '<unk>',
#   'expect',
#   'them',
#   'not',
#   'to',
#   'get',
#   'mad',
#   '<unk>'],
#  ['girl',
#   'u',
#   'look',
#   'so',
#   'good',
#   'id',
#   'lick',
#   'the',
#   'ice',
#   'cream',
#   '<unk>',
#   'ya',
#   'cone',
#   'while',
#   'playing',
#   'with',
#   'the',
#   'cherry'],
#  ['glad', 'you', 'like', 'the', 'photos'],
#  ['three', 'horns', 'never', 'play', 'with', 'long', 'necks'],
#  ['<unk>', '<unk>', 'you', 'need', 'to', 'follow', 'me'],
#  ['working',
#   'at',
#   'a',
#   'coffee',
#   'shop',
#   'great',
#   'way',
#   'to',
#   'spend',
#   'a',
#   'beautiful',
#   'afternoon'],
#  ['thanks', 'supporting', 'the', 'spot'],
#  ['last',
#   'night',
#   'of',
#   '<unk>',
#   'for',
#   'awhile',
#   'i',
#   'am',
#   'excited',
#   'to',
#   '<unk>',
#   'myself',
#   'to',
#   'my',
#   'bed'],
#  ['hello',
#   '<unk>',
#   'this',
#   'is',
#   '<unk>',
#   'independence',
#   'week',
#   'and',
#   '<unk>',
#   'dallas',
#   'will',
#   'be',
#   'celebrating',
#   'it',
#   'thursday',
#   'friday',
#   'and',
#   'saturday',
#   'viva',
#   'mexico'],
#  ['is', 'that', 'the', 'one', 'at', '<unk>', 'corner'],
#  ['hope', 'you', 'feel', 'better', 'soon'],
#  ['<unk>', 'alex', 'whats', 'up'],
#  ['you',
#   'are',
#   'going',
#   'to',
#   'have',
#   'soo',
#   'much',
#   'fun',
#   'at',
#   'rodeo',
#   '<unk>',
#   'have',
#   'a',
#   'blast'],
#  ['feed', 'me', 'beats'],
#  ['got',
#   'distracted',
#   'by',
#   'the',
#   'new',
#   '<unk>',
#   'ultimate',
#   'ninja',
#   'storm',
#   'mwah',
#   'hahaha'],
#  ['<unk>', '<unk>', 'say', 'no', 'mo'],
#  ['working',
#   'trying',
#   'to',
#   'stay',
#   'out',
#   'of',
#   'trouble',
#   'just',
#   'making',
#   'sure',
#   'youre',
#   'doing',
#   'the',
#   'same'],
#  ['a',
#   'week',
#   'of',
#   'rising',
#   '<unk>',
#   'was',
#   'probably',
#   'too',
#   'good',
#   'to',
#   'be',
#   'true',
#   'futures',
#   'lower',
#   'market',
#   'will',
#   'hate',
#   'obamas',
#   'millionaire',
#   'tax',
#   'europe',
#   'still',
#   '<unk>'],
#  ['we',
#   'need',
#   'webb',
#   'jimmy',
#   'smith',
#   'cant',
#   'cover',
#   'anyone',
#   'apparently'],
#  ['well',
#   'thats',
#   'something',
#   'anyway',
#   'i',
#   'just',
#   'get',
#   'so',
#   'tired',
#   'of',
#   'the',
#   'world',
#   'how',
#   'people',
#   'treat',
#   'each',
#   'other',
#   'i',
#   'just',
#   'want',
#   'to',
#   'watch',
#   'baseball'],
#  ['<unk>', 'trend', 'analysis'],
#  ['okay', 'thanks'],
#  ['wrote', 'it', 'myself'],
#  ['online',
#   'presence',
#   'having',
#   'an',
#   'online',
#   'presence',
#   'gives',
#   'potential',
#   '<unk>',
#   'or',
#   'investors',
#   'and',
#   'customers',
#   'immediate',
#   'access',
#   'to',
#   'your',
#   'business'],
#  ['i', 'eat', 'it', 'n', 'treat', 'it'],
#  ['m',
#   'what',
#   'is',
#   'that',
#   'sweet',
#   '<unk>',
#   'smell',
#   '<unk>',
#   'down',
#   'the',
#   'avenue',
#   'oh',
#   'its',
#   'rabbit',
#   'fresh',
#   'from',
#   'the',
#   'oven',
#   'at',
#   'the',
#   'b',
#   'come',
#   'try',
#   'it',
#   'day'],
#  ['each',
#   'day',
#   'is',
#   'a',
#   'second',
#   'chance',
#   'dont',
#   'take',
#   'it',
#   'for',
#   'granted'],
#  ['<unk>',
#   'congrats',
#   'girl',
#   'so',
#   'proud',
#   'of',
#   'u',
#   'teacher',
#   '<unk>',
#   'na',
#   '<unk>'],
#  ['thanks',
#   'for',
#   'the',
#   'follow',
#   'im',
#   'an',
#   'actor',
#   'too',
#   'but',
#   'sadly',
#   'have',
#   'not',
#   'been',
#   'in',
#   'any',
#   'movies',
#   'or',
#   'tv',
#   'shows'],
#  ['brand',
#   'new',
#   'nod',
#   'roll',
#   'smoke',
#   'drops',
#   '<unk>',
#   'at',
#   'midnight',
#   'tonight',
#   'free',
#   '<unk>',
#   '<unk>',
#   '<unk>'],
#  ['s',
#   'most',
#   'recent',
#   'instagram',
#   'picture',
#   'haha',
#   'i',
#   'saw',
#   'the',
#   'no',
#   'fear',
#   'shakespeare',
#   'romeo',
#   'and',
#   'juliet'],
#  ['me',
#   'but',
#   'its',
#   'my',
#   'birthday',
#   'jeff',
#   'its',
#   'not',
#   'really',
#   'anymore'],
#  ['happy', 'mlk', 'day'],
#  ['did',
#   'jeter',
#   'and',
#   'ortiz',
#   'find',
#   'the',
#   'fountain',
#   'of',
#   'youth',
#   'over',
#   'the',
#   'break',
#   'or',
#   'what'],
#  ['are',
#   'you',
#   'a',
#   'professional',
#   '<unk>',
#   'follower',
#   'does',
#   'that',
#   'pay',
#   'well',
#   'i',
#   'need',
#   'a',
#   'job'],
#  ['robert',
#   'is',
#   'off',
#   'to',
#   'indianapolis',
#   'for',
#   'a',
#   'tax',
#   'day',
#   'ethics',
#   'speech',
#   'for',
#   '<unk>'],
#  ['im', 'so', 'sleepy', 'im', 'out', 'night', 'world'],
#  ['i',
#   'sure',
#   'hope',
#   'this',
#   'is',
#   'true',
#   'hard',
#   'drive',
#   'performance',
#   'is',
#   'one',
#   'of',
#   'the',
#   'last',
#   'mile',
#   'sticking',
#   'points',
#   'in',
#   'a',
#   'solid',
#   'creative',
#   'workflow'],
#  ['a', 'self', 'serve', 'frozen', 'yogurt', 'place', '<unk>'],
#  ['didnt',
#   'wan',
#   'na',
#   'get',
#   'up',
#   'but',
#   'im',
#   'sitting',
#   'here',
#   'with',
#   'a',
#   'cup',
#   'of',
#   'java',
#   'watching',
#   'the',
#   'early',
#   'morning',
#   'sunshine',
#   'creep',
#   'across',
#   'the',
#   'lawn',
#   'with',
#   'smile',
#   'on',
#   'my',
#   'face'],
#  ['actually',
#   'k',
#   'new',
#   'followers',
#   'if',
#   'he',
#   'could',
#   'eat',
#   'while',
#   'driving',
#   'would',
#   'be',
#   'good'],
#  ['i',
#   'will',
#   'never',
#   'call',
#   'a',
#   'guy',
#   'daddy',
#   'lol',
#   'that',
#   'ish',
#   'sounds',
#   'weird',
#   'and',
#   'awkward'],
#  ['we',
#   'have',
#   'lunch',
#   'box',
#   'specials',
#   'every',
#   'day',
#   'doors',
#   'open',
#   'at',
#   'am'],
#  ['natalie',
#   'my',
#   'shirt',
#   'looks',
#   'manly',
#   'because',
#   'i',
#   'like',
#   'manly',
#   'things',
#   'i',
#   'like',
#   'to',
#   'play',
#   'with',
#   '<unk>',
#   'trucks'],
#  ['filming',
#   'in',
#   '<unk>',
#   'upcoming',
#   'music',
#   'video',
#   'tomorrow',
#   'in',
#   'the',
#   'lead',
#   'role',
#   'of',
#   'the',
#   'club',
#   'owner',
#   'look',
#   'out',
#   'for',
#   'it',
#   'soon'],
#  ['<unk>',
#   'great',
#   'question',
#   'about',
#   'metrics',
#   'and',
#   'how',
#   'efficient',
#   'tax',
#   'dollars',
#   'are',
#   'at',
#   'use',
#   'by',
#   'state',
#   '<unk>'],
#  ['make',
#   'sure',
#   'to',
#   'like',
#   'this',
#   'page',
#   'the',
#   'old',
#   'einstein',
#   'music',
#   'page',
#   'will',
#   'be',
#   'taken',
#   'down',
#   'soon'],
#  ['im',
#   'gon',
#   'na',
#   'go',
#   'do',
#   'some',
#   'reading',
#   'now',
#   'guys',
#   'goodnight'],
#  ['week', 'email', 'sent', 'to', '<unk>', 'for', 'habitat', 'images'],
#  ['well',
#   'meh',
#   'why',
#   'would',
#   'that',
#   'interest',
#   'me',
#   'hahah',
#   'but',
#   'he',
#   'is',
#   'coming',
#   'to',
#   'indy',
#   'july',
#   'th'],
#  ['coming',
#   'to',
#   'dinner',
#   'in',
#   'philly',
#   'tonight',
#   'for',
#   'restaurant',
#   'week',
#   'ive',
#   'heard',
#   'amazing',
#   'things',
#   'cant',
#   'wait'],
#  ['btw',
#   'apparently',
#   '<unk>',
#   'was',
#   'seasonal',
#   'unfortunately',
#   'my',
#   'gluten',
#   '<unk>',
#   'isnt',
#   'sad',
#   'face',
#   'and',
#   'stomach'],
#  ['cnn',
#   'it',
#   'would',
#   'be',
#   'tragic',
#   'to',
#   'do',
#   'anything',
#   'that',
#   'might',
#   '<unk>',
#   'the',
#   'banks',
#   'in',
#   'their',
#   'quest',
#   'to',
#   'take',
#   'your',
#   'money',
#   'and',
#   'sit',
#   'on',
#   'it'],
#  ['how',
#   'does',
#   'one',
#   'prepare',
#   'for',
#   'straight',
#   'days',
#   'of',
#   'and',
#   'high',
#   'humidity'],
#  ['what',
#   'kind',
#   'of',
#   'pie',
#   'i',
#   'think',
#   'we',
#   'might',
#   'have',
#   '<unk>',
#   'to',
#   'you',
#   'about',
#   'the',
#   '<unk>',
#   'lack',
#   'of',
#   'proper',
#   'pies',
#   'over',
#   'here'],
#  ['christian', '<unk>'],
#  ['my',
#   'cab',
#   'driver',
#   'is',
#   'playing',
#   'dirty',
#   'rap',
#   'stay',
#   'classy',
#   'toledo'],
#  ['i', 'was', 'just', 'picking', 'it', 'up', 'lol'],
#  ['<unk>', 'not', 'real', 'that', 'is', 'a', 'fake', 'picture'],
#  ['one',
#   'week',
#   'from',
#   'now',
#   'i',
#   'will',
#   'be',
#   'getting',
#   'off',
#   'a',
#   'plane',
#   'in',
#   'austin',
#   'for',
#   '<unk>',
#   'not',
#   'wait'],
#  ['<unk>',
#   'with',
#   'terms',
#   'in',
#   'this',
#   '<unk>',
#   'webinar',
#   '<unk>',
#   'is',
#   'the',
#   'disc',
#   'service',
#   '<unk>',
#   'central',
#   'is',
#   'the',
#   '<unk>',
#   'index',
#   'used',
#   'w',
#   'or',
#   'wo',
#   '<unk>',
#   'right'],
#  ['no', 'dm', 'it', 'to', 'me'],
#  ['fifth',
#   'suggestion',
#   'work',
#   'on',
#   'spending',
#   'at',
#   'least',
#   'thirty',
#   'minutes',
#   'catching',
#   'up',
#   'on',
#   'the',
#   'days',
#   '<unk>',
#   'on',
#   'and',
#   'let',
#   'her',
#   'talk',
#   'you',
#   'listen'],
#  ['rt',
#   'chat',
#   'w',
#   '<unk>',
#   'brian',
#   '<unk>',
#   'networking',
#   'lounge',
#   'patron',
#   'profiles',
#   'can',
#   'support',
#   'pub',
#   'lib',
#   'decisions',
#   're',
#   'collections'],
#  ['its', 'going', 'to', 'be', 'a', 'long', 'list'],
#  ['three',
#   'weeks',
#   'still',
#   'no',
#   'word',
#   'frm',
#   '<unk>',
#   'on',
#   'corp',
#   'approval',
#   '<unk>',
#   're',
#   '<unk>',
#   'week',
#   'was',
#   'word',
#   'now',
#   'no',
#   'answer',
#   'emails'],
#  ['placing',
#   '<unk>',
#   'for',
#   'another',
#   'happy',
#   'client',
#   'on',
#   '<unk>',
#   'pens',
#   'thanks',
#   'dan',
#   'v'],
#  ['<unk>',
#   'rt',
#   'and',
#   'keeping',
#   'me',
#   'from',
#   'a',
#   'cocktail',
#   'is',
#   '<unk>',
#   'pictures',
#   'with',
#   'voice'],
#  ['soon', 'enough', 'that', 'may', 'change'],
#  ['traffic',
#   'alert',
#   'semi',
#   'fire',
#   'nb',
#   'near',
#   'mm',
#   'near',
#   'anderson',
#   'and',
#   'use',
#   'caution',
#   'in',
#   'area'],
#  ['doesnt',
#   'seem',
#   'to',
#   'be',
#   'a',
#   'big',
#   'storm',
#   'coming',
#   'looking',
#   'at',
#   'the',
#   'radar',
#   'if',
#   'you',
#   'dont',
#   'mind',
#   'being',
#   'rained',
#   'on',
#   'a',
#   'little',
#   'youre',
#   'in',
#   'for',
#   'a',
#   'w'],
#  ['the',
#   'party',
#   'is',
#   'going',
#   'to',
#   'have',
#   'to',
#   'reel',
#   'him',
#   'in',
#   'but',
#   'i',
#   'think',
#   'its',
#   'too',
#   'late',
#   'his',
#   '<unk>',
#   'and',
#   'lack',
#   'of',
#   'any',
#   'humility',
#   'has',
#   'already',
#   'lost',
#   'it'],
#  ['what', 'more', 'could', 'you', 'have', 'asked', 'for'],
#  ['theres',
#   'a',
#   '<unk>',
#   'on',
#   'your',
#   'face',
#   'in',
#   'that',
#   'commercial',
#   'gross'],
#  ['haha', 'hey', 'jake'],
#  ['<unk>', '<unk>', 'family', 'dad', 'must', 'be', 'rolling', 'over'],
#  ['can',
#   'not',
#   '<unk>',
#   'enough',
#   'praise',
#   'upon',
#   'hairspray',
#   'presented',
#   'by',
#   'theater',
#   'students',
#   'at',
#   'the',
#   '<unk>',
#   'performances',
#   'thru'],
#  ...]

# %%
from nltk.util import ngrams
from collections import Counter

def count_n_grams_builtin(data, n, start_token="<s>", end_token="<e>") -> dict:
    # Flatten the list of tokenized sentences into a single list of words
    all_words = [word for sentence in data for word in sentence]

    # Add start and end tokens to the list
    all_words = [start_token] * (n - 1) + all_words + [end_token]

    # Use NLTK's ngrams function to obtain n-grams
    n_grams = list(ngrams(all_words, n))

    # Use Counter to count the occurrences of each n-gram
    n_gram_counts = Counter(n_grams)

    return n_gram_counts

# %%
ngramstraing =  count_n_grams_builtin(final_train, 2)
ngramstraing
# Out:
# Counter({('<unk>', '<unk>'): 86971,
#          ('the', '<unk>'): 58550,
#          ('in', 'the'): 46946,
#          ('for', 'the'): 44357,
#          ('of', 'the'): 34331,
#          ('a', '<unk>'): 33111,
#          ('on', 'the'): 29261,
#          ('<unk>', 'and'): 28315,
#          ('to', 'be'): 28151,
#          ('<unk>', 'i'): 27735,
#          ('to', 'the'): 26049,
#          ('thanks', 'for'): 25700,
#          ('to', '<unk>'): 23478,
#          ('at', 'the'): 22249,
#          ('<unk>', 'is'): 21813,
#          ('i', 'love'): 21006,
#          ('and', '<unk>'): 20955,
#          ('going', 'to'): 20525,
#          ('have', 'a'): 20178,
#          ('if', 'you'): 19811,
#          ('thank', 'you'): 19617,
#          ('of', '<unk>'): 19287,
#          ('i', 'have'): 18722,
#          ('<unk>', 'in'): 17964,
#          ('for', 'a'): 17809,
#          ('i', 'am'): 17703,
#          ('i', 'dont'): 17294,
#          ('<unk>', 'to'): 16805,
#          ('<unk>', 'the'): 16586,
#          ('at', '<unk>'): 16428,
#          ('to', 'get'): 16230,
#          ('to', 'see'): 16168,
#          ('is', 'a'): 16108,
#          ('in', '<unk>'): 15773,
#          ('will', 'be'): 15489,
#          ('i', 'was'): 15120,
#          ('i', 'think'): 14909,
#          ('want', 'to'): 14854,
#          ('<unk>', 'for'): 14638,
#          ('is', 'the'): 14416,
#          ('a', 'great'): 14272,
#          ('in', 'a'): 14048,
#          ('i', 'just'): 14002,
#          ('you', 'are'): 13925,
#          ('are', 'you'): 13877,
#          ('for', '<unk>'): 13772,
#          ('have', 'to'): 13385,
#          ('and', 'i'): 13144,
#          ('gon', 'na'): 12950,
#          ('<unk>', 'of'): 12563,
#          ('need', 'to'): 12463,
#          ('<unk>', 'on'): 12425,
#          ('my', '<unk>'): 12403,
#          ('it', 'was'): 12337,
#          ('i', 'can'): 12189,
#          ('do', 'you'): 11760,
#          ('on', '<unk>'): 11629,
#          ('i', 'know'): 11620,
#          ('you', 'have'): 11416,
#          ('the', 'best'): 11347,
#          ('with', 'the'): 11091,
#          ('all', 'the'): 11071,
#          ('but', 'i'): 11013,
#          ('so', 'much'): 10878,
#          ('to', 'do'): 10788,
#          ('a', 'good'): 10722,
#          ('it', 'is'): 10602,
#          ('to', 'go'): 10486,
#          ('i', 'cant'): 10300,
#          ('be', 'a'): 10193,
#          ('is', '<unk>'): 10190,
#          ('in', 'my'): 10184,
#          ('on', 'my'): 10166,
#          ('cant', 'wait'): 10095,
#          ('<unk>', 'you'): 10056,
#          ('you', 'can'): 9955,
#          ('right', 'now'): 9603,
#          ('of', 'my'): 9506,
#          ('i', 'will'): 9365,
#          ('you', 'know'): 9312,
#          ('one', 'of'): 9262,
#          ('this', 'is'): 9261,
#          ('love', 'you'): 9242,
#          ('i', 'need'): 9236,
#          ('out', 'of'): 9210,
#          ('and', 'the'): 9060,
#          ('like', 'a'): 9037,
#          ('i', 'want'): 8966,
#          ('we', 'are'): 8868,
#          ('<unk>', 'a'): 8847,
#          ('wan', 'na'): 8551,
#          ('when', 'i'): 8454,
#          ('with', 'a'): 8376,
#          ('with', '<unk>'): 8275,
#          ('go', 'to'): 8272,
#          ('on', 'a'): 8207,
#          ('when', 'you'): 8171,
#          ('<unk>', 'at'): 8166,
#          ('i', 'got'): 8084,
#          ('you', '<unk>'): 7962,
#          ('see', 'you'): 7836,
#          ('had', 'a'): 7832,
#          ('if', 'i'): 7598,
#          ('that', 'i'): 7535,
#          ('<unk>', 'with'): 7525,
#          ('the', 'same'): 7498,
#          ('of', 'a'): 7325,
#          ('follow', 'me'): 7227,
#          ('a', 'lot'): 7218,
#          ('from', 'the'): 7199,
#          ('for', 'you'): 7108,
#          ('im', 'not'): 6970,
#          ('forward', 'to'): 6960,
#          ('<unk>', 'my'): 6884,
#          ('last', 'night'): 6869,
#          ('<unk>', 'are'): 6795,
#          ('to', 'make'): 6787,
#          ('would', 'be'): 6783,
#          ('was', 'a'): 6763,
#          ('to', 'my'): 6758,
#          ('that', '<unk>'): 6751,
#          ('to', 'have'): 6674,
#          ('to', 'you'): 6655,
#          ('trying', 'to'): 6645,
#          ('i', 'would'): 6645,
#          ('i', 'hope'): 6556,
#          ('to', 'me'): 6501,
#          ('your', '<unk>'): 6499,
#          ('got', 'ta'): 6498,
#          ('time', 'to'): 6411,
#          ('<unk>', 'im'): 6398,
#          ('its', 'a'): 6361,
#          ('the', 'world'): 6334,
#          ('you', 'for'): 6328,
#          ('way', 'to'): 6328,
#          ('a', 'new'): 6324,
#          ('so', 'i'): 6290,
#          ('back', 'to'): 6286,
#          ('i', 'hate'): 6286,
#          ('be', '<unk>'): 6277,
#          ('did', 'you'): 6235,
#          ('<unk>', 'that'): 6217,
#          ('<unk>', 'it'): 6196,
#          ('i', 'get'): 6168,
#          ('to', 'a'): 6118,
#          ('with', 'my'): 6109,
#          ('for', 'me'): 6097,
#          ('the', 'new'): 6023,
#          ('get', 'a'): 5999,
#          ('it', '<unk>'): 5995,
#          ('that', 'is'): 5917,
#          ('i', 'had'): 5916,
#          ('i', 'like'): 5816,
#          ('i', '<unk>'): 5813,
#          ('we', 'have'): 5813,
#          ('i', 'feel'): 5800,
#          ('about', 'the'): 5781,
#          ('you', 'guys'): 5775,
#          ('what', 'you'): 5746,
#          ('the', 'first'): 5737,
#          ('a', 'little'): 5700,
#          ('<unk>', 'but'): 5637,
#          ('and', 'a'): 5615,
#          ('you', 'dont'): 5591,
#          ('wait', 'to'): 5541,
#          ('the', 'day'): 5506,
#          ('should', 'be'): 5502,
#          ('<unk>', 'this'): 5406,
#          ('from', '<unk>'): 5398,
#          ('i', 'could'): 5366,
#          ('looking', 'forward'): 5358,
#          ('is', 'not'): 5305,
#          ('an', '<unk>'): 5296,
#          ('<unk>', 'just'): 5273,
#          ('a', 'few'): 5253,
#          ('as', 'a'): 5253,
#          ('is', 'it'): 5248,
#          ('for', 'my'): 5241,
#          ('me', 'i'): 5238,
#          ('dont', 'know'): 5202,
#          ('all', 'of'): 5146,
#          ('check', 'out'): 5141,
#          ('i', 'do'): 5129,
#          ('i', 'wish'): 5103,
#          ('<unk>', 'rt'): 5015,
#          ('me', 'to'): 4986,
#          ('happy', 'birthday'): 4986,
#          ('<unk>', 'so'): 4981,
#          ('with', 'you'): 4976,
#          ('you', 'and'): 4973,
#          ('the', 'follow'): 4971,
#          ('by', 'the'): 4913,
#          ('they', 'are'): 4899,
#          ('you', 'want'): 4874,
#          ('<unk>', 'thanks'): 4866,
#          ('hope', 'you'): 4857,
#          ('<unk>', 'we'): 4848,
#          ('the', 'only'): 4818,
#          ('there', 'is'): 4804,
#          ('do', 'it'): 4798,
#          ('for', 'your'): 4779,
#          ('let', 'me'): 4774,
#          ('the', 'way'): 4772,
#          ('to', 'all'): 4771,
#          ('<unk>', 'its'): 4769,
#          ('in', 'your'): 4759,
#          ('you', 'to'): 4743,
#          ('we', 'can'): 4733,
#          ('what', 'i'): 4724,
#          ('good', 'morning'): 4677,
#          ('<unk>', 'or'): 4671,
#          ('got', 'a'): 4666,
#          ('to', 'hear'): 4643,
#          ('be', 'the'): 4615,
#          ('i', 'miss'): 4593,
#          ('how', 'to'): 4562,
#          ('me', '<unk>'): 4557,
#          ('you', 'i'): 4552,
#          ('make', 'it'): 4546,
#          ('this', 'weekend'): 4546,
#          ('that', 'was'): 4537,
#          ('of', 'your'): 4518,
#          ('lol', 'i'): 4511,
#          ('love', 'to'): 4504,
#          ('just', 'got'): 4497,
#          ('at', 'least'): 4489,
#          ('looking', 'for'): 4484,
#          ('the', 'most'): 4481,
#          ('im', 'so'): 4460,
#          ('i', 'didnt'): 4439,
#          ('it', 'i'): 4422,
#          ('what', 'a'): 4418,
#          ('know', 'what'): 4412,
#          ('is', 'so'): 4407,
#          ('<unk>', 'from'): 4402,
#          ('im', 'going'): 4383,
#          ('ill', 'be'): 4375,
#          ('i', 'really'): 4374,
#          ('like', 'the'): 4373,
#          ('on', 'your'): 4346,
#          ('my', 'life'): 4340,
#          ('<unk>', 'was'): 4340,
#          ('have', 'you'): 4335,
#          ('<unk>', 'if'): 4330,
#          ('to', 'say'): 4305,
#          ('on', 'twitter'): 4300,
#          ('<unk>', 'will'): 4283,
#          ('are', 'the'): 4281,
#          ('are', '<unk>'): 4275,
#          ('its', 'not'): 4263,
#          ('this', 'week'): 4259,
#          ('this', 'morning'): 4251,
#          ('na', 'be'): 4248,
#          ('now', 'i'): 4245,
#          ('you', 'should'): 4244,
#          ('you', 'get'): 4231,
#          ('not', 'a'): 4226,
#          ('wish', 'i'): 4215,
#          ('to', 'work'): 4195,
#          ('like', 'to'): 4193,
#          ('of', 'you'): 4184,
#          ('you', 'think'): 4169,
#          ('is', 'that'): 4155,
#          ('need', 'a'): 4143,
#          ('that', 'you'): 4135,
#          ('about', 'to'): 4131,
#          ('is', 'going'): 4122,
#          ('feel', 'like'): 4115,
#          ('me', 'and'): 4102,
#          ('what', 'is'): 4099,
#          ('up', 'to'): 4083,
#          ('ready', 'for'): 4078,
#          ('this', '<unk>'): 4075,
#          ('you', 'do'): 4071,
#          ('have', 'been'): 4067,
#          ('out', 'to'): 4048,
#          ('it', 'to'): 4044,
#          ('like', '<unk>'): 4042,
#          ('<unk>', 'me'): 4035,
#          ('love', 'it'): 4033,
#          ('lot', 'of'): 3972,
#          ('about', '<unk>'): 3971,
#          ('get', 'to'): 3962,
#          ('thanks', 'to'): 3959,
#          ('such', 'a'): 3957,
#          ('love', 'the'): 3914,
#          ('at', 'pm'): 3890,
#          ('and', 'you'): 3886,
#          ('by', '<unk>'): 3858,
#          ('the', 'last'): 3851,
#          ('<unk>', 'by'): 3849,
#          ('listening', 'to'): 3846,
#          ('the', 'next'): 3839,
#          ('new', '<unk>'): 3833,
#          ('has', 'been'): 3825,
#          ('i', 'thought'): 3822,
#          ('good', 'luck'): 3787,
#          ('me', 'a'): 3763,
#          ('ready', 'to'): 3756,
#          ('or', '<unk>'): 3752,
#          ('you', 'were'): 3746,
#          ('im', 'a'): 3733,
#          ('i', 'guess'): 3727,
#          ('have', 'the'): 3711,
#          ('<unk>', 'what'): 3689,
#          ('be', 'in'): 3660,
#          ('i', 'see'): 3656,
#          ('looks', 'like'): 3647,
#          ('rt', '<unk>'): 3631,
#          ('ive', 'been'): 3626,
#          ('can', 'you'): 3611,
#          ('more', 'than'): 3595,
#          ('get', 'it'): 3570,
#          ('to', 'come'): 3568,
#          ('is', 'my'): 3566,
#          ('dont', 'have'): 3563,
#          ('to', 'take'): 3552,
#          ('you', 'need'): 3550,
#          ('to', 'your'): 3526,
#          ('kind', 'of'): 3515,
#          ('out', 'the'): 3510,
#          ('part', 'of'): 3504,
#          ('this', 'year'): 3502,
#          ('it', 'out'): 3498,
#          ('think', 'i'): 3490,
#          ('has', 'a'): 3475,
#          ('miss', 'you'): 3456,
#          ('to', 'know'): 3447,
#          ('as', 'well'): 3436,
#          ('you', 'in'): 3420,
#          ('of', 'our'): 3418,
#          ('up', 'with'): 3390,
#          ('rt', 'i'): 3389,
#          ('we', 'will'): 3388,
#          ('the', 'time'): 3368,
#          ('you', 'too'): 3358,
#          ('to', 'watch'): 3356,
#          ('<unk>', 'when'): 3349,
#          ('and', 'im'): 3337,
#          ('<unk>', 'today'): 3331,
#          ('<unk>', 'as'): 3322,
#          ('was', '<unk>'): 3318,
#          ('<unk>', 'lol'): 3315,
#          ('you', 'so'): 3315,
#          ('some', '<unk>'): 3312,
#          ('<unk>', 'your'): 3309,
#          ('im', '<unk>'): 3308,
#          ('of', 'course'): 3300,
#          ('<unk>', 'has'): 3289,
#          ('for', 'all'): 3283,
#          ('so', '<unk>'): 3282,
#          ('can', 'i'): 3282,
#          ('do', 'i'): 3281,
#          ('he', 'is'): 3274,
#          ('to', 'start'): 3271,
#          ('mothers', 'day'): 3261,
#          ('just', '<unk>'): 3253,
#          ('see', 'the'): 3245,
#          ('with', 'me'): 3229,
#          ('my', 'favorite'): 3229,
#          ('you', 'will'): 3223,
#          ('our', '<unk>'): 3219,
#          ('you', 'a'): 3218,
#          ('was', 'the'): 3207,
#          ('there', 'are'): 3201,
#          ('can', 'be'): 3180,
#          ('am', 'i'): 3165,
#          ('up', 'for'): 3149,
#          ('get', 'the'): 3142,
#          ('my', 'mom'): 3138,
#          ('no', 'one'): 3123,
#          ('all', 'day'): 3123,
#          ('about', 'it'): 3122,
#          ('not', '<unk>'): 3121,
#          ('in', 'this'): 3119,
#          ('you', 'cant'): 3114,
#          ('come', 'to'): 3112,
#          ('you', 'got'): 3110,
#          ('lots', 'of'): 3107,
#          ('time', 'for'): 3101,
#          ('you', 'like'): 3100,
#          ('time', 'i'): 3099,
#          ('up', 'and'): 3098,
#          ('a', 'big'): 3088,
#          ('having', 'a'): 3086,
#          ('and', 'then'): 3076,
#          ('at', 'a'): 3074,
#          ('up', 'on'): 3063,
#          ('the', 'game'): 3062,
#          ('i', 'wan'): 3056,
#          ('is', 'on'): 3056,
#          ('but', 'im'): 3052,
#          ('<unk>', 'not'): 3049,
#          ('tell', 'me'): 3040,
#          ('its', '<unk>'): 3039,
#          ('i', 'did'): 3036,
#          ('for', 'following'): 3034,
#          ('<unk>', 'all'): 3030,
#          ('so', 'far'): 3021,
#          ('what', 'are'): 3019,
#          ('that', 'the'): 3019,
#          ('to', 'meet'): 3003,
#          ('able', 'to'): 2993,
#          ('we', 'need'): 2990,
#          ('working', 'on'): 2987,
#          ('make', 'a'): 2967,
#          ('on', 'this'): 2965,
#          ('is', 'in'): 2956,
#          ('so', 'many'): 2954,
#          ('just', 'a'): 2950,
#          ('have', '<unk>'): 2941,
#          ('my', 'new'): 2937,
#          ('had', 'to'): 2929,
#          ('wait', 'for'): 2917,
#          ('take', 'a'): 2915,
#          ('out', 'there'): 2913,
#          ('to', 'find'): 2903,
#          ('up', 'the'): 2898,
#          ('day', 'of'): 2896,
#          ('if', 'youre'): 2870,
#          ('the', 'end'): 2864,
#          ('<unk>', 'no'): 2860,
#          ('it', 'up'): 2852,
#          ('back', 'in'): 2851,
#          ('makes', 'me'): 2841,
#          ('me', 'know'): 2839,
#          ('next', 'week'): 2834,
#          ('im', 'in'): 2832,
#          ('<unk>', 'up'): 2827,
#          ('and', 'it'): 2823,
#          ('the', 'other'): 2820,
#          ('like', 'that'): 2810,
#          ('excited', 'to'): 2810,
#          ('<unk>', 'out'): 2805,
#          ('some', 'of'): 2789,
#          ('<unk>', 'have'): 2789,
#          ('it', 'will'): 2784,
#          ('like', 'it'): 2778,
#          ('no', '<unk>'): 2777,
#          ('better', 'than'): 2768,
#          ('know', 'how'): 2765,
#          ('all', 'my'): 2763,
#          ('more', '<unk>'): 2758,
#          ('know', 'i'): 2756,
#          ('try', 'to'): 2754,
#          ('i', 'should'): 2740,
#          ('you', 'just'): 2732,
#          ('you', 'all'): 2729,
#          ('used', 'to'): 2726,
#          ('talking', 'about'): 2717,
#          ('would', 'love'): 2717,
#          ('today', 'i'): 2715,
#          ('all', 'i'): 2701,
#          ('to', 'follow'): 2697,
#          ('for', 'this'): 2697,
#          ('too', 'much'): 2694,
#          ('<unk>', 'tonight'): 2681,
#          ('can', 'not'): 2677,
#          ('be', 'there'): 2673,
#          ('out', '<unk>'): 2667,
#          ('the', 'rt'): 2666,
#          ('and', 'my'): 2645,
#          ('i', 'still'): 2644,
#          ('follow', 'back'): 2643,
#          ('but', 'it'): 2642,
#          ('the', 'th'): 2638,
#          ('<unk>', 'now'): 2638,
#          ('it', 'would'): 2632,
#          ('talk', 'to'): 2631,
#          ('life', 'is'): 2629,
#          ('how', 'much'): 2625,
#          ('it', 'in'): 2614,
#          ('to', 'help'): 2608,
#          ('he', 'was'): 2604,
#          ('not', 'the'): 2596,
#          ('good', 'to'): 2594,
#          ('with', 'your'): 2594,
#          ('day', 'to'): 2583,
#          ('of', 'it'): 2582,
#          ('is', 'to'): 2582,
#          ('if', 'u'): 2579,
#          ('me', 'too'): 2561,
#          ('into', 'the'): 2557,
#          ('a', 'long'): 2547,
#          ('the', 'one'): 2545,
#          ('needs', 'to'): 2543,
#          ('dont', 'want'): 2538,
#          ('at', 'all'): 2538,
#          ('off', 'to'): 2530,
#          ('not', 'to'): 2527,
#          ('so', 'excited'): 2526,
#          ('not', 'sure'): 2526,
#          ('great', 'day'): 2524,
#          ('<unk>', 'how'): 2520,
#          ('are', 'so'): 2519,
#          ('all', '<unk>'): 2516,
#          ('im', 'gon'): 2515,
#          ('sounds', 'like'): 2513,
#          ('and', 'get'): 2504,
#          ('do', 'not'): 2503,
#          ('<unk>', 'can'): 2501,
#          ('love', '<unk>'): 2497,
#          ('to', 'win'): 2497,
#          ('to', 'our'): 2495,
#          ('i', 'havent'): 2492,
#          ('for', 'some'): 2490,
#          ('up', '<unk>'): 2490,
#          ('to', 'sleep'): 2486,
#          ('how', 'are'): 2483,
#          ('be', 'on'): 2478,
#          ('come', 'on'): 2477,
#          ('for', 'our'): 2475,
#          ('day', 'i'): 2471,
#          ('up', 'in'): 2470,
#          ('today', 'is'): 2468,
#          ('over', 'the'): 2451,
#          ('its', 'the'): 2449,
#          ('please', 'follow'): 2442,
#          ('i', 'saw'): 2437,
#          ('<unk>', 'good'): 2433,
#          ('yes', 'i'): 2431,
#          ('but', 'the'): 2424,
#          ('to', 'play'): 2423,
#          ('lets', 'go'): 2421,
#          ('what', 'the'): 2419,
#          ('what', 'do'): 2405,
#          ('and', 'we'): 2402,
#          ('the', 'show'): 2402,
#          ('look', 'at'): 2400,
#          ('dont', 'think'): 2398,
#          ('listen', 'to'): 2396,
#          ('can', 'do'): 2393,
#          ('<unk>', 'dont'): 2386,
#          ('get', '<unk>'): 2384,
#          ('im', 'just'): 2383,
#          ('end', 'of'): 2381,
#          ('like', 'i'): 2379,
#          ('to', 'talk'): 2378,
#          ('know', 'that'): 2377,
#          ('off', 'the'): 2360,
#          ('got', 'to'): 2358,
#          ('have', 'no'): 2358,
#          ('make', 'sure'): 2341,
#          ('<unk>', 'love'): 2340,
#          ('make', 'me'): 2337,
#          ('who', 'is'): 2329,
#          ('a', 'day'): 2328,
#          ('a', 'bit'): 2326,
#          ('could', 'be'): 2324,
#          ('it', 'on'): 2317,
#          ('you', 'on'): 2317,
#          ('and', 'its'): 2312,
#          ('going', 'on'): 2310,
#          ('because', 'i'): 2308,
#          ('as', 'i'): 2307,
#          ('is', 'your'): 2305,
#          ('social', 'media'): 2301,
#          ('but', 'its'): 2298,
#          ('are', 'a'): 2297,
#          ('tonight', 'at'): 2296,
#          ('<unk>', 'like'): 2296,
#          ('wanted', 'to'): 2291,
#          ('like', 'you'): 2286,
#          ('how', 'many'): 2279,
#          ('know', 'if'): 2277,
#          ('hard', 'to'): 2272,
#          ('day', '<unk>'): 2267,
#          ('shout', 'out'): 2259,
#          ('people', 'who'): 2255,
#          ('my', 'phone'): 2254,
#          ('must', 'be'): 2250,
#          ('at', 'my'): 2240,
#          ('glad', 'you'): 2236,
#          ('been', 'a'): 2235,
#          ('i', 'never'): 2234,
#          ('would', 'have'): 2231,
#          ('of', 'this'): 2227,
#          ('waiting', 'for'): 2226,
#          ('for', 'that'): 2226,
#          ('wants', 'to'): 2219,
#          ('the', 'word'): 2211,
#          ('watching', 'the'): 2210,
#          ('would', 'you'): 2208,
#          ('on', 'it'): 2204,
#          ('to', 'keep'): 2198,
#          ('at', 'work'): 2194,
#          ('out', 'for'): 2191,
#          ('you', 'love'): 2191,
#          ('how', 'do'): 2184,
#          ('<unk>', 'who'): 2173,
#          ('just', 'saw'): 2173,
#          ('on', 'that'): 2167,
#          ('of', 'all'): 2159,
#          ('thats', 'a'): 2156,
#          ('yeah', 'i'): 2156,
#          ('from', 'a'): 2148,
#          ('of', 'them'): 2146,
#          ('welcome', 'to'): 2137,
#          ('can', 'get'): 2136,
#          ('but', 'you'): 2135,
#          ('first', 'time'): 2128,
#          ('is', 'just'): 2128,
#          ('you', 'at'): 2128,
#          ('<unk>', 'u'): 2120,
#          ('the', 'rest'): 2113,
#          ('me', 'up'): 2105,
#          ('as', '<unk>'): 2098,
#          ('it', 'and'): 2096,
#          ('is', 'this'): 2092,
#          ('know', 'you'): 2088,
#          ('good', '<unk>'): 2083,
#          ('now', '<unk>'): 2080,
#          ('<unk>', 'do'): 2078,
#          ('it', 'all'): 2073,
#          ('is', 'an'): 2065,
#          ('haha', 'i'): 2055,
#          ('to', 'it'): 2055,
#          ('me', 'on'): 2054,
#          ('its', 'been'): 2054,
#          ('my', 'first'): 2052,
#          ('have', 'an'): 2050,
#          ('my', 'friend'): 2044,
#          ('might', 'be'): 2039,
#          ('me', 'in'): 2037,
#          ('congrats', 'to'): 2035,
#          ('for', 'it'): 2032,
#          ('whats', 'up'): 2032,
#          ('thats', 'what'): 2029,
#          ('when', 'the'): 2027,
#          ('at', 'am'): 2027,
#          ('you', 'could'): 2025,
#          ('went', 'to'): 2022,
#          ('the', 'right'): 2020,
#          ('happy', 'mothers'): 2017,
#          ('they', 'have'): 2013,
#          ('dont', 'forget'): 2013,
#          ('love', 'that'): 2012,
#          ('well', 'i'): 2010,
#          ('so', 'good'): 2010,
#          ('in', 'our'): 2006,
#          ('look', 'like'): 2004,
#          ('the', 'whole'): 2001,
#          ('why', 'do'): 1993,
#          ('to', 'give'): 1984,
#          ('glad', 'to'): 1983,
#          ('i', 'mean'): 1981,
#          ('for', 'an'): 1980,
#          ('<unk>', 'they'): 1978,
#          ('is', 'like'): 1978,
#          ('much', 'for'): 1976,
#          ('here', 'in'): 1976,
#          ('i', 'wonder'): 1972,
#          ('not', 'be'): 1970,
#          ('rt', 'if'): 1969,
#          ('think', 'of'): 1966,
#          ('on', 'our'): 1965,
#          ('out', 'and'): 1962,
#          ('<unk>', 'about'): 1961,
#          ('you', 'the'): 1960,
#          ('should', 'have'): 1959,
#          ('of', 'us'): 1955,
#          ('my', 'friends'): 1952,
#          ('hope', 'to'): 1951,
#          ('if', 'it'): 1950,
#          ('great', 'to'): 1947,
#          ('that', 'would'): 1946,
#          ('was', 'just'): 1944,
#          ('why', 'i'): 1943,
#          ('we', 'love'): 1941,
#          ('go', '<unk>'): 1940,
#          ('<unk>', 'happy'): 1938,
#          ('excited', 'for'): 1933,
#          ('a', 'couple'): 1933,
#          ('thanks', 'so'): 1928,
#          ('of', 'those'): 1928,
#          ('<unk>', 'thats'): 1926,
#          ('a', 'very'): 1925,
#          ('theres', 'a'): 1919,
#          ('how', 'you'): 1916,
#          ('nice', 'to'): 1914,
#          ('coming', 'to'): 1913,
#          ('talk', 'about'): 1911,
#          ('about', 'you'): 1909,
#          ('your', 'favorite'): 1909,
#          ('as', 'the'): 1902,
#          ('and', 'your'): 1901,
#          ('great', '<unk>'): 1901,
#          ('but', '<unk>'): 1892,
#          ('instead', 'of'): 1890,
#          ('lol', '<unk>'): 1888,
#          ('i', 'always'): 1883,
#          ('get', 'your'): 1881,
#          ('a', 'while'): 1881,
#          ('got', 'the'): 1879,
#          ('<unk>', 'thank'): 1878,
#          ('do', 'the'): 1878,
#          ('if', 'they'): 1875,
#          ('dont', 'get'): 1874,
#          ('rest', 'of'): 1874,
#          ('dont', 'like'): 1873,
#          ('a', 'man'): 1868,
#          ('happy', 'to'): 1864,
#          ('love', 'your'): 1863,
#          ('how', 'i'): 1859,
#          ('have', 'fun'): 1858,
#          ('get', 'my'): 1858,
#          ('your', 'life'): 1856,
#          ('in', 'love'): 1853,
#          ('if', 'the'): 1852,
#          ('live', 'in'): 1849,
#          ('be', 'at'): 1849,
#          ('join', 'us'): 1847,
#          ('call', 'me'): 1847,
#          ('cant', 'believe'): 1845,
#          ('it', 'just'): 1833,
#          ('do', 'that'): 1830,
#          ('<unk>', 'got'): 1828,
#          ('an', 'amazing'): 1827,
#          ('why', 'is'): 1818,
#          ('it', 'a'): 1814,
#          ('is', 'there'): 1813,
#          ('did', 'i'): 1812,
#          ('his', '<unk>'): 1811,
#          ('if', 'we'): 1810,
#          ('sure', 'to'): 1809,
#          ('a', 'nice'): 1804,
#          ('you', 'see'): 1803,
#          ('the', 'people'): 1802,
#          ('that', 'one'): 1801,
#          ('you', 'had'): 1799,
#          ('are', 'not'): 1799,
#          ('<unk>', 'new'): 1794,
#          ('<unk>', 'oh'): 1791,
#          ('to', 'for'): 1790,
#          ('people', 'are'): 1788,
#          ('from', 'my'): 1788,
#          ('the', 'morning'): 1785,
#          ('me', 'the'): 1781,
#          ('to', 'bed'): 1777,
#          ('being', 'a'): 1771,
#          ('will', 'you'): 1770,
#          ('<unk>', 'he'): 1764,
#          ('to', 'use'): 1762,
#          ('my', 'head'): 1760,
#          ('day', 'in'): 1755,
#          ('let', 'us'): 1753,
#          ('may', 'be'): 1753,
#          ('im', 'sure'): 1751,
#          ('the', 'weekend'): 1751,
#          ('and', 'now'): 1747,
#          ('wake', 'up'): 1747,
#          ('she', 'is'): 1747,
#          ('it', 'for'): 1743,
#          ('new', 'year'): 1743,
#          ('getting', 'ready'): 1741,
#          ('of', 'me'): 1741,
#          ('see', 'it'): 1738,
#          ('my', 'day'): 1738,
#          ('and', 'not'): 1733,
#          ('is', 'no'): 1732,
#          ('with', 'that'): 1732,
#          ('will', 'have'): 1730,
#          ('like', 'this'): 1729,
#          ('got', 'my'): 1727,
#          ('<unk>', 'be'): 1726,
#          ('then', 'i'): 1721,
#          ('new', 'york'): 1721,
#          ('too', '<unk>'): 1720,
#          ('a', 'bad'): 1715,
#          ('out', 'on'): 1713,
#          ('thinking', 'about'): 1712,
#          ('the', 'year'): 1710,
#          ('<unk>', 'get'): 1710,
#          ('today', '<unk>'): 1709,
#          ('be', 'able'): 1708,
#          ('i', 'might'): 1707,
#          ('<unk>', 'great'): 1706,
#          ('now', 'im'): 1703,
#          ('a', 'week'): 1702,
#          ('with', 'us'): 1702,
#          ('those', 'who'): 1701,
#          ('my', 'way'): 1700,
#          ('give', 'me'): 1697,
#          ('one', 'day'): 1692,
#          ('want', 'a'): 1692,
#          ('to', 'stop'): 1690,
#          ('you', 'would'): 1689,
#          ('you', 'go'): 1687,
#          ('when', 'they'): 1684,
#          ('<unk>', 'would'): 1683,
#          ('out', 'with'): 1682,
#          ('away', 'from'): 1682,
#          ('their', '<unk>'): 1682,
#          ('i', 'say'): 1680,
#          ('of', 'that'): 1679,
#          ('and', 'they'): 1676,
#          ('check', 'it'): 1675,
#          ('to', 'tell'): 1671,
#          ('are', 'in'): 1670,
#          ('thanks', '<unk>'): 1669,
#          ('tell', 'you'): 1664,
#          ('next', 'time'): 1662,
#          ('i', 'said'): 1662,
#          ('but', 'not'): 1659,
#          ('is', 'one'): 1657,
#          ('are', 'going'): 1654,
#          ('on', 'facebook'): 1654,
#          ('i', 'go'): 1654,
#          ('we', 'should'): 1651,
#          ('we', 'do'): 1651,
#          ('think', 'about'): 1650,
#          ('the', 'worst'): 1650,
#          ('up', 'a'): 1643,
#          ('into', 'a'): 1638,
#          ('the', 'good'): 1637,
#          ('my', 'heart'): 1634,
#          ('love', 'my'): 1633,
#          ('and', 'all'): 1629,
#          ('<unk>', 'why'): 1627,
#          ('proud', 'of'): 1627,
#          ('<unk>', 'cant'): 1624,
#          ('u', '<unk>'): 1622,
#          ('na', 'go'): 1622,
#          ('so', 'happy'): 1617,
#          ('to', 'eat'): 1615,
#          ('stop', 'by'): 1615,
#          ('we', 'all'): 1612,
#          ('watch', 'the'): 1612,
#          ('they', 'were'): 1606,
#          ('we', 'were'): 1605,
#          ('<unk>', 'day'): 1604,
#          ('at', 'this'): 1599,
#          ('is', 'good'): 1598,
#          ('oh', 'my'): 1594,
#          ('would', 'like'): 1592,
#          ('was', 'so'): 1590,
#          ('where', 'you'): 1586,
#          ('a', 'free'): 1586,
#          ('im', 'still'): 1584,
#          ('my', 'mind'): 1582,
#          ('think', 'you'): 1582,
#          ('do', 'a'): 1581,
#          ('get', 'out'): 1581,
#          ('know', 'the'): 1578,
#          ('is', 'now'): 1578,
#          ('is', 'what'): 1578,
#          ('<unk>', 'were'): 1577,
#          ('a', 'chance'): 1577,
#          ('to', 'check'): 1577,
#          ('down', 'to'): 1576,
#          ('been', '<unk>'): 1576,
#          ('only', 'one'): 1576,
#          ('to', 'put'): 1575,
#          ('how', 'about'): 1575,
#          ('a', 'beautiful'): 1574,
#          ('the', 'big'): 1573,
#          ('a', 'year'): 1572,
#          ('<unk>', 'one'): 1571,
#          ('see', 'what'): 1571,
#          ('every', 'time'): 1567,
#          ('that', 'we'): 1567,
#          ('today', 'and'): 1567,
#          ('when', 'im'): 1566,
#          ('i', 'agree'): 1566,
#          ('its', 'so'): 1564,
#          ('think', 'its'): 1560,
#          ('was', 'in'): 1556,
#          ('just', 'like'): 1551,
#          ('come', 'out'): 1551,
#          ('so', 'you'): 1551,
#          ('i', 'wont'): 1548,
#          ('its', 'all'): 1548,
#          ('too', 'i'): 1547,
#          ('is', 'still'): 1545,
#          ('our', 'new'): 1545,
#          ('thats', 'the'): 1544,
#          ('supposed', 'to'): 1544,
#          ('get', 'some'): 1543,
#          ('the', 'future'): 1543,
#          ('in', 'that'): 1543,
#          ('out', 'in'): 1542,
#          ('when', 'it'): 1540,
#          ('about', 'a'): 1540,
#          ('a', 'huge'): 1539,
#          ('so', 'glad'): 1536,
#          ('the', 'night'): 1532,
#          ('what', 'to'): 1526,
#          ('told', 'me'): 1523,
#          ('know', 'it'): 1523,
#          ('whats', 'the'): 1523,
#          ('<unk>', 'well'): 1522,
#          ('bout', 'to'): 1521,
#          ('have', 'any'): 1519,
#          ('no', 'i'): 1518,
#          ('one', '<unk>'): 1518,
#          ('look', 'forward'): 1518,
#          ('up', 'i'): 1517,
#          ('up', 'at'): 1515,
#          ('im', 'on'): 1514,
#          ('get', 'in'): 1511,
#          ('for', 'more'): 1510,
#          ('to', 'this'): 1510,
#          ('made', 'it'): 1510,
#          ('high', 'school'): 1509,
#          ('dont', 'even'): 1508,
#          ('<unk>', 'right'): 1508,
#          ('to', 'try'): 1506,
#          ('its', 'like'): 1505,
#          ('that', 'im'): 1503,
#          ('we', 'got'): 1502,
#          ('next', 'year'): 1501,
#          ('good', 'day'): 1501,
#          ('a', 'wonderful'): 1500,
#          ('to', 'learn'): 1499,
#          ('i', 'hear'): 1498,
#          ('the', 'fuck'): 1498,
#          ('<unk>', 'too'): 1498,
#          ('find', 'out'): 1497,
#          ('for', 'sure'): 1497,
#          ('the', 'house'): 1495,
#          ('me', 'back'): 1495,
#          ('me', 'for'): 1494,
#          ('it', 'when'): 1494,
#          ('this', 'time'): 1494,
#          ('moment', 'when'): 1494,
#          ('than', 'the'): 1493,
#          ('will', 'never'): 1492,
#          ('stay', 'tuned'): 1489,
#          ('what', 'we'): 1488,
#          ('can', 'we'): 1487,
#          ('make', 'the'): 1486,
#          ('chance', 'to'): 1485,
#          ('congrats', 'on'): 1481,
#          ('when', 'we'): 1479,
#          ('think', 'im'): 1479,
#          ('its', 'time'): 1478,
#          ('about', 'that'): 1478,
#          ('get', 'back'): 1477,
#          ('you', 'you'): 1476,
#          ('great', 'time'): 1476,
#          ('at', 'me'): 1475,
#          ('time', '<unk>'): 1475,
#          ('my', 'own'): 1474,
#          ('man', 'i'): 1474,
#          ('its', 'just'): 1474,
#          ('come', 'back'): 1473,
#          ('will', 'do'): 1472,
#          ('through', 'the'): 1470,
#          ('all', 'you'): 1469,
#          ('has', 'to'): 1468,
#          ('who', 'are'): 1467,
#          ('interested', 'in'): 1467,
#          ('made', 'me'): 1467,
#          ('they', 'dont'): 1465,
#          ('got', 'it'): 1465,
#          ('to', 'buy'): 1461,
#          ('me', 'if'): 1459,
#          ('an', 'awesome'): 1458,
#          ('a', 'girl'): 1456,
#          ('your', 'own'): 1454,
#          ('we', 'dont'): 1453,
#          ('by', 'a'): 1453,
#          ('do', 'u'): 1452,
#          ('in', 'and'): 1452,
#          ('the', 'past'): 1452,
#          ('<unk>', 'hey'): 1448,
#          ('youre', 'not'): 1447,
#          ('the', 'hell'): 1447,
#          ('meet', 'you'): 1446,
#          ('youre', 'a'): 1446,
#          ('to', 'everyone'): 1445,
#          ('out', 'i'): 1445,
#          ('wont', 'be'): 1444,
#          ('the', 'great'): 1442,
#          ('back', 'on'): 1441,
#          ('am', 'so'): 1440,
#          ('we', 'had'): 1440,
#          ('following', 'me'): 1438,
#          ('if', 'your'): 1438,
#          ('because', 'of'): 1437,
#          ('<unk>', 'go'): 1435,
#          ('and', 'have'): 1434,
#          ('good', 'night'): 1432,
#          ('say', 'that'): 1431,
#          ('just', 'want'): 1431,
#          ('it', 'but'): 1431,
#          ('in', 'it'): 1430,
#          ('out', 'my'): 1430,
#          ('at', 'home'): 1430,
#          ('do', '<unk>'): 1427,
#          ('woke', 'up'): 1424,
#          ('be', 'so'): 1422,
#          ('you', 'make'): 1419,
#          ('us', 'know'): 1418,
#          ('each', 'other'): 1418,
#          ('but', 'we'): 1418,
#          ('no', 'problem'): 1418,
#          ('see', '<unk>'): 1417,
#          ('you', 'ever'): 1417,
#          ('you', 'feel'): 1411,
#          ...})

# %%
def prob_for_single_word(word, previous_n_gram, n_gram_counts, nplus1_gram_counts, vocabulary_size, k = 1.0) -> 'float':

  # Convert the previous_n_gram into a tuple
  previous_n_gram = tuple(previous_n_gram)

  # Calculating the count, if exists from our freq dictionary otherwise zero
  previous_n_gram_count = n_gram_counts[previous_n_gram] if previous_n_gram in n_gram_counts else 0

  # The Denominator
  denom = previous_n_gram_count + k * vocabulary_size

  # previous n-gram plus the current word as a tuple
  nplus1_gram = previous_n_gram + (word,)

  # Calculating the nplus1 count, if exists from our freq dictionary otherwise zero
  nplus1_gram_count = nplus1_gram_counts[nplus1_gram] if nplus1_gram in nplus1_gram_counts else 0

  # Numerator
  num = nplus1_gram_count + k

  # Final Fraction
  prob = num / denom
  return prob

# %%
def probs(previous_n_gram, n_gram_counts, nplus1_gram_counts, vocabulary, k=1.0) -> 'dict':

  # Convert to Tuple
  previous_n_gram = tuple(previous_n_gram)

  # Add end and unknown tokens to the vocabulary
  vocabulary = vocabulary + ["<e>", "<unk>"]

  # Calculate the size of the vocabulary
  vocabulary_size = len(vocabulary)

  # Empty dict for probabilites
  probabilities = {}

  # Iterate over words
  for word in vocabulary:

    # Calculate probability
    probability = prob_for_single_word(word, previous_n_gram,
                                           n_gram_counts, nplus1_gram_counts,
                                           vocabulary_size, k=k)
    # Create mapping: word -> probability
    probabilities[word] = probability

  return probabilities

# %%
def auto_complete(previous_tokens, n_gram_counts, nplus1_gram_counts, vocabulary, k=1.0, start_with=None):


    # length of previous words
    n = len(list(n_gram_counts.keys())[0])

    # most recent 'n' words
    previous_n_gram = previous_tokens[-n:]

    # Calculate probabilty for all words
    probabilities = probs(previous_n_gram,n_gram_counts, nplus1_gram_counts,vocabulary, k=k)

    # Intialize the suggestion and max probability
    suggestion = None
    max_prob = 0

    # Iterate over all words and probabilites, returning the max.
    # We also add a check if the start_with parameter is provided
    for word, prob in probabilities.items():

        if start_with != None:

            if not word.startswith(start_with):
                continue

        if prob > max_prob:

            suggestion = word
            max_prob = prob

    return suggestion, max_prob

# %%
def get_suggestions(previous_tokens, n_gram_counts_list, vocabulary, k=1.0, start_with=None):

    # See how many models we have
    count = len(n_gram_counts_list)

    # Empty list for suggestions
    suggestions = []

    # IMP: Earlier "-1"

    # Loop over counts
    for i in range(count-1):

        # get n and nplus1 counts
        n_gram_counts = n_gram_counts_list[i]
        nplus1_gram_counts = n_gram_counts_list[i+1]

        # get suggestions
        suggestion = auto_complete(previous_tokens, n_gram_counts,
                                    nplus1_gram_counts, vocabulary,
                                    k=k, start_with=start_with)
        # Append to list
        suggestions.append(suggestion)

    return suggestions

# %%
n_gram_counts_list = []
for n in range(1, 6):
    n_model_counts = count_n_grams_builtin(final_train, n)
    n_gram_counts_list.append(n_model_counts)

# %%
previous_tokens = ["i", "was", "about"]
suggestion = get_suggestions(previous_tokens, n_gram_counts_list, vocabulary, k=1.0)

display(suggestion)
# Out:
# [('the', 0.08511202049047605),
#  ('to', 0.010632183908045977),
#  ('to', 0.007232612507305669),
#  ('lol', 7.372456502506635e-05)]
